# %%
import quandl
import pandas as pd
import seaborn as sns
import yfinance as yf 
import pandas as pd
from matplotlib import pylab as plt
import numpy as np
from datetime import datetime
import math
import quandl
import seaborn as sns
import sys
import pandas_datareader.data as web
from statsmodels.graphics.tsaplots import plot_acf
import datetime as dt
from dateutil.relativedelta import relativedelta

# %%
def Z_score(data):
    # not including the current observation
    std = data.iloc[:-1].std()
    mean = data.iloc[:-1].mean()
    Z = (data[-1:] - mean)/std
    return Z

# %%
def color_negative_red(value):
    """
      Colors elements in a dateframe
      green if positive and red if
      negative. Does not color NaN
      values.
      """

    if value < 0:
        color = 'red'
    elif value > 0:
        color = 'green'
    else:
        color = 'black'

    return 'color: %s' % color

# %% [markdown]
# # Sentiment analysis (Futures only)
# - sp500
# - gold
# - dollar
# - Bitcoin (Not option data)
#
#
# Z score for net positions (1 and 3 years) and change in position (1 month and 3 months).

# %%
#data import

gold_tmp = quandl.get("CFTC/088691_F_L_ALL")
sp500_tmp = quandl.get("CFTC/138741_F_L_ALL")
dxy_tmp = quandl.get("CFTC/098662_F_L_ALL")
bitcoin_tmp = quandl.get("CFTC/133741_F_L_ALL")

# %%
assets = [gold_tmp,sp500_tmp, dxy_tmp, bitcoin_tmp]
asset_names = ['Gold', 'SP500', 'DXY', 'Bitcoin']

# %%
for asset in assets:
    asset['Net Position'] = asset['Noncommercial Long'] - asset['Noncommercial Short']
    asset['1 Yr Z Score'] = asset['Net Position'].rolling(52).apply(lambda x: Z_score(x),raw=False)
    asset['3 Yr Z Score'] = asset['Net Position'].rolling(3 * 52).apply(lambda x: Z_score(x),raw=False) 
    asset['1 Month Change'] = asset['Net Position'].diff(4)/asset['Net Position'].shift(4)
    asset['3 Month Change'] = asset['Net Position'].diff(3*4)/asset['Net Position'].shift(3*4)

# %%
TOTAL_ASSETS = None

for asset in assets:
    
    TOTAL_ASSETS = pd.concat([TOTAL_ASSETS, asset.tail(1)], axis = 0)
    
TOTAL_ASSETS['Asset'] = asset_names
TOTAL_ASSETS.set_index(['Asset'], inplace=True, drop=True)

compact = ['1 Yr Z Score', '3 Yr Z Score', '1 Month Change', '3 Month Change']
TOTAL_ASSETS = TOTAL_ASSETS[compact]

# %% [markdown]
# ## Display Results

# %%
th_props = [
  ('font-size', '16px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'Black'),
  ('background-color', '#f7f7f9')
  ]


# Set CSS properties for td elements in dataframe
td_props = [('font-size', '16px'), ('text-align', 'center')]

# Set table styles
styles = [
    dict(selector="th", props=th_props),
    dict(selector="td", props=td_props)
]

cm_low_good = sns.diverging_palette(150, 10, s=80, l=70, n=len(TOTAL_ASSETS.columns), as_cmap=True)#sns.light_palette("green", as_cmap=True)
cm_high_good = sns.diverging_palette(10, 150, s=80, l=70, n=len(TOTAL_ASSETS.columns), as_cmap=True)

TOTAL_ASSETS_VIEW = (TOTAL_ASSETS.style
    .applymap(color_negative_red, subset=['1 Yr Z Score', '3 Yr Z Score', '1 Month Change', '3 Month Change'])
    #.background_gradient(axis = 0 ,subset = ['DSSP', 'HIDI'],cmap=cm_high_good)
    #.background_gradient(axis = 0 ,subset = ['VRANK', 'MRANK','CRANK', 'ST'],cmap=cm_low_good)
    .set_caption('Speculator Positioning')
    .format({'1 Month Change': "{:.1%}",'3 Month Change': "{:.1%}", '1 Yr Z Score': "{:.2f}", '3 Yr Z Score': "{:.2f}"})
    .set_table_styles(styles))

# %% [markdown]
# # Returns, Realized and Implied Volatility

# %%
#Prices

GOLD_price_tmp = yf.download('GLD')
SP500_price_tmp = yf.download('SPY')
DXY_price_tmp = yf.download('DX-Y.NYB')
BIT_price_tmp = yf.download('BTC-USD')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
GOLD_price = pd.DataFrame(GOLD_price_tmp['Close'])
SP500_price = pd.DataFrame(SP500_price_tmp['Close'])
DXY_price = pd.DataFrame(DXY_price_tmp['Close'])
BIT_price = pd.DataFrame(BIT_price_tmp['Close'])


prices = [GOLD_price,SP500_price,DXY_price, BIT_price ]
price_names = ['Gold', 'SP500', 'DXY', 'Bitcoin']

# %%
imp_vol = pd.DataFrame()
imp_vol['Asset'] = ['Gold', 'SP500', 'DXY', 'Bitcoin']
imp_vol['ImpVol'] = np.nan 

tickers = ['GLD', 'SPY', 'UUP']
month_delta = 1

for i in range(len(tickers)):
    try:
        price_ind = yf.download(tickers[i],start='2020-01-01', progress = False, threads = False)
        stock = yf.Ticker(tickers[i])
        option_dates = stock.options
        date = dt.datetime.now()
        date += relativedelta(months=month_delta) 
        expiry_one_month = min(option_dates, key=lambda x:abs(dt.datetime.strptime(x, "%Y-%M-%d")-date))
        current_price = float(price_ind['Close'].tail(1))
        
        calls = stock.option_chain(expiry_one_month).calls
        puts = stock.option_chain(expiry_one_month).puts
        
        #ATM Skew
        ATM_put = puts[puts['strike'] == min(puts['strike'], key=lambda x:abs(x-current_price))]
        ATM_call = calls[calls['strike'] == min(calls['strike'], key=lambda x:abs(x-current_price))]
        ATM_skew = float(ATM_put['impliedVolatility']) - float(ATM_call['impliedVolatility']) 
        
        imp_vol.loc[i,"ImpVol"] = float(ATM_put['impliedVolatility'])
        
    except:
        print("ERROR! INDEX: ", i, ', TICKER: ', tickers[i])

# %%
for price in prices:
    price['1 Month Return'] = price['Close'].pct_change(20)
    price['3 Month Return'] = price['Close'].pct_change(60)
    price['Volatility'] = price['Close'].pct_change().rolling(21).std()*(252**0.5)
    price['3 year Volatility Z-Score'] = price['Volatility'].rolling(3 * 52).apply(lambda x: Z_score(x),raw=False) 


PRICES = None

for price in prices:
    
    PRICES = pd.concat([PRICES, price.tail(1)], axis = 0)
    
PRICES['Asset'] = asset_names
compact_1 = ['Asset', '1 Month Return', '3 Month Return', 'Volatility', '3 year Volatility Z-Score']
PRICES = PRICES[compact_1]
PRICES.set_index(['Asset'], inplace=True, drop=True)

PRICES = pd.merge(PRICES, imp_vol, how="left", on=['Asset'])
PRICES['Implied Vol Premium'] = PRICES['ImpVol'] - PRICES['Volatility']

# %%
PRICES
# Out:
#      Asset  1 Month Return  3 Month Return  Volatility  \
# 0     Gold       -0.045512       -0.005962    0.111584
# 1    SP500       -0.017207        0.063591    0.172549
# 2      DXY        0.007131        0.036524    0.055040
# 3  Bitcoin       -0.180713       -0.229385    0.573743
#
#    3 year Volatility Z-Score    ImpVol  Implied Vol Premium
# 0                  -0.696051  0.161385             0.049801
# 1                   2.151487  0.218590             0.046041
# 2                   0.500940  0.087411             0.032371
# 3                   0.485662       NaN                  NaN

# %%
th_props = [
  ('font-size', '16px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'Black'),
  ('background-color', '#f7f7f9')
  ]


# Set CSS properties for td elements in dataframe
td_props = [('font-size', '16px'), ('text-align', 'center')]

# Set table styles
styles = [
    dict(selector="th", props=th_props),
    dict(selector="td", props=td_props)
]


cm_low_good = sns.diverging_palette(150, 10, s=80, l=70, n=len(PRICES.columns), as_cmap=True)#sns.light_palette("green", as_cmap=True)
cm_high_good = sns.diverging_palette(10, 150, s=80, l=70, n=len(PRICES.columns), as_cmap=True)

PRICES_VIEW = (PRICES.style
    .applymap(color_negative_red, subset=['1 Month Return', '3 Month Return', 'Volatility', '3 year Volatility Z-Score', 'ImpVol', 'Implied Vol Premium'])
    .set_caption('Asset Metrics')
    .format({'1 Month Return': "{:.1%}",'3 Month Return': "{:.1%}", 'Volatility': "{:.1%}", '3 year Volatility Z-Score': "{:.2f}", 
            'ImpVol': "{:.1%}",'Implied Vol Premium': "{:.1%}" })
    .set_table_styles(styles))

# %% [markdown]
# ## View metrics

# %%
PRICES_VIEW
# Out:
# <style  type="text/css" >
#     #T_1922467a_5dcc_11ec_b44d_8c859039bca2 th {
#           font-size: 16px;
#           text-align: center;
#           font-weight: bold;
#           color: Black;
#           background-color: #f7f7f9;
#     }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2 td {
#           font-size: 16px;
#           text-align: center;
#     }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row0_col1 {
#             color:  red;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row0_col2 {
#             color:  red;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row0_col3 {
#             color:  green;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row0_col4 {
#             color:  red;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row0_col5 {
#             color:  green;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row0_col6 {
#             color:  green;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row1_col1 {
#             color:  red;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row1_col2 {
#             color:  green;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row1_col3 {
#             color:  green;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row1_col4 {
#             color:  green;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row1_col5 {
#             color:  green;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row1_col6 {
#             color:  green;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row2_col1 {
#             color:  green;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row2_col2 {
#             color:  green;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row2_col3 {
#             color:  green;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row2_col4 {
#             color:  green;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row2_col5 {
#             color:  green;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row2_col6 {
#             color:  green;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row3_col1 {
#             color:  red;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row3_col2 {
#             color:  red;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row3_col3 {
#             color:  green;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row3_col4 {
#             color:  green;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row3_col5 {
#             color:  black;
#         }    #T_1922467a_5dcc_11ec_b44d_8c859039bca2row3_col6 {
#             color:  black;
#         }</style><table id="T_1922467a_5dcc_11ec_b44d_8c859039bca2" ><caption>Asset Metrics</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Asset</th>        <th class="col_heading level0 col1" >1 Month Return</th>        <th class="col_heading level0 col2" >3 Month Return</th>        <th class="col_heading level0 col3" >Volatility</th>        <th class="col_heading level0 col4" >3 year Volatility Z-Score</th>        <th class="col_heading level0 col5" >ImpVol</th>        <th class="col_heading level0 col6" >Implied Vol Premium</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1922467a_5dcc_11ec_b44d_8c859039bca2level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row0_col0" class="data row0 col0" >Gold</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row0_col1" class="data row0 col1" >-4.6%</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row0_col2" class="data row0 col2" >-0.6%</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row0_col3" class="data row0 col3" >11.2%</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row0_col4" class="data row0 col4" >-0.70</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row0_col5" class="data row0 col5" >16.1%</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row0_col6" class="data row0 col6" >5.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_1922467a_5dcc_11ec_b44d_8c859039bca2level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row1_col0" class="data row1 col0" >SP500</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row1_col1" class="data row1 col1" >-1.7%</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row1_col2" class="data row1 col2" >6.4%</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row1_col3" class="data row1 col3" >17.3%</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row1_col4" class="data row1 col4" >2.15</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row1_col5" class="data row1 col5" >21.9%</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row1_col6" class="data row1 col6" >4.6%</td>
#             </tr>
#             <tr>
#                         <th id="T_1922467a_5dcc_11ec_b44d_8c859039bca2level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row2_col0" class="data row2 col0" >DXY</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row2_col1" class="data row2 col1" >0.7%</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row2_col2" class="data row2 col2" >3.7%</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row2_col3" class="data row2 col3" >5.5%</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row2_col4" class="data row2 col4" >0.50</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row2_col5" class="data row2 col5" >8.7%</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row2_col6" class="data row2 col6" >3.2%</td>
#             </tr>
#             <tr>
#                         <th id="T_1922467a_5dcc_11ec_b44d_8c859039bca2level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row3_col0" class="data row3 col0" >Bitcoin</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row3_col1" class="data row3 col1" >-18.1%</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row3_col2" class="data row3 col2" >-22.9%</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row3_col3" class="data row3 col3" >57.4%</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row3_col4" class="data row3 col4" >0.49</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row3_col5" class="data row3 col5" >nan%</td>
#                         <td id="T_1922467a_5dcc_11ec_b44d_8c859039bca2row3_col6" class="data row3 col6" >nan%</td>
#             </tr>
#     </tbody></table>

# %%
TOTAL_ASSETS_VIEW
# Out:
# <style  type="text/css" >
#     #T_1e357d76_5dcc_11ec_b44d_8c859039bca2 th {
#           font-size: 16px;
#           text-align: center;
#           font-weight: bold;
#           color: Black;
#           background-color: #f7f7f9;
#     }    #T_1e357d76_5dcc_11ec_b44d_8c859039bca2 td {
#           font-size: 16px;
#           text-align: center;
#     }    #T_1e357d76_5dcc_11ec_b44d_8c859039bca2row0_col0 {
#             color:  green;
#             color:  green;
#         }    #T_1e357d76_5dcc_11ec_b44d_8c859039bca2row0_col1 {
#             color:  red;
#             color:  red;
#         }    #T_1e357d76_5dcc_11ec_b44d_8c859039bca2row0_col2 {
#             color:  red;
#             color:  red;
#         }    #T_1e357d76_5dcc_11ec_b44d_8c859039bca2row0_col3 {
#             color:  green;
#             color:  green;
#         }    #T_1e357d76_5dcc_11ec_b44d_8c859039bca2row1_col0 {
#             color:  green;
#             color:  green;
#         }    #T_1e357d76_5dcc_11ec_b44d_8c859039bca2row1_col1 {
#             color:  green;
#             color:  green;
#         }    #T_1e357d76_5dcc_11ec_b44d_8c859039bca2row1_col2 {
#             color:  green;
#             color:  green;
#         }    #T_1e357d76_5dcc_11ec_b44d_8c859039bca2row1_col3 {
#             color:  green;
#             color:  green;
#         }    #T_1e357d76_5dcc_11ec_b44d_8c859039bca2row2_col0 {
#             color:  green;
#             color:  green;
#         }    #T_1e357d76_5dcc_11ec_b44d_8c859039bca2row2_col1 {
#             color:  green;
#             color:  green;
#         }    #T_1e357d76_5dcc_11ec_b44d_8c859039bca2row2_col2 {
#             color:  red;
#             color:  red;
#         }    #T_1e357d76_5dcc_11ec_b44d_8c859039bca2row2_col3 {
#             color:  green;
#             color:  green;
#         }    #T_1e357d76_5dcc_11ec_b44d_8c859039bca2row3_col0 {
#             color:  green;
#             color:  green;
#         }    #T_1e357d76_5dcc_11ec_b44d_8c859039bca2row3_col1 {
#             color:  green;
#             color:  green;
#         }    #T_1e357d76_5dcc_11ec_b44d_8c859039bca2row3_col2 {
#             color:  red;
#             color:  red;
#         }    #T_1e357d76_5dcc_11ec_b44d_8c859039bca2row3_col3 {
#             color:  red;
#             color:  red;
#         }</style><table id="T_1e357d76_5dcc_11ec_b44d_8c859039bca2" ><caption>Speculator Positioning</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1 Yr Z Score</th>        <th class="col_heading level0 col1" >3 Yr Z Score</th>        <th class="col_heading level0 col2" >1 Month Change</th>        <th class="col_heading level0 col3" >3 Month Change</th>    </tr>    <tr>        <th class="index_name level0" >Asset</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e357d76_5dcc_11ec_b44d_8c859039bca2level0_row0" class="row_heading level0 row0" >Gold</th>
#                         <td id="T_1e357d76_5dcc_11ec_b44d_8c859039bca2row0_col0" class="data row0 col0" >0.27</td>
#                         <td id="T_1e357d76_5dcc_11ec_b44d_8c859039bca2row0_col1" class="data row0 col1" >-0.03</td>
#                         <td id="T_1e357d76_5dcc_11ec_b44d_8c859039bca2row0_col2" class="data row0 col2" >-13.2%</td>
#                         <td id="T_1e357d76_5dcc_11ec_b44d_8c859039bca2row0_col3" class="data row0 col3" >4.5%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e357d76_5dcc_11ec_b44d_8c859039bca2level0_row1" class="row_heading level0 row1" >SP500</th>
#                         <td id="T_1e357d76_5dcc_11ec_b44d_8c859039bca2row1_col0" class="data row1 col0" >1.19</td>
#                         <td id="T_1e357d76_5dcc_11ec_b44d_8c859039bca2row1_col1" class="data row1 col1" >1.90</td>
#                         <td id="T_1e357d76_5dcc_11ec_b44d_8c859039bca2row1_col2" class="data row1 col2" >161.3%</td>
#                         <td id="T_1e357d76_5dcc_11ec_b44d_8c859039bca2row1_col3" class="data row1 col3" >203.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e357d76_5dcc_11ec_b44d_8c859039bca2level0_row2" class="row_heading level0 row2" >DXY</th>
#                         <td id="T_1e357d76_5dcc_11ec_b44d_8c859039bca2row2_col0" class="data row2 col0" >1.53</td>
#                         <td id="T_1e357d76_5dcc_11ec_b44d_8c859039bca2row2_col1" class="data row2 col1" >1.24</td>
#                         <td id="T_1e357d76_5dcc_11ec_b44d_8c859039bca2row2_col2" class="data row2 col2" >-1.6%</td>
#                         <td id="T_1e357d76_5dcc_11ec_b44d_8c859039bca2row2_col3" class="data row2 col3" >43.6%</td>
#             </tr>
#             <tr>
#                         <th id="T_1e357d76_5dcc_11ec_b44d_8c859039bca2level0_row3" class="row_heading level0 row3" >Bitcoin</th>
#                         <td id="T_1e357d76_5dcc_11ec_b44d_8c859039bca2row3_col0" class="data row3 col0" >1.17</td>
#                         <td id="T_1e357d76_5dcc_11ec_b44d_8c859039bca2row3_col1" class="data row3 col1" >0.75</td>
#                         <td id="T_1e357d76_5dcc_11ec_b44d_8c859039bca2row3_col2" class="data row3 col2" >-38.1%</td>
#                         <td id="T_1e357d76_5dcc_11ec_b44d_8c859039bca2row3_col3" class="data row3 col3" >-23.5%</td>
#             </tr>
#     </tbody></table>
