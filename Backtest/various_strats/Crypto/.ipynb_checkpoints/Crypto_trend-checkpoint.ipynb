# %%
import yfinance as yf 
import pandas as pd
from matplotlib import pylab as plt
import numpy as np
from datetime import datetime
import seaborn as sns
from scipy.stats import norm
import scipy.optimize as sco
import scipy
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %% [markdown]
# # Crypto Trend Following
#
# testing trend following on crypto (start with bitcoin).
#
# Methods to test:
# - Time Series Momentum
# - Breakouts
# - Moving Average Cross Over
#
# Also try to optimize the best parameters
#
# FUTURE WORK
# - implement same models with week day data only (if to use Avanza or futures)

# %%
# load help function

# %run crypto_help.ipynb

# %%
## Data import of WE

dat_tmp = yf.download('DOGE-USD')
#dat_tmp = yf.download('DOT1-USD')
close = pd.DataFrame(dat_tmp['Close'])



####Convert to Week day data

close_5day = close[close.index.dayofweek < 5]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # Data Analysis

# %%
df_ret = close.pct_change(1).dropna()

# %%
plot_acf(df_ret, lags=20)
plt.show()

# %%
plot_pacf(df_ret, lags=10)
plt.show()

# %% [markdown]
# ### Time Series Momentum

# %%
test = pd.DataFrame(range(1,100))
test.columns = ['lookback']
for i in range(len(test)):
    
    test.loc[i, 'metric'] = time_series(close ,test.loc[i, 'lookback'] , metric = 'sharpe')

# %%
plt.plot(test['lookback'], test['metric']);
#print(test['metric'].max())

# %% [markdown]
# ### Simple EWMA

# %%
test = pd.DataFrame(range(2,100))
test.columns = ['lookback']
for i in range(len(test)):
    
    test.loc[i, 'metric'] = MA_TF(close ,test.loc[i, 'lookback'] , metric = 'sharpe')

# %%
plt.plot(test['lookback'], test['metric']);
#print(test['metric'].max())

# %% [markdown]
# ### Breakouts and Cross over:
#
# Use functions

# %%
optimize_results(method = cross_over, data = close, metric = 'sharpe', plot = 'False')
# Out:
# Best Slow Moving Avergae/Long Breakout:  30
# Best Fast Moving Avergae/Exit Breakout:  10
#  sharpe :  1.094266307287564

# %% [markdown]
# #### Equity Curve for Time Series Momentum

# %%
df_tmp = time_series(close ,15 , metric = 'data')
res = df_tmp[['Strategy_cum', 'Bench']]
strategy_evaluation(res, ['Bench'], 3000, freq = 'D')
# Out:
# <style  type="text/css" >
#     #T_d558717e_3631_11ec_ae71_8c859039bca2 th {
#           font-size: 20px;
#           text-align: center;
#           font-weight: bold;
#           color: Black;
#           background-color: #f7f7f9;
#     }    #T_d558717e_3631_11ec_ae71_8c859039bca2 td {
#           font-size: 20px;
#           text-align: center;
#     }    #T_d558717e_3631_11ec_ae71_8c859039bca2row0_col0 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_d558717e_3631_11ec_ae71_8c859039bca2row0_col1 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_d558717e_3631_11ec_ae71_8c859039bca2row0_col2 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_d558717e_3631_11ec_ae71_8c859039bca2row0_col3 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_d558717e_3631_11ec_ae71_8c859039bca2row0_col4 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_d558717e_3631_11ec_ae71_8c859039bca2row0_col5 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_d558717e_3631_11ec_ae71_8c859039bca2row0_col6 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_d558717e_3631_11ec_ae71_8c859039bca2row0_col7 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_d558717e_3631_11ec_ae71_8c859039bca2row0_col8 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_d558717e_3631_11ec_ae71_8c859039bca2row1_col0 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_d558717e_3631_11ec_ae71_8c859039bca2row1_col1 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_d558717e_3631_11ec_ae71_8c859039bca2row1_col2 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_d558717e_3631_11ec_ae71_8c859039bca2row1_col3 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_d558717e_3631_11ec_ae71_8c859039bca2row1_col4 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_d558717e_3631_11ec_ae71_8c859039bca2row1_col5 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_d558717e_3631_11ec_ae71_8c859039bca2row1_col6 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_d558717e_3631_11ec_ae71_8c859039bca2row1_col7 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_d558717e_3631_11ec_ae71_8c859039bca2row1_col8 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }</style><table id="T_d558717e_3631_11ec_ae71_8c859039bca2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CAGR</th>        <th class="col_heading level0 col1" >Volatility</th>        <th class="col_heading level0 col2" >Sharpe</th>        <th class="col_heading level0 col3" >Sortino</th>        <th class="col_heading level0 col4" >Max DD</th>        <th class="col_heading level0 col5" >MAR</th>        <th class="col_heading level0 col6" >SWR</th>        <th class="col_heading level0 col7" >Skew</th>        <th class="col_heading level0 col8" >Kurtosis</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d558717e_3631_11ec_ae71_8c859039bca2level0_row0" class="row_heading level0 row0" >Portfolio</th>
#                         <td id="T_d558717e_3631_11ec_ae71_8c859039bca2row0_col0" class="data row0 col0" >153.7%</td>
#                         <td id="T_d558717e_3631_11ec_ae71_8c859039bca2row0_col1" class="data row0 col1" >99.2%</td>
#                         <td id="T_d558717e_3631_11ec_ae71_8c859039bca2row0_col2" class="data row0 col2" >1.52</td>
#                         <td id="T_d558717e_3631_11ec_ae71_8c859039bca2row0_col3" class="data row0 col3" >1.79</td>
#                         <td id="T_d558717e_3631_11ec_ae71_8c859039bca2row0_col4" class="data row0 col4" >-66%</td>
#                         <td id="T_d558717e_3631_11ec_ae71_8c859039bca2row0_col5" class="data row0 col5" >2.33</td>
#                         <td id="T_d558717e_3631_11ec_ae71_8c859039bca2row0_col6" class="data row0 col6" >118.2%</td>
#                         <td id="T_d558717e_3631_11ec_ae71_8c859039bca2row0_col7" class="data row0 col7" >16.264</td>
#                         <td id="T_d558717e_3631_11ec_ae71_8c859039bca2row0_col8" class="data row0 col8" >483.96</td>
#             </tr>
#             <tr>
#                         <th id="T_d558717e_3631_11ec_ae71_8c859039bca2level0_row1" class="row_heading level0 row1" >Bench</th>
#                         <td id="T_d558717e_3631_11ec_ae71_8c859039bca2row1_col0" class="data row1 col0" >92.6%</td>
#                         <td id="T_d558717e_3631_11ec_ae71_8c859039bca2row1_col1" class="data row1 col1" >115.7%</td>
#                         <td id="T_d558717e_3631_11ec_ae71_8c859039bca2row1_col2" class="data row1 col2" >1.21</td>
#                         <td id="T_d558717e_3631_11ec_ae71_8c859039bca2row1_col3" class="data row1 col3" >1.88</td>
#                         <td id="T_d558717e_3631_11ec_ae71_8c859039bca2row1_col4" class="data row1 col4" >-91%</td>
#                         <td id="T_d558717e_3631_11ec_ae71_8c859039bca2row1_col5" class="data row1 col5" >1.02</td>
#                         <td id="T_d558717e_3631_11ec_ae71_8c859039bca2row1_col6" class="data row1 col6" >51.2%</td>
#                         <td id="T_d558717e_3631_11ec_ae71_8c859039bca2row1_col7" class="data row1 col7" >12.385</td>
#                         <td id="T_d558717e_3631_11ec_ae71_8c859039bca2row1_col8" class="data row1 col8" >332.611</td>
#             </tr>
#     </tbody></table>

# %%
plot(res, "log") # "log" for log otherwise "" for lin
trade_analysis(df_tmp['signal'])
# Out:
# Number of Trades:  151.0
# Average holding time:  8.0
# Trades per Year:  21.4

# %% [markdown]
# #### Equity Curve for Exponential and Price

# %%
df_tmp = MA_TF(close ,20 , metric = 'data')
res = df_tmp[['Strategy_cum', 'Bench']]
strategy_evaluation(res, ['Bench'], 3000, freq = 'D')
# Out:
# <style  type="text/css" >
#     #T_ece58b74_3631_11ec_ae71_8c859039bca2 th {
#           font-size: 20px;
#           text-align: center;
#           font-weight: bold;
#           color: Black;
#           background-color: #f7f7f9;
#     }    #T_ece58b74_3631_11ec_ae71_8c859039bca2 td {
#           font-size: 20px;
#           text-align: center;
#     }    #T_ece58b74_3631_11ec_ae71_8c859039bca2row0_col0 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_ece58b74_3631_11ec_ae71_8c859039bca2row0_col1 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_ece58b74_3631_11ec_ae71_8c859039bca2row0_col2 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_ece58b74_3631_11ec_ae71_8c859039bca2row0_col3 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_ece58b74_3631_11ec_ae71_8c859039bca2row0_col4 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_ece58b74_3631_11ec_ae71_8c859039bca2row0_col5 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_ece58b74_3631_11ec_ae71_8c859039bca2row0_col6 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_ece58b74_3631_11ec_ae71_8c859039bca2row0_col7 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_ece58b74_3631_11ec_ae71_8c859039bca2row0_col8 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_ece58b74_3631_11ec_ae71_8c859039bca2row1_col0 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_ece58b74_3631_11ec_ae71_8c859039bca2row1_col1 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_ece58b74_3631_11ec_ae71_8c859039bca2row1_col2 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_ece58b74_3631_11ec_ae71_8c859039bca2row1_col3 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_ece58b74_3631_11ec_ae71_8c859039bca2row1_col4 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_ece58b74_3631_11ec_ae71_8c859039bca2row1_col5 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_ece58b74_3631_11ec_ae71_8c859039bca2row1_col6 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_ece58b74_3631_11ec_ae71_8c859039bca2row1_col7 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_ece58b74_3631_11ec_ae71_8c859039bca2row1_col8 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }</style><table id="T_ece58b74_3631_11ec_ae71_8c859039bca2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CAGR</th>        <th class="col_heading level0 col1" >Volatility</th>        <th class="col_heading level0 col2" >Sharpe</th>        <th class="col_heading level0 col3" >Sortino</th>        <th class="col_heading level0 col4" >Max DD</th>        <th class="col_heading level0 col5" >MAR</th>        <th class="col_heading level0 col6" >SWR</th>        <th class="col_heading level0 col7" >Skew</th>        <th class="col_heading level0 col8" >Kurtosis</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ece58b74_3631_11ec_ae71_8c859039bca2level0_row0" class="row_heading level0 row0" >Portfolio</th>
#                         <td id="T_ece58b74_3631_11ec_ae71_8c859039bca2row0_col0" class="data row0 col0" >119.5%</td>
#                         <td id="T_ece58b74_3631_11ec_ae71_8c859039bca2row0_col1" class="data row0 col1" >97.8%</td>
#                         <td id="T_ece58b74_3631_11ec_ae71_8c859039bca2row0_col2" class="data row0 col2" >1.38</td>
#                         <td id="T_ece58b74_3631_11ec_ae71_8c859039bca2row0_col3" class="data row0 col3" >1.63</td>
#                         <td id="T_ece58b74_3631_11ec_ae71_8c859039bca2row0_col4" class="data row0 col4" >-80%</td>
#                         <td id="T_ece58b74_3631_11ec_ae71_8c859039bca2row0_col5" class="data row0 col5" >1.49</td>
#                         <td id="T_ece58b74_3631_11ec_ae71_8c859039bca2row0_col6" class="data row0 col6" >84.5%</td>
#                         <td id="T_ece58b74_3631_11ec_ae71_8c859039bca2row0_col7" class="data row0 col7" >16.628</td>
#                         <td id="T_ece58b74_3631_11ec_ae71_8c859039bca2row0_col8" class="data row0 col8" >499.141</td>
#             </tr>
#             <tr>
#                         <th id="T_ece58b74_3631_11ec_ae71_8c859039bca2level0_row1" class="row_heading level0 row1" >Bench</th>
#                         <td id="T_ece58b74_3631_11ec_ae71_8c859039bca2row1_col0" class="data row1 col0" >93.5%</td>
#                         <td id="T_ece58b74_3631_11ec_ae71_8c859039bca2row1_col1" class="data row1 col1" >115.9%</td>
#                         <td id="T_ece58b74_3631_11ec_ae71_8c859039bca2row1_col2" class="data row1 col2" >1.22</td>
#                         <td id="T_ece58b74_3631_11ec_ae71_8c859039bca2row1_col3" class="data row1 col3" >1.88</td>
#                         <td id="T_ece58b74_3631_11ec_ae71_8c859039bca2row1_col4" class="data row1 col4" >-91%</td>
#                         <td id="T_ece58b74_3631_11ec_ae71_8c859039bca2row1_col5" class="data row1 col5" >1.03</td>
#                         <td id="T_ece58b74_3631_11ec_ae71_8c859039bca2row1_col6" class="data row1 col6" >52.1%</td>
#                         <td id="T_ece58b74_3631_11ec_ae71_8c859039bca2row1_col7" class="data row1 col7" >12.321</td>
#                         <td id="T_ece58b74_3631_11ec_ae71_8c859039bca2row1_col8" class="data row1 col8" >330.941</td>
#             </tr>
#     </tbody></table>

# %%
plot(res, "log") # "log" for log otherwise "" for lin
trade_analysis(df_tmp['signal'])
# Out:
# Number of Trades:  151.0
# Average holding time:  8.0
# Trades per Year:  21.3

# %% [markdown]
# #### Equity Curve for Break Outs

# %%
df_tmp = break_out(close, lookback_low = 10, lookback_high = 20, metric = 'data')
res = df_tmp[['Strategy_cum', 'Bench']]
strategy_evaluation(res, ['Bench'], 3000, freq = 'D')
# Out:
# <style  type="text/css" >
#     #T_fc2f4df4_3631_11ec_ae71_8c859039bca2 th {
#           font-size: 20px;
#           text-align: center;
#           font-weight: bold;
#           color: Black;
#           background-color: #f7f7f9;
#     }    #T_fc2f4df4_3631_11ec_ae71_8c859039bca2 td {
#           font-size: 20px;
#           text-align: center;
#     }    #T_fc2f4df4_3631_11ec_ae71_8c859039bca2row0_col0 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_fc2f4df4_3631_11ec_ae71_8c859039bca2row0_col1 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_fc2f4df4_3631_11ec_ae71_8c859039bca2row0_col2 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_fc2f4df4_3631_11ec_ae71_8c859039bca2row0_col3 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_fc2f4df4_3631_11ec_ae71_8c859039bca2row0_col4 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_fc2f4df4_3631_11ec_ae71_8c859039bca2row0_col5 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_fc2f4df4_3631_11ec_ae71_8c859039bca2row0_col6 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_fc2f4df4_3631_11ec_ae71_8c859039bca2row0_col7 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_fc2f4df4_3631_11ec_ae71_8c859039bca2row0_col8 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_fc2f4df4_3631_11ec_ae71_8c859039bca2row1_col0 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_fc2f4df4_3631_11ec_ae71_8c859039bca2row1_col1 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_fc2f4df4_3631_11ec_ae71_8c859039bca2row1_col2 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_fc2f4df4_3631_11ec_ae71_8c859039bca2row1_col3 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_fc2f4df4_3631_11ec_ae71_8c859039bca2row1_col4 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_fc2f4df4_3631_11ec_ae71_8c859039bca2row1_col5 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_fc2f4df4_3631_11ec_ae71_8c859039bca2row1_col6 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_fc2f4df4_3631_11ec_ae71_8c859039bca2row1_col7 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_fc2f4df4_3631_11ec_ae71_8c859039bca2row1_col8 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }</style><table id="T_fc2f4df4_3631_11ec_ae71_8c859039bca2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CAGR</th>        <th class="col_heading level0 col1" >Volatility</th>        <th class="col_heading level0 col2" >Sharpe</th>        <th class="col_heading level0 col3" >Sortino</th>        <th class="col_heading level0 col4" >Max DD</th>        <th class="col_heading level0 col5" >MAR</th>        <th class="col_heading level0 col6" >SWR</th>        <th class="col_heading level0 col7" >Skew</th>        <th class="col_heading level0 col8" >Kurtosis</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fc2f4df4_3631_11ec_ae71_8c859039bca2level0_row0" class="row_heading level0 row0" >Portfolio</th>
#                         <td id="T_fc2f4df4_3631_11ec_ae71_8c859039bca2row0_col0" class="data row0 col0" >137.7%</td>
#                         <td id="T_fc2f4df4_3631_11ec_ae71_8c859039bca2row0_col1" class="data row0 col1" >94.5%</td>
#                         <td id="T_fc2f4df4_3631_11ec_ae71_8c859039bca2row0_col2" class="data row0 col2" >1.47</td>
#                         <td id="T_fc2f4df4_3631_11ec_ae71_8c859039bca2row0_col3" class="data row0 col3" >1.54</td>
#                         <td id="T_fc2f4df4_3631_11ec_ae71_8c859039bca2row0_col4" class="data row0 col4" >-63%</td>
#                         <td id="T_fc2f4df4_3631_11ec_ae71_8c859039bca2row0_col5" class="data row0 col5" >2.19</td>
#                         <td id="T_fc2f4df4_3631_11ec_ae71_8c859039bca2row0_col6" class="data row0 col6" >103.9%</td>
#                         <td id="T_fc2f4df4_3631_11ec_ae71_8c859039bca2row0_col7" class="data row0 col7" >17.68</td>
#                         <td id="T_fc2f4df4_3631_11ec_ae71_8c859039bca2row0_col8" class="data row0 col8" >542.417</td>
#             </tr>
#             <tr>
#                         <th id="T_fc2f4df4_3631_11ec_ae71_8c859039bca2level0_row1" class="row_heading level0 row1" >Bench</th>
#                         <td id="T_fc2f4df4_3631_11ec_ae71_8c859039bca2row1_col0" class="data row1 col0" >94.8%</td>
#                         <td id="T_fc2f4df4_3631_11ec_ae71_8c859039bca2row1_col1" class="data row1 col1" >115.7%</td>
#                         <td id="T_fc2f4df4_3631_11ec_ae71_8c859039bca2row1_col2" class="data row1 col2" >1.22</td>
#                         <td id="T_fc2f4df4_3631_11ec_ae71_8c859039bca2row1_col3" class="data row1 col3" >1.90</td>
#                         <td id="T_fc2f4df4_3631_11ec_ae71_8c859039bca2row1_col4" class="data row1 col4" >-91%</td>
#                         <td id="T_fc2f4df4_3631_11ec_ae71_8c859039bca2row1_col5" class="data row1 col5" >1.04</td>
#                         <td id="T_fc2f4df4_3631_11ec_ae71_8c859039bca2row1_col6" class="data row1 col6" >53.4%</td>
#                         <td id="T_fc2f4df4_3631_11ec_ae71_8c859039bca2row1_col7" class="data row1 col7" >12.393</td>
#                         <td id="T_fc2f4df4_3631_11ec_ae71_8c859039bca2row1_col8" class="data row1 col8" >332.688</td>
#             </tr>
#     </tbody></table>

# %%
plot(res, "log") # "log" for log otherwise "" for lin
trade_analysis(df_tmp['signal'])
# Out:
# Number of Trades:  44.0
# Average holding time:  20.0
# Trades per Year:  6.2

# %% [markdown]
# #### Equity Curve for Cross Overs

# %%
df_tmp = cross_over(close, lookback_low = 10, lookback_high = 35, metric = 'data')
res = df_tmp[['Strategy_cum', 'Bench']]
strategy_evaluation(res, ['Bench'], 3000, freq = 'D')
# Out:
# <style  type="text/css" >
#     #T_04967a8a_3632_11ec_ae71_8c859039bca2 th {
#           font-size: 20px;
#           text-align: center;
#           font-weight: bold;
#           color: Black;
#           background-color: #f7f7f9;
#     }    #T_04967a8a_3632_11ec_ae71_8c859039bca2 td {
#           font-size: 20px;
#           text-align: center;
#     }    #T_04967a8a_3632_11ec_ae71_8c859039bca2row0_col0 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_04967a8a_3632_11ec_ae71_8c859039bca2row0_col1 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_04967a8a_3632_11ec_ae71_8c859039bca2row0_col2 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_04967a8a_3632_11ec_ae71_8c859039bca2row0_col3 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_04967a8a_3632_11ec_ae71_8c859039bca2row0_col4 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_04967a8a_3632_11ec_ae71_8c859039bca2row0_col5 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_04967a8a_3632_11ec_ae71_8c859039bca2row0_col6 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_04967a8a_3632_11ec_ae71_8c859039bca2row0_col7 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_04967a8a_3632_11ec_ae71_8c859039bca2row0_col8 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_04967a8a_3632_11ec_ae71_8c859039bca2row1_col0 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_04967a8a_3632_11ec_ae71_8c859039bca2row1_col1 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_04967a8a_3632_11ec_ae71_8c859039bca2row1_col2 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_04967a8a_3632_11ec_ae71_8c859039bca2row1_col3 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_04967a8a_3632_11ec_ae71_8c859039bca2row1_col4 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_04967a8a_3632_11ec_ae71_8c859039bca2row1_col5 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_04967a8a_3632_11ec_ae71_8c859039bca2row1_col6 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_04967a8a_3632_11ec_ae71_8c859039bca2row1_col7 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_04967a8a_3632_11ec_ae71_8c859039bca2row1_col8 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }</style><table id="T_04967a8a_3632_11ec_ae71_8c859039bca2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CAGR</th>        <th class="col_heading level0 col1" >Volatility</th>        <th class="col_heading level0 col2" >Sharpe</th>        <th class="col_heading level0 col3" >Sortino</th>        <th class="col_heading level0 col4" >Max DD</th>        <th class="col_heading level0 col5" >MAR</th>        <th class="col_heading level0 col6" >SWR</th>        <th class="col_heading level0 col7" >Skew</th>        <th class="col_heading level0 col8" >Kurtosis</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_04967a8a_3632_11ec_ae71_8c859039bca2level0_row0" class="row_heading level0 row0" >Portfolio</th>
#                         <td id="T_04967a8a_3632_11ec_ae71_8c859039bca2row0_col0" class="data row0 col0" >124.3%</td>
#                         <td id="T_04967a8a_3632_11ec_ae71_8c859039bca2row0_col1" class="data row0 col1" >98.5%</td>
#                         <td id="T_04967a8a_3632_11ec_ae71_8c859039bca2row0_col2" class="data row0 col2" >1.39</td>
#                         <td id="T_04967a8a_3632_11ec_ae71_8c859039bca2row0_col3" class="data row0 col3" >1.56</td>
#                         <td id="T_04967a8a_3632_11ec_ae71_8c859039bca2row0_col4" class="data row0 col4" >-84%</td>
#                         <td id="T_04967a8a_3632_11ec_ae71_8c859039bca2row0_col5" class="data row0 col5" >1.48</td>
#                         <td id="T_04967a8a_3632_11ec_ae71_8c859039bca2row0_col6" class="data row0 col6" >89.1%</td>
#                         <td id="T_04967a8a_3632_11ec_ae71_8c859039bca2row0_col7" class="data row0 col7" >16.517</td>
#                         <td id="T_04967a8a_3632_11ec_ae71_8c859039bca2row0_col8" class="data row0 col8" >495.806</td>
#             </tr>
#             <tr>
#                         <th id="T_04967a8a_3632_11ec_ae71_8c859039bca2level0_row1" class="row_heading level0 row1" >Bench</th>
#                         <td id="T_04967a8a_3632_11ec_ae71_8c859039bca2row1_col0" class="data row1 col0" >94.0%</td>
#                         <td id="T_04967a8a_3632_11ec_ae71_8c859039bca2row1_col1" class="data row1 col1" >115.9%</td>
#                         <td id="T_04967a8a_3632_11ec_ae71_8c859039bca2row1_col2" class="data row1 col2" >1.22</td>
#                         <td id="T_04967a8a_3632_11ec_ae71_8c859039bca2row1_col3" class="data row1 col3" >1.89</td>
#                         <td id="T_04967a8a_3632_11ec_ae71_8c859039bca2row1_col4" class="data row1 col4" >-91%</td>
#                         <td id="T_04967a8a_3632_11ec_ae71_8c859039bca2row1_col5" class="data row1 col5" >1.03</td>
#                         <td id="T_04967a8a_3632_11ec_ae71_8c859039bca2row1_col6" class="data row1 col6" >52.5%</td>
#                         <td id="T_04967a8a_3632_11ec_ae71_8c859039bca2row1_col7" class="data row1 col7" >12.323</td>
#                         <td id="T_04967a8a_3632_11ec_ae71_8c859039bca2row1_col8" class="data row1 col8" >330.93</td>
#             </tr>
#     </tbody></table>

# %%
plot(res, "log") # "log" for log otherwise "" for lin
trade_analysis(df_tmp['signal'])
# Out:
# Number of Trades:  30.0
# Average holding time:  38.0
# Trades per Year:  4.2
