# %%
import yfinance as yf 
import pandas as pd
from matplotlib import pylab as plt
import numpy as np
from datetime import datetime

#import selenium
#from selenium import webdriver
from time import sleep

import quandl

import seaborn as sns

import sys

from scipy.stats import norm

# %%
def port_eval(port, freq = 'D'):
    
    port = pd.DataFrame(port)
    port_ret = calc_port_ret(port)
    
    Roll_Max = port.cummax()
    Daily_Drawdown = port/Roll_Max - 1.0
    Max_Daily_Drawdown = Daily_Drawdown.cummin()
    
    Max_Daily_Drawdown = round(Max_Daily_Drawdown.tail(1),2)
    
    neg_ret = port_ret[port_ret<1].dropna()
    
    mean = np.mean(port_ret - 1)
    std = np.std(port_ret - 1)
    
    alpha = 0.05
    ES = round(alpha**-1 * norm.pdf(norm.ppf(alpha))*std - mean,3)
 
    
    if freq == 'D':
        cagr = round(port_ret.cumprod().tail(1)**(252/len(port_ret)) - 1,4)
        MAR = round(cagr/Max_Daily_Drawdown,2)
        vol = round(np.log(port_ret).std()*np.sqrt(252),3)
        sortino = round(np.log(neg_ret).std()*np.sqrt(252),2)
        sortino = round(cagr/sortino,2)
        sharpe = round(cagr/vol,2)
        
    elif freq == 'M':
        cagr = round(port_ret.cumprod().tail(1)**(12/len(port_ret)) - 1,4)
        MAR = round(cagr/Max_Daily_Drawdown,2)
        vol = round(np.log(port_ret).std()*np.sqrt(12),3)
        sortino = round(np.log(neg_ret).std()*np.sqrt(12),2)
        sortino = round(cagr/sortino,2)
        sharpe = round(cagr/vol,2)
        
        
    metrics = pd.DataFrame({'': [float(cagr.iloc[0]), float(vol.iloc[0]),
                                 float(sharpe.iloc[0]),float(sortino.iloc[0]),
                                 float(Max_Daily_Drawdown.iloc[0]), abs(float(MAR.iloc[0])),
                                 float(ES)]},
                   index=['CAGR', 'Volatility', 'Sharpe','Sortino', 'Max DD', 'MAR', 'ES'])
    

    
    return metrics

# %%
def calc_port_ret(port):
    port_ret = port/port.shift(1)
    port_ret = port_ret.fillna(1)
    
    return port_ret

# %%
def backtest_strategy(data, W, tol, rebalance_freq, data_names, leverage = 1):
    initial = 1
    asset = [i * initial for i in W]
    port = []
    port_W = [] 

    if sum(W) == 1:

        for i in range(len(data)):
            #port.append(initial)
            port_W.append([i / initial for i in asset])
            
            daily_ret = ((data.iloc[i]-1) * leverage) +1
            asset = asset * daily_ret #data.iloc[i]
            initial = sum(asset)
            port.append(initial)
            #Rebalancing by days
            if i%rebalance_freq == 0:
                for i in range(len(W)):
                    asset[i] = initial * W[i]
            
            #Rebalancing by deviation
            for i in range(len(asset)):
                if abs(asset[i]/initial - W[i])> tol:  
                      asset = [i * initial for i in W]
    
        port = pd.DataFrame(port)
        port.index = data.index
    
        result = pd.concat([port, data.cumprod()], axis =1)
        result.columns = ["Portfolio"] + data_names
        
        return (result, port_W)
        
    else:
        print("Weight not Equal to 1!")

# %%
def strategy_evaluation(result, data_names, freq = 'D'):
    metrics = pd.DataFrame([])
    
    if freq == 'D':
    
        for i in result.columns:
            metrics = pd.concat([metrics, port_eval(result[i], freq = 'D').transpose()], axis = 0)
        metrics.index = ["Portfolio"] + data_names
        
    elif freq == 'M':
        for i in result.columns:
            metrics = pd.concat([metrics, port_eval(result[i], freq = 'M').transpose()], axis = 0)
        metrics.index = ["Portfolio"] + data_names
        
    th_props = [
  ('font-size', '11px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'Black'),
  ('background-color', '#f7f7f9')
  ]


    # Set CSS properties for td elements in dataframe
    td_props = [
      ('font-size', '11px'), ('text-align', 'center')
      ]

    # Set table styles
    styles = [
      dict(selector="th", props=th_props),
      dict(selector="td", props=td_props)
      ]

    cm_neg_good = sns.diverging_palette(150, 10, s=80, l=70, n=len(metrics.columns), as_cmap=True)#sns.light_palette("green", as_cmap=True)
    cm_pos_good = sns.diverging_palette(10, 150, s=80, l=70, n=len(metrics.columns), as_cmap=True)

    metrics = (metrics.style
      .background_gradient(axis = 0 ,subset = ['CAGR','Max DD', 'Sharpe','MAR','Sortino' ],cmap=cm_pos_good)
      .background_gradient(axis = 0 ,subset = ['Volatility', 'ES'],cmap=cm_neg_good)
      #.set_caption('Performance Metrics')
      .format({'CAGR': "{:.2%}", 'Max DD': "{:.2%}", 'ES': "{:.2%}", 'Volatility': "{:.2%}"})
      .set_table_styles(styles))
    
    return metrics

# %%
def correlation_map(result):
    ret = calc_port_ret(result)
    ret = np.log(ret)
    corr = ret.corr()
    th_props = [
      ('font-size', '11px'),
      ('text-align', 'center'),
      ('font-weight', 'bold'),
      ('color', 'Black'),
      ('background-color', '#f7f7f9')
      ]

    
        # Set CSS properties for td elements in dataframe
    td_props = [
          ('font-size', '11px'), ('text-align', 'center')
          ]
    
        # Set table styles
    styles = [
          dict(selector="th", props=th_props),
          dict(selector="td", props=td_props)
          ]
    
    cm_neg_good = sns.diverging_palette(150, 10, s=80, l=70, n=len(corr.columns)**2, as_cmap=True)#sns.light_palette("green", as_cmap=True)
    cm_pos_good = sns.diverging_palette(10, 150, s=80, l=70, n=len(corr.columns)**2, as_cmap=True)
    
    
    corr = (corr.style
          .background_gradient(axis = 0 ,cmap=cm_neg_good)
          .set_table_styles(styles))
    
    return corr

# %% [markdown]
# # Backtesting Portfolio
#
# TODO:
# - collect data, dividned adjusted
# - leverage
# - start and end date

# %%
SP500_daily_tmp = yf.download("^SP500TR")
SHY_daily_tmp = yf.download("SHY")
TLT_daily_tmp =  yf.download("TLT")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
SP500_daily= pd.DataFrame(SP500_daily_tmp['Close'])
SHY_daily = pd.DataFrame(SHY_daily_tmp['Close'])
TLT_daily = pd.DataFrame(TLT_daily_tmp['Close'])

SP500_daily.columns = ['SP500']
SHY_daily.columns = ['SHY']
TLT_daily.columns = ['TLT']

# %%
# TYX 30 yr Treasury

TYX_tmp = yf.download('^TYX')

TYX_tmp.insert(1, "TYX", 0.0, True)
ttm = 30
price = 100.0
prev_price = 0
row = 0

for i in TYX_tmp['Close']:
    TYX_tmp['TYX'][row] = price
    curr_price = 1/(1+i/100)**ttm
    if prev_price == 0: 
        price_change = 0
    else: 
        price_change = (curr_price-prev_price)/prev_price
    imp_yield = (price*(1+i/100)-price)/252
    price = price*(1+price_change) + imp_yield
    prev_price = curr_price
    row += 1
    
TYX = pd.DataFrame(TYX_tmp['TYX'])
# Out:
# [*********************100%***********************]  1 of 1 completed
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
# TNX 10 year gov bond

TNX_tmp = yf.download('^TNX')

TNX_tmp.insert(1, "TNX", 0.0, True)
ttm = 10
price = 100.0
prev_price = 0
row = 0

for i in TNX_tmp['Close']:
    TNX_tmp['TNX'][row] = price
    curr_price = 1/(1+i/100)**ttm
    if prev_price == 0: 
        price_change = 0
    else: 
        price_change = (curr_price-prev_price)/prev_price
    imp_yield = (price*(1+i/100)-price)/252
    price = price*(1+price_change) + imp_yield
    prev_price = curr_price
    row += 1
    
TNX = pd.DataFrame(TNX_tmp['TNX'])
# Out:
# [*********************100%***********************]  1 of 1 completed
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
# FVX 5 year gov bond

FVX_tmp = yf.download('^FVX')

FVX_tmp.insert(1, "FVX", 0.0, True)
ttm = 5
price = 100.0
prev_price = 0
row = 0

for i in FVX_tmp['Close']:
    FVX_tmp['FVX'][row] = price
    curr_price = 1/(1+i/100)**ttm
    if prev_price == 0: 
        price_change = 0
    else: 
        price_change = (curr_price-prev_price)/prev_price
    imp_yield = (price*(1+i/100)-price)/252
    price = price*(1+price_change) + imp_yield
    prev_price = curr_price
    row += 1
    
FVX = pd.DataFrame(FVX_tmp['FVX'])
# Out:
# [*********************100%***********************]  1 of 1 completed
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
#Gold Import
Gold_tmp = quandl.get("LBMA/GOLD", authtoken="6rNSyTM5R4g7_B7XSyQW")

# %%
Gold = pd.DataFrame(Gold_tmp["USD (AM)"])
Gold_monthly = Gold.resample('M').last()
Gold.columns = ['Gold']
Gold_monthly.columns = ['Gold']

# %%
#Long Vol Import
long_vol_imp = pd.read_excel (r'https://www.eurekahedge.com/Indices/ExportIndexReturnsToExcel?IndexType=Eurekahedge&IndexId=640')

long_vol = long_vol_imp[3:]
long_vol.index= pd.to_datetime(long_vol_imp[3:]['Unnamed: 0'])
long_vol = pd.DataFrame(long_vol['Unnamed: 2'])
long_vol.columns = ["Long Vol"]

# %%
#Monthly SP500
SP500_monthly = quandl.get("MULTPL/SP500_REAL_PRICE_MONTH", authtoken="6rNSyTM5R4g7_B7XSyQW")
SP500_monthly.columns = ['SP500']

# %%
####DAILY DATA#########

data = pd.concat([SP500_daily,Gold, TLT_daily], axis = 1) #asset_2, asset_4
data = data.ffill()
data = data.dropna()
data = data/data.shift(1)
data = data.fillna(1)

# %%
######## Monthly Data

data_tmp = pd.concat([SP500_monthly, long_vol], axis = 1)
data_tmp = data_tmp.ffill()
data_tmp = data_tmp.dropna()
monthly_data = data_tmp/data_tmp.shift()
monthly_data = monthly_data.fillna(1)
monthly_data = monthly_data.ffill()
monthly_data = monthly_data.dropna()

# %%
rebalance_freq = 252/4
tol = 0.1
W = [1/2, 1/2, 0]

data_names = data.columns.tolist()


result, weights = backtest_strategy(data, W, tol, rebalance_freq, data_names, leverage = 1)

# %%
sns.set_style("darkgrid");
plt.figure(figsize=(20,10));
for i in result.columns:
    plt.plot(np.log(result[i]), label = i);

start = datetime.date(result.index.min());
end = datetime.date(result.index.max());
plt.legend(loc=2, prop={'size': 20});
plt.title('Backtest from ' + str(start) + ' to ' + str(end), fontsize=20)
plt.ylabel('Leg Return', fontsize=18)
plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)

strategy_evaluation(result, data_names, freq = 'D')
# Out:
# <style  type="text/css" >
#     #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2 th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: Black;
#           background-color: #f7f7f9;
#     }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2 td {
#           font-size: 11px;
#           text-align: center;
#     }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row0_col0 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row0_col1 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row0_col2 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row0_col3 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row0_col4 {
#             background-color:  #8bd5b6;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row0_col5 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row0_col6 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row1_col0 {
#             background-color:  #92d7ba;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row1_col1 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row1_col2 {
#             background-color:  #fad5d7;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row1_col3 {
#             background-color:  #f7b8bb;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row1_col4 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row1_col5 {
#             background-color:  #f5acaf;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row1_col6 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row2_col0 {
#             background-color:  #6bc9a1;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row2_col1 {
#             background-color:  #f8c2c5;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row2_col2 {
#             background-color:  #e4f5ee;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row2_col3 {
#             background-color:  #dcf2e9;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row2_col4 {
#             background-color:  #fad4d6;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row2_col5 {
#             background-color:  #fce8e8;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row2_col6 {
#             background-color:  #f7bec1;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row3_col0 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row3_col1 {
#             background-color:  #6dcaa3;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row3_col2 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row3_col3 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row3_col4 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row3_col5 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row3_col6 {
#             background-color:  #76cda9;
#             color:  #000000;
#         }</style><table id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >CAGR</th>        <th class="col_heading level0 col1" >Volatility</th>        <th class="col_heading level0 col2" >Sharpe</th>        <th class="col_heading level0 col3" >Sortino</th>        <th class="col_heading level0 col4" >Max DD</th>        <th class="col_heading level0 col5" >MAR</th>        <th class="col_heading level0 col6" >ES</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2level0_row0" class="row_heading level0 row0" >Portfolio</th>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row0_col0" class="data row0 col0" >10.84%</td>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row0_col1" class="data row0 col1" >13.20%</td>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row0_col2" class="data row0 col2" >0.82</td>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row0_col3" class="data row0 col3" >1.08</td>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row0_col4" class="data row0 col4" >-33.00%</td>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row0_col5" class="data row0 col5" >0.33</td>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row0_col6" class="data row0 col6" >1.70%</td>
#             </tr>
#             <tr>
#                         <th id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2level0_row1" class="row_heading level0 row1" >SP500</th>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row1_col0" class="data row1 col0" >9.43%</td>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row1_col1" class="data row1 col1" >19.40%</td>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row1_col2" class="data row1 col2" >0.49</td>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row1_col3" class="data row1 col3" >0.55</td>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row1_col4" class="data row1 col4" >-55.00%</td>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row1_col5" class="data row1 col5" >0.17</td>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row1_col6" class="data row1 col6" >2.50%</td>
#             </tr>
#             <tr>
#                         <th id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2level0_row2" class="row_heading level0 row2" >Gold</th>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row2_col0" class="data row2 col0" >10.24%</td>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row2_col1" class="data row2 col1" >17.70%</td>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row2_col2" class="data row2 col2" >0.58</td>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row2_col3" class="data row2 col3" >0.79</td>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row2_col4" class="data row2 col4" >-45.00%</td>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row2_col5" class="data row2 col5" >0.23</td>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row2_col6" class="data row2 col6" >2.30%</td>
#             </tr>
#             <tr>
#                         <th id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2level0_row3" class="row_heading level0 row3" >TLT</th>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row3_col0" class="data row3 col0" >4.01%</td>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row3_col1" class="data row3 col1" >13.80%</td>
#                         <td id="T_80ccc8e2_cc53_11ea_aa2d_8c859039bca2row3_col2" class="data row3 col2" >

# %%
correlation_map(result)
# Out:
# <style  type="text/css" >
#     #T_669bcf90_cc53_11ea_aa2d_8c859039bca2 th {
#           font-size: 11px;
#           text-align: center;
#           font-weight: bold;
#           color: Black;
#           background-color: #f7f7f9;
#     }    #T_669bcf90_cc53_11ea_aa2d_8c859039bca2 td {
#           font-size: 11px;
#           text-align: center;
#     }    #T_669bcf90_cc53_11ea_aa2d_8c859039bca2row0_col0 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_669bcf90_cc53_11ea_aa2d_8c859039bca2row0_col1 {
#             background-color:  #f9d1d3;
#             color:  #000000;
#         }    #T_669bcf90_cc53_11ea_aa2d_8c859039bca2row0_col2 {
#             background-color:  #f8c3c5;
#             color:  #000000;
#         }    #T_669bcf90_cc53_11ea_aa2d_8c859039bca2row0_col3 {
#             background-color:  #e6f6ef;
#             color:  #000000;
#         }    #T_669bcf90_cc53_11ea_aa2d_8c859039bca2row1_col0 {
#             background-color:  #c0e8d7;
#             color:  #000000;
#         }    #T_669bcf90_cc53_11ea_aa2d_8c859039bca2row1_col1 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_669bcf90_cc53_11ea_aa2d_8c859039bca2row1_col2 {
#             background-color:  #54c193;
#             color:  #000000;
#         }    #T_669bcf90_cc53_11ea_aa2d_8c859039bca2row1_col3 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_669bcf90_cc53_11ea_aa2d_8c859039bca2row2_col0 {
#             background-color:  #fad4d6;
#             color:  #000000;
#         }    #T_669bcf90_cc53_11ea_aa2d_8c859039bca2row2_col1 {
#             background-color:  #b3e3cf;
#             color:  #000000;
#         }    #T_669bcf90_cc53_11ea_aa2d_8c859039bca2row2_col2 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_669bcf90_cc53_11ea_aa2d_8c859039bca2row2_col3 {
#             background-color:  #aee2cc;
#             color:  #000000;
#         }    #T_669bcf90_cc53_11ea_aa2d_8c859039bca2row3_col0 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_669bcf90_cc53_11ea_aa2d_8c859039bca2row3_col1 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_669bcf90_cc53_11ea_aa2d_8c859039bca2row3_col2 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_669bcf90_cc53_11ea_aa2d_8c859039bca2row3_col3 {
#             background-color:  #f29094;
#             color:  #000000;
#         }</style><table id="T_669bcf90_cc53_11ea_aa2d_8c859039bca2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Portfolio</th>        <th class="col_heading level0 col1" >SP500</th>        <th class="col_heading level0 col2" >Gold</th>        <th class="col_heading level0 col3" >TLT</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_669bcf90_cc53_11ea_aa2d_8c859039bca2level0_row0" class="row_heading level0 row0" >Portfolio</th>
#                         <td id="T_669bcf90_cc53_11ea_aa2d_8c859039bca2row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_669bcf90_cc53_11ea_aa2d_8c859039bca2row0_col1" class="data row0 col1" >0.495371</td>
#                         <td id="T_669bcf90_cc53_11ea_aa2d_8c859039bca2row0_col2" class="data row0 col2" >0.717435</td>
#                         <td id="T_669bcf90_cc53_11ea_aa2d_8c859039bca2row0_col3" class="data row0 col3" >0.230535</td>
#             </tr>
#             <tr>
#                         <th id="T_669bcf90_cc53_11ea_aa2d_8c859039bca2level0_row1" class="row_heading level0 row1" >SP500</th>
#                         <td id="T_669bcf90_cc53_11ea_aa2d_8c859039bca2row1_col0" class="data row1 col0" >0.495371</td>
#                         <td id="T_669bcf90_cc53_11ea_aa2d_8c859039bca2row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_669bcf90_cc53_11ea_aa2d_8c859039bca2row1_col2" class="data row1 col2" >0.0141758</td>
#                         <td id="T_669bcf90_cc53_11ea_aa2d_8c859039bca2row1_col3" class="data row1 col3" >-0.425179</td>
#             </tr>
#             <tr>
#                         <th id="T_669bcf90_cc53_11ea_aa2d_8c859039bca2level0_row2" class="row_heading level0 row2" >Gold</th>
#                         <td id="T_669bcf90_cc53_11ea_aa2d_8c859039bca2row2_col0" class="data row2 col0" >0.717435</td>
#                         <td id="T_669bcf90_cc53_11ea_aa2d_8c859039bca2row2_col1" class="data row2 col1" >0.0141758</td>
#                         <td id="T_669bcf90_cc53_11ea_aa2d_8c859039bca2row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_669bcf90_cc53_11ea_aa2d_8c859039bca2row2_col3" class="data row2 col3" >-0.00870778</td>
#             </tr>
#             <tr>
#                         <th id="T_669bcf90_cc53_11ea_aa2d_8c859039bca2level0_row3" class="row_heading level0 row3" >TLT</th>
#                         <td id="T_669bcf90_cc53_11ea_aa2d_8c859039bca2row3_col0" class="data row3 col0" >0.230535</td>
#                         <td id="T_669bcf90_cc53_11ea_aa2d_8c859039bca2row3_col1" class="data row3 col1" >-0.425179</td>
#                         <td id="T_669bcf90_cc53_11ea_aa2d_8c859039bca2row3_col2" class="data row3 col2" >-0.00870778</td>
#                         <td id="T_669bcf90_cc53_11ea_aa2d_8c859039bca2row3_col3" class="data row3 col3" >1</td>
#             </tr>
#     </tbody></table>
