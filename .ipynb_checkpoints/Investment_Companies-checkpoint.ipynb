# %% [markdown]
# # Investment Comp Screener

# %%
import yfinance as yf 
import pandas as pd
from matplotlib import pylab as plt
import numpy as np
from datetime import datetime
import math
from time import sleep
import quandl
import seaborn as sns
import sys
from scipy.stats import norm
import os
import glob
import re
import seaborn as sns

from statsmodels.distributions.empirical_distribution import ECDF

# %%
def calc_ecdf(data):
    #low is good
    ecdf= ECDF(data)
    current_perc = ecdf(data[-1])
    
    return(current_perc)

# %% [markdown]
# ## Data Import

# %%
path = "../../../R Projects/Investment/Stocks/Holding_Companies/data"
arr = [x for x in os.listdir(path) if x.endswith(".csv")]

# %%
for f in arr:
    print(f)
# Out:
# 2020-08-02_trac b_pris_historik.csv
# 2020-08-02_lund b_pris_historik.csv
# 2020-08-02_hav b_pris_historik.csv
# 2020-08-02_ores_pris_historik.csv
# 2020-08-02_indu c_pris_historik.csv
# 2020-08-02_svol b_pris_historik.csv
# 2020-08-02_bure_pris_historik.csv
# 2020-08-02_cred a_pris_historik.csv
# 2020-08-02_inve b_pris_historik.csv
# 2020-08-02_kinv b_pris_historik.csv
# 2020-08-02_vnv_pris_historik.csv
# 2020-08-02_naxs_pris_historik.csv
# 2020-08-02_lato b_pris_historik.csv

# %%
for k in arr:
    if "trac" in k:
        traction = pd.read_csv(os.path.join(path,k))
    if "lund" in k:
        lundbergs = pd.read_csv(os.path.join(path,k))
    if "hav" in k:
        havsfrun = pd.read_csv(os.path.join(path,k))
    if "ores" in k:
        oresund = pd.read_csv(os.path.join(path,k))
    if "indu" in k:
        industri = pd.read_csv(os.path.join(path,k))
    if "svol" in k:
        svolder = pd.read_csv(os.path.join(path,k))
    if "bure" in k:
        bure = pd.read_csv(os.path.join(path,k))
    if "cred" in k:
        creades = pd.read_csv(os.path.join(path,k))
    if "inve" in k:
        investor = pd.read_csv(os.path.join(path,k))
    if "kinv" in k:
        kinnevik = pd.read_csv(os.path.join(path,k))
    if "vnv" in k:
        vnv = pd.read_csv(os.path.join(path,k))
    if "naxs" in k:
        naxs = pd.read_csv(os.path.join(path,k))
    if "lato" in k:
        latour = pd.read_csv(os.path.join(path,k))

# %% [markdown]
# ## Calculate Metrics

# %%
companies = [traction, lundbergs, havsfrun, oresund, industri,
             svolder, bure, creades, investor, kinnevik, vnv, naxs,latour]

companies_names = ['Traction', 'Lundbergsföretagen', 'Havsfrun Investment', 'Öresund', 'Industrivärden',
             'Svolder', 'Bure', 'Creades', 'Investor', 'Kinnevik', 'VNV Global', 'NAXS','Latour']

for comp in companies:
    
    comp['DATUM'] = pd.to_datetime(comp['DATUM'])
    comp.set_index(['DATUM'], inplace=True, drop=True)
    comp['R/P']=comp['PRIS']/comp['BERÄKNAT_SUBSTANSVÄRDE'] - 1

# %%
#high DSSP and HIDI is good

AVG_DISC = pd.DataFrame(latour['PRIS'].copy())
AVG_DISC['PRIS'] = 0
AVG_DISC.columns = ['AVG_DISC']

for comp in companies:

    AVG_DISC['AVG_DISC'] = AVG_DISC['AVG_DISC'] + comp['R/P']

AVG_DISC = AVG_DISC/len(companies)

for comp in companies:
    comp['SPREAD'] = comp['R/P'] - AVG_DISC['AVG_DISC']
    comp['DSSP'] = -comp['SPREAD'].rolling(252*3).apply(lambda x: calc_ecdf(x),raw=False) + 1
    comp['HIDI'] = -comp['R/P'].rolling(252*3).apply(lambda x: calc_ecdf(x),raw=False) + 1
    comp['MOM'] = (comp['PRIS'].pct_change(252) + comp['PRIS'].pct_change(126) + comp['PRIS'].pct_change(63))/3
    comp['NAV MOM'] = (comp['BERÄKNAT_SUBSTANSVÄRDE'].pct_change(252) + comp['BERÄKNAT_SUBSTANSVÄRDE'].pct_change(126) + comp['BERÄKNAT_SUBSTANSVÄRDE'].pct_change(63))/3

# %%
INV_COMP = None

for comp in companies:
    
    INV_COMP = pd.concat([INV_COMP, comp.tail(1)], axis = 0)

INV_COMP['Company'] = companies_names
INV_COMP.set_index(['Company'], inplace=True, drop=True)

INV_COMP['Company'] = companies_names

# %%
INV_COMP['VRANK'] = (INV_COMP['R/P'].rank() + INV_COMP['DSSP'].rank(ascending = False) +
 INV_COMP['HIDI'].rank(ascending = False)).rank()

INV_COMP['MRANK'] = (INV_COMP['MOM'].rank(ascending = False)+INV_COMP['NAV MOM'].rank(ascending = False)).rank()

INV_COMP['COMB RANK'] = (INV_COMP['VRANK'] + INV_COMP['MRANK']).rank()


compact = ['R/P', 'DSSP', 'HIDI', 'MOM', 'NAV MOM', 'VRANK', 'MRANK', 'COMB RANK']

INV_COMP = INV_COMP[compact]

# %% [markdown]
# ## Display Results

# %%
th_props = [
  ('font-size', '16px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'Black'),
  ('background-color', '#f7f7f9')
  ]


# Set CSS properties for td elements in dataframe
td_props = [('font-size', '16px'), ('text-align', 'center')]

# Set table styles
styles = [
    dict(selector="th", props=th_props),
    dict(selector="td", props=td_props)
]

cm_low_good = sns.diverging_palette(150, 10, s=80, l=70, n=len(INV_COMP.columns), as_cmap=True)#sns.light_palette("green", as_cmap=True)
cm_high_good = sns.diverging_palette(10, 150, s=80, l=70, n=len(INV_COMP.columns), as_cmap=True)

INV_COMP_VIEW = (INV_COMP.style
    .background_gradient(axis = 0 ,subset = ['MOM', 'NAV MOM', 'DSSP', 'HIDI'],cmap=cm_high_good)
    .background_gradient(axis = 0 ,subset = ['R/P','VRANK', 'MRANK','COMB RANK'],cmap=cm_low_good)
    #.set_caption('Performance Metrics')
    .format({'R/P': "{:.1%}", 'DSSP': "{:.0%}", 'HIDI': "{:.0%}", 'MOM':"{:.1%}", 'NAV MOM': "{:.1%}",
            'Sortino': "{:.2f}", 'MAR': "{:.2f}"})
    .set_table_styles(styles))

# %%
INV_COMP_VIEW
# Out:
# <style  type="text/css" >
#     #T_fccc7322_edb7_11ea_aa62_8c859039bca2 th {
#           font-size: 16px;
#           text-align: center;
#           font-weight: bold;
#           color: Black;
#           background-color: #f7f7f9;
#     }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2 td {
#           font-size: 16px;
#           text-align: center;
#     }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row0_col0 {
#             background-color:  #d9f1e7;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row0_col1 {
#             background-color:  #94d8bb;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row0_col2 {
#             background-color:  #f7c0c2;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row0_col3 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row0_col4 {
#             background-color:  #f7bdc0;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row0_col5 {
#             background-color:  #fce8e9;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row0_col6 {
#             background-color:  #f39fa2;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row0_col7 {
#             background-color:  #f39fa2;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row1_col0 {
#             background-color:  #fce3e4;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row1_col1 {
#             background-color:  #b4e4d0;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row1_col2 {
#             background-color:  #f5b0b2;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row1_col3 {
#             background-color:  #f5a9ac;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row1_col4 {
#             background-color:  #fce5e6;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row1_col5 {
#             background-color:  #f8c8ca;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row1_col6 {
#             background-color:  #fbddde;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row1_col7 {
#             background-color:  #f6b6b9;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row2_col0 {
#             background-color:  #f2969a;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row2_col1 {
#             background-color:  #f29498;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row2_col2 {
#             background-color:  #f29498;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row2_col3 {
#             background-color:  #f2969a;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row2_col4 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row2_col5 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row2_col6 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row2_col7 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row3_col0 {
#             background-color:  #ecf8f3;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row3_col1 {
#             background-color:  #63c69c;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row3_col2 {
#             background-color:  #fce6e7;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row3_col3 {
#             background-color:  #f3999d;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row3_col4 {
#             background-color:  #f8c1c3;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row3_col5 {
#             background-color:  #c2e9d8;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row3_col6 {
#             background-color:  #f7bdc0;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row3_col7 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row4_col0 {
#             background-color:  #a0dcc3;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row4_col1 {
#             background-color:  #51c091;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row4_col2 {
#             background-color:  #fce7e8;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row4_col3 {
#             background-color:  #f4a5a8;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row4_col4 {
#             background-color:  #fbdfe0;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row4_col5 {
#             background-color:  #87d3b3;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row4_col6 {
#             background-color:  #f9cdcf;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row4_col7 {
#             background-color:  #d8f1e6;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row5_col0 {
#             background-color:  #bee7d6;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row5_col1 {
#             background-color:  #51c091;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row5_col2 {
#             background-color:  #fad5d7;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row5_col3 {
#             background-color:  #f9cdcf;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row5_col4 {
#             background-color:  #d9f1e7;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row5_col5 {
#             background-color:  #a4dec5;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row5_col6 {
#             background-color:  #93d8bb;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row5_col7 {
#             background-color:  #69c9a0;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row6_col0 {
#             background-color:  #f8c1c3;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row6_col1 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row6_col2 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row6_col3 {
#             background-color:  #bbe6d4;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row6_col4 {
#             background-color:  #dcf2e9;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row6_col5 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row6_col6 {
#             background-color:  #93d8bb;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row6_col7 {
#             background-color:  #fad5d6;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row7_col0 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_fccc7322_edb7_11ea_aa62_8c859039bca2row7_col1 {
#             background-col
