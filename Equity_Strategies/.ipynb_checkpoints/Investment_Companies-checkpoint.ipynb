# %% [markdown]
# # Investment Comp Screener
#
# Premia/ Discount (P/D)
#
# Sector 3 year Z Score (S3ZS)
#
# Company 3 year Z Score (C3ZS)

# %%
import yfinance as yf 
import pandas as pd
from matplotlib import pylab as plt
import numpy as np
from datetime import datetime
import math
from time import sleep
import quandl
import seaborn as sns
import sys
from scipy.stats import norm
import os
import glob
import re
import seaborn as sns

from statsmodels.distributions.empirical_distribution import ECDF

# %%
def calc_ecdf(data):
    #low is good
    ecdf= ECDF(data)
    current_perc = ecdf(data[-1])
    
    return(current_perc)

# %%
def color_negative_red(value):
    """
      Colors elements in a dateframe
      green if positive and red if
      negative. Does not color NaN
      values.
      """

    if value < 0:
        color = 'red'
    elif value > 0:
        color = 'green'
    else:
        color = 'black'

    return 'color: %s' % color

# %%
def Z_score(data):
    # not including the current observation
    std = data.iloc[:-1].std()
    mean = data.iloc[:-1].mean()
    Z = (data[-1:] - mean)/std
    return Z

# %%
def mod_Z_score(data):
    median = np.median(data.iloc[:-1])
    deviation_from_med = np.array(data.iloc[:-1]) - median
    MAD = np.median(np.abs(deviation_from_med))
    mod_Z = (data[-1:] - median)/(MAD * 1.4826)
    return mod_Z

# %%
def signal(rank):
    if rank <= 2: return 1
    if rank <= 4: return 0.5
    if rank <= 7: return 0
    if rank <= 9: return -0.5
    if rank > 9: return -1

# %% [markdown]
# ## Data Import

# %%
path = "holding_companies_data"
arr = [x for x in os.listdir(path) if x.endswith(".csv")]

# %%
for f in arr:
    print(f)
# Out:
# 2021-03-30_bure_pris_historik.csv
# 2021-03-30_vnv_pris_historik.csv
# 2021-03-30_indu c_pris_historik.csv
# 2021-03-30_svol b_pris_historik.csv
# 2021-03-30_lund b_pris_historik.csv
# 2021-03-30_ores_pris_historik.csv
# 2021-03-30_trac b_pris_historik.csv
# 2021-03-30_kinv b_pris_historik.csv
# 2021-03-30_lato b_pris_historik.csv
# 2021-03-30_cred a_pris_historik.csv
# 2021-03-30_inve b_pris_historik.csv

# %%
for k in arr:
    if "trac" in k:
        traction = pd.read_csv(os.path.join(path,k))
    if "lund" in k:
        lundbergs = pd.read_csv(os.path.join(path,k))
    if "hav" in k:
        havsfrun = pd.read_csv(os.path.join(path,k))
    if "ores" in k:
        oresund = pd.read_csv(os.path.join(path,k))
    if "indu" in k:
        industri = pd.read_csv(os.path.join(path,k))
    if "svol" in k:
        svolder = pd.read_csv(os.path.join(path,k))
    if "bure" in k:
        bure = pd.read_csv(os.path.join(path,k))
    if "cred" in k:
        creades = pd.read_csv(os.path.join(path,k))
    if "inve" in k:
        investor = pd.read_csv(os.path.join(path,k))
    if "kinv" in k:
        kinnevik = pd.read_csv(os.path.join(path,k))
    if "vnv" in k:
        vnv = pd.read_csv(os.path.join(path,k))
    if "naxs" in k:
        naxs = pd.read_csv(os.path.join(path,k))
    if "lato" in k:
        latour = pd.read_csv(os.path.join(path,k))

# %% [markdown]
# ## Calculate Metrics

# %%
look_back = 3*252 #3 years
ST_look_back = 5



companies = [traction, lundbergs, oresund, industri,
             svolder, bure, creades, investor, kinnevik, vnv,latour]

companies_names = ['Traction', 'Lundbergsföretagen', 'Öresund', 'Industrivärden',
             'Svolder', 'Bure', 'Creades', 'Investor', 'Kinnevik', 'VNV Global','Latour']


for comp in companies:
    
    comp['DATUM'] = pd.to_datetime(comp['DATUM'])
    comp.set_index(['DATUM'], inplace=True, drop=True)
    comp['P/D']=comp['PRIS']/comp['BERÄKNAT_SUBSTANSVÄRDE'] - 1

# %%
# for comp in companies:
#     comp['ADJ Pris'] = comp['Pris']
#     comp['ADJ NAV'] = comp['BERÄKNAT_SUBSTANSVÄRDE']

# #KINNEVIK ZALANDO 
# ZALANDO_DATE= companies[8].index.searchsorted(datetime(2021, 3, 23))
# ZALANDO_AMOUNT= 20
# companies[8]['ADJ PRIS'].iloc[ZALANDO_DATE:] = companies[8]['ADJ PRIS'].iloc[start:] + ZALANDO AMOUNT
# companies[8]['ADJ NAV'].iloc[ZALANDO_DATE:] = companies[8]['ADJ NAV'].iloc[start:] + ZALANDO AMOUNT

# %%
#high DSSP and HIDI is good

AVG_DISC = pd.DataFrame(latour['PRIS'].copy())
AVG_DISC['PRIS'] = 0
AVG_DISC.columns = ['AVG_DISC']

for comp in companies:

    AVG_DISC['AVG_DISC'] = AVG_DISC['AVG_DISC'] + comp['P/D']

AVG_DISC = AVG_DISC/len(companies)

for comp in companies:
    comp['SPREAD'] = comp['P/D'] - AVG_DISC['AVG_DISC']
    #comp['DSSP'] = -comp['SPREAD'].rolling(look_back).apply(lambda x: calc_ecdf(x),raw=False) + 1
    comp['S3ZS'] = -comp['SPREAD'].rolling(look_back).apply(lambda x: Z_score(x),raw=False) 
    #comp['HIDI'] = -comp['R/P'].rolling(look_back).apply(lambda x: calc_ecdf(x),raw=False) + 1
    comp['C3ZS'] = -comp['P/D'].rolling(look_back).apply(lambda x: Z_score(x),raw=False)
    comp['MOM'] = (comp['PRIS'].pct_change(252) + comp['PRIS'].pct_change(126) + comp['PRIS'].pct_change(63))/3
    comp['NAV MOM'] = (comp['BERÄKNAT_SUBSTANSVÄRDE'].pct_change(252) + comp['BERÄKNAT_SUBSTANSVÄRDE'].pct_change(126) + comp['BERÄKNAT_SUBSTANSVÄRDE'].pct_change(63))/3
    comp['ST'] = comp['PRIS'].pct_change(ST_look_back)

# %%
INV_COMP = None

for comp in companies:
    
    INV_COMP = pd.concat([INV_COMP, comp.tail(1)], axis = 0)

INV_COMP['Company'] = companies_names
INV_COMP.set_index(['Company'], inplace=True, drop=True)

INV_COMP['P/D']=-INV_COMP['P/D']

# %%
INV_COMP['VRANK'] = (INV_COMP['P/D'].rank(ascending = False) + INV_COMP['S3ZS'].rank(ascending = False) +
 INV_COMP['C3ZS'].rank(ascending = False)).rank()



INV_COMP['MRANK'] = (INV_COMP['MOM'].rank(ascending = False)+INV_COMP['NAV MOM'].rank(ascending = False)).rank()

INV_COMP['CRANK'] = (INV_COMP['VRANK'] + INV_COMP['MRANK']).rank()
    
INV_COMP['SIGNAL'] = INV_COMP.apply(lambda x: signal(x['CRANK']), axis=1)

INV_COMP.at['Traction', 'DEFWEIGHT'] = 0.05
INV_COMP.at['Lundbergsföretagen', 'DEFWEIGHT'] = 0.1
INV_COMP.at['Öresund', 'DEFWEIGHT'] = 0.05
INV_COMP.at['Industrivärden', 'DEFWEIGHT'] = 0.115
INV_COMP.at['Svolder', 'DEFWEIGHT'] = 0.05
INV_COMP.at['Bure', 'DEFWEIGHT'] = 0.05
INV_COMP.at['Creades', 'DEFWEIGHT'] = 0.05
INV_COMP.at['Investor', 'DEFWEIGHT'] = 0.25
INV_COMP.at['Kinnevik', 'DEFWEIGHT'] = 0.115
INV_COMP.at['VNV Global', 'DEFWEIGHT'] = 0.05
INV_COMP.at['Latour', 'DEFWEIGHT'] = 0.12

weight_factor = 0.5

INV_COMP['TARGET'] = INV_COMP['DEFWEIGHT']+INV_COMP['DEFWEIGHT']*INV_COMP['SIGNAL']*weight_factor

compact = ['P/D', 'C3ZS', 'S3ZS', 'MOM', 'NAV MOM', 'VRANK', 'MRANK', 'CRANK', 'ST','DEFWEIGHT', 'SIGNAL', 'TARGET']

INV_COMP = INV_COMP[compact]

# %%
average = pd.DataFrame(INV_COMP.mean(axis = 0)).transpose()
average.index = ['Average'] 
INV_COMP = pd.concat([INV_COMP, average], axis = 0)

# %% [markdown]
# ## Display Results

# %%
th_props = [
  ('font-size', '16px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'Black'),
  ('background-color', '#f7f7f9')
  ]


# Set CSS properties for td elements in dataframe
td_props = [('font-size', '16px'), ('text-align', 'center')]

# Set table styles
styles = [
    dict(selector="th", props=th_props),
    dict(selector="td", props=td_props)
]

cm_low_good = sns.diverging_palette(150, 10, s=80, l=70, n=len(INV_COMP.columns), as_cmap=True)#sns.light_palette("green", as_cmap=True)
cm_high_good = sns.diverging_palette(10, 150, s=80, l=70, n=len(INV_COMP.columns), as_cmap=True)

INV_COMP_VIEW = (INV_COMP.style
    .applymap(color_negative_red, subset=['P/D', 'MOM', 'NAV MOM'])
    .background_gradient(axis = 0 ,subset = ['S3ZS', 'C3ZS'],cmap=cm_high_good)
    .background_gradient(axis = 0 ,subset = ['VRANK', 'MRANK','CRANK', 'ST'],cmap=cm_low_good)
    #.set_caption('Performance Metrics')
    .format({'P/D': "{:.1%}", 'S3ZS': "{:.2f}", 'C3ZS': "{:.2f}", 'MOM':"{:.1%}", 'NAV MOM': "{:.1%}",
            'Sortino': "{:.2f}", 'MAR': "{:.2f}", 'VRANK': "{:.0f}", 'MRANK': "{:.0f}", 'CRANK': "{:.0f}",
             'ST':"{:.1%}",'DEFWEIGHT':"{:.1%}",'SIGNAL': "{:.1f}" ,'TARGET':"{:.1%}"})
    .set_table_styles(styles))

# %%
INV_COMP_VIEW
# Out:
# <style  type="text/css" >
#     #T_60395ef6_acbd_11eb_ab43_8c859039bca2 th {
#           font-size: 16px;
#           text-align: center;
#           font-weight: bold;
#           color: Black;
#           background-color: #f7f7f9;
#     }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2 td {
#           font-size: 16px;
#           text-align: center;
#     }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row0_col0 {
#             color:  green;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row0_col1 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row0_col2 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row0_col3 {
#             color:  green;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row0_col4 {
#             color:  green;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row0_col5 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row0_col6 {
#             background-color:  #fbdadb;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row0_col7 {
#             background-color:  #82d1b0;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row0_col8 {
#             background-color:  #c4eada;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row1_col0 {
#             color:  green;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row1_col1 {
#             background-color:  #56c194;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row1_col2 {
#             background-color:  #57c295;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row1_col3 {
#             color:  green;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row1_col4 {
#             color:  green;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row1_col5 {
#             background-color:  #6ecaa3;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row1_col6 {
#             background-color:  #f4a2a5;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row1_col7 {
#             background-color:  #fbdddf;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row1_col8 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row2_col0 {
#             color:  red;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row2_col1 {
#             background-color:  #bee7d6;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row2_col2 {
#             background-color:  #a0dcc3;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row2_col3 {
#             color:  green;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row2_col4 {
#             color:  green;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row2_col5 {
#             background-color:  #b1e3cd;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row2_col6 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row2_col7 {
#             background-color:  #f9cacc;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row2_col8 {
#             background-color:  #f7bcbe;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row3_col0 {
#             color:  green;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row3_col1 {
#             background-color:  #f6b0b3;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row3_col2 {
#             background-color:  #b6e4d1;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row3_col3 {
#             color:  green;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row3_col4 {
#             color:  green;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row3_col5 {
#             background-color:  #d3efe3;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row3_col6 {
#             background-color:  #6ecaa3;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row3_col7 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row3_col8 {
#             background-color:  #97d9bd;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row4_col0 {
#             color:  red;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row4_col1 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row4_col2 {
#             background-color:  #f5aeb1;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row4_col3 {
#             color:  green;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row4_col4 {
#             color:  green;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row4_col5 {
#             background-color:  #f5abae;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row4_col6 {
#             background-color:  #4ebf8f;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row4_col7 {
#             background-color:  #c8ebdc;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row4_col8 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row5_col0 {
#             color:  red;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row5_col1 {
#             background-color:  #f7bcbf;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row5_col2 {
#             background-color:  #f3989b;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row5_col3 {
#             color:  green;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row5_col4 {
#             color:  green;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row5_col5 {
#             background-color:  #f5abae;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row5_col6 {
#             background-color:  #f7bdc0;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row5_col7 {
#             background-color:  #f29094;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row5_col8 {
#             background-color:  #d4efe4;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row6_col0 {
#             color:  red;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row6_col1 {
#             background-color:  #9cdbc0;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row6_col2 {
#             background-color:  #d9f1e7;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row6_col3 {
#             color:  green;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row6_col4 {
#             color:  green;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row6_col5 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row6_col6 {
#             background-color:  #b1e3cd;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row6_col7 {
#             background-color:  #a5dec6;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row6_col8 {
#             background-color:  #9adabf;
#             color:  #000000;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row7_col0 {
#             color:  green;
#         }    #T_60395ef6_acbd_11eb_ab43_8c859039bca2row7_col1 {
#             background-colo
