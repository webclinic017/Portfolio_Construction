# %% [markdown]
# # Quantitative Stock Selection

# %%
import yfinance as yf 

import pandas as pd
from matplotlib import pylab as plt
import numpy as np
from datetime import datetime
import math
from time import sleep
import quandl
import seaborn as sns
import sys
from scipy.stats import norm
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Functions

# %%
# FUNCTIONS FOR VIEWING SINGLE COMPANY RANKINGS 

def company(company):
    for i in data['Company']:
        if company in i or company in i.lower():
            return data.loc[data['Company'] == i]
    print('No company found')
    
def Company(company):
    for i in data['Company']:
        if company in i or company in i.lower():
            stock = data.loc[data['Company'] == i]
            stock = stock[compact]
            return stock
    print('No company found')

# %% [markdown]
# ## Data Import and Wrangling

# %%
# IMPORT LATEST DATA 

data_tmp = pd.read_excel("equity_data/Borsdata_2021-09-10.xlsx", sheet_name="Export")
data_tmp = data_tmp[1:]

data_tmp = data_tmp.rename({'Performance - Perform. 3m' : 'Return 3m','Performance - Perform. 6m' : 'Return 6m',
                            'Performance - Perform. 1y' : 'Return 1y',
                            'Div. Yield - Current': 'Yield', 
                            'Total Equity  - Millions':'Total Equity', 'FCF - Millions': 'FCF','ROE - Current':'ROE',
                            'Volatility - St.Dev. 100d':'Volatility','Market Cap - Current': 'Market Cap', 
                            'ROC - Current':'ROC', 'Tot. Assets - Millions':'Tot. Assets', 
                            'Gross profit - Millions':'Gross profit', 'Assets Turn - Current': 'Assets Turn',
                            'P/FCF - Current':'P/FCF', 'P/E - Current':'P/E', 'P/S - Current':'P/S',
                            'P/B - Current':'P/B','EV/EBIT - Current':'EV/EBIT',
                            'Info - Country' : 'Country','F-Score - Point':'F-Score',
                            'Info - List' : 'List', 'Info - Sector' : 'Sector', 'Info - Industry' : 'Industry',
                            'Info - Ticker' : 'Tick', 'Info - Yahoo':'Yahoo', 'Info - Last Report': 'Last Report',
                           'Volume - Average 50d Mill' : 'Volume'}, axis=1)

# FORMAT FOR VIEWING PLEASURE
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.options.display.float_format = "{:,.2f}".format

# %%
# MAKE NUMBERS FLOATS 

data_tmp['Market Cap'] = data_tmp['Market Cap'].replace(',', '') # remove , as 1000 separator

list = ['P/E', 'EV/EBIT', 'P/FCF', 'P/S', 'P/B', 'Assets Turn', 'Gross profit', 'Tot. Assets', 'ROC', 'Yield', 'Market Cap', 'Volatility',
        'F-Score', 'ROC', 'ROE', 'FCF', 'Total Equity', 
        'Return 3m', 'Return 6m', 'Return 1y']

for i in list: 
    data_tmp[i] = pd.to_numeric(data_tmp[i]) # make every number numeric


data_tmp['FCFROE'] = data_tmp['FCF']/data_tmp['Total Equity'] # calc FCFROE
data_tmp['GPA'] = data_tmp['Gross profit']/data_tmp['Tot. Assets']

# %%
### FILTER DATA FOR VOLUME, LIST AND MARKET CAP

data_tmp = data_tmp.loc[data_tmp['Market Cap'] > 500]
#data_tmp = data_tmp.loc[(data_tmp['List'] != 'First North') & (data_tmp['List'] != 'Spotlight') 
#                        & (data_tmp['List'] != 'NGM')]

data_tmp = data_tmp.loc[ (data_tmp['List'] != 'Spotlight') 
                        & (data_tmp['List'] != 'NGM')]

#Volume Filter
data_tmp = data_tmp.loc[data_tmp['Volume'] > 0.7]

# Set to dattime
data_tmp['Last Report'] = pd.to_datetime(data_tmp['Last Report'])

#set new index
data_tmp.index = range(len(data_tmp.index))

# %% [markdown]
# ## Calculate Price Based Data from Yahoo Finance

# %%
## Get PEAD
data_tmp["EA ret"] = np.nan
data_tmp["EA ret std"] = np.nan
data_tmp['1 Year Volatility'] = np.nan
data_tmp['Ret ID'] = np.nan
data_tmp['Beta'] = np.nan
index = yf.download('^OMXSPI',start='2020-01-01')
index = index['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
for i in range(len(data_tmp)):
    if data_tmp.iloc[i]['Yahoo'] != 'SDIP.ST':
        try:
            stock = yf.download(data_tmp.iloc[i]['Yahoo'],start='2020-01-01', progress = False)
            stock = stock['Close']
            import_data = pd.concat([stock, index], axis = 1)
            import_data.columns = ['stock', 'index']
            
            #price ID per Alpha Architect
            stock_id_pos = stock.tail(253).pct_change().dropna().gt(0).sum()/252
            stock_id_neg = stock.tail(253).pct_change().dropna().lt(0).sum()/252
            ret_sign = math.copysign(1, stock.pct_change(120).tail(1))
            data_tmp.loc[i, 'Ret ID'] = ret_sign * (stock_id_neg - stock_id_pos)
            
            #get beta of stock
            y_dat = import_data.pct_change().dropna().tail(252)['stock']
            x_dat = import_data.pct_change().dropna().tail(252)['index'].values.reshape((-1, 1))
            lin_model = LinearRegression().fit(x_dat, y_dat)
            data_tmp.loc[i, 'Beta'] = lin_model.coef_


            # get index of date of report
            idx = import_data.index.get_loc(data_tmp.iloc[i]['Last Report'])
            EA_data = import_data.iloc[idx - 2 : idx +2 ]
            
            data_tmp.loc[i,"1 Year Volatility"]= 100 * np.log(stock/stock.shift()).tail(252).std()*252**.5 
            data_tmp.loc[i, 'EA Volatility'] = (stock.iloc[idx-61:idx]/stock.iloc[idx-61:idx].shift()).tail(60).std()*252**0.5
    
            EA_ret = (EA_data.pct_change().dropna()+1).cumprod().tail(1)
            pead_ret = float(EA_ret['stock'] - EA_ret['index'])
            data_tmp.loc[i,"EA ret"]= pead_ret *100
            
            std = ((np.sqrt(3))*data_tmp.iloc[i]["Volatility"])/(np.sqrt(252))
            data_tmp.loc[i,"EA ret std"]= (pead_ret *100)/std
            
        except:
            data_tmp.loc[i,"EA ret"]= np.nan
            print("ERROR! INDEX: ", i, ', TICKER: ', data_tmp.iloc[i]['Yahoo'])
# Out:
# ERROR! INDEX:  69 , TICKER:  SFAST.ST
# ERROR! INDEX:  118 , TICKER:  PFE.ST
# ERROR! INDEX:  251 , TICKER:  GOGRID-SDB.ST
# ERROR! INDEX:  252 , TICKER:  GIGSEK.ST
# ERROR! INDEX:  320 , TICKER:  CPAC-SPAC.ST
# ERROR! INDEX:  372 , TICKER:  BICO.ST
# ERROR! INDEX:  411 , TICKER:  AFRY.ST

# %%
# calculate beta

y_dat = import_data.pct_change().dropna()['stock']
x_dat = import_data.pct_change().dropna()['index'].values.reshape((-1, 1))

lin_model = LinearRegression().fit(x_dat, y_dat)

# %%
lin_model.coef_
# Out:
# array([1.12178656])

# %%
lin_model.intercept_
# Out:
# -0.0007211187658195793

# %%
## Impute EA std and calculate EA STD after everything has been imputed

data_tmp.loc[data_tmp['EA Volatility'].isna(),'EA Volatility'] = data_tmp['EA Volatility'].median()
data_tmp["EA ret std"] = data_tmp["EA ret std"]/(data_tmp["EA Volatility"]*np.sqrt(3))

# %%
####### FILTER DATA FOR SUB STRATEGIES

data_full = data_tmp.copy()
### MOMENTUM

data_mom = data_tmp.copy()
data_mom = data_mom.loc[(data_mom['Industry'] != 'Holding Companies')]

#data_mom = data_tmp.loc[(data_tmp['Sector'] != 'Financials')]

data = data_tmp.copy()

### GESTALT
data = data.loc[(data_tmp['Sector'] != 'Financials')]
#data.index = range(len(data_tmp)) # make new index after removing

# %% [markdown]
# ## MOMENTUM

# %%
# MANAGE NaNs and NEGATIVE EARNINGS  
# set nan to min
for i in ['Return 3m', 'Return 6m', 'Return 1y']:
    data_mom.loc[data_mom[i].isna() ,i] = data_mom[i].min()
    
data_mom.loc[data_mom['Volatility'].isna(),'Volatility'] = data_mom['Volatility'].median()
data_mom.loc[data_mom['EA ret'].isna(),'EA ret'] = data_mom['EA ret'].median()
data_mom.loc[data_mom['EA ret std'].isna(),'EA ret std'] = data_mom['EA ret std'].median()
data_mom.loc[data_mom['Ret ID'].isna(),'Ret ID'] = data_mom['Ret ID'].median()

#Impute 100 day volatility for NANs
data_mom.loc[data_mom['1 Year Volatility'].isna(),'1 Year Volatility'] = data_mom.loc[data_mom['1 Year Volatility'].isna(),'Volatility']

# %%
# RANK ON DIFFERENT METRICS 

data_mom['3m Rank'] = data_mom['Return 3m'].rank(ascending = False)
data_mom['6m Rank'] = data_mom['Return 6m'].rank(ascending = False)
data_mom['1y Rank'] = data_mom['Return 1y'].rank(ascending = False)
data_mom['EA Rank'] = data_mom['EA ret'].rank(ascending = False)
data_mom['EA Std Rank'] = data_mom['EA ret std'].rank(ascending = False)
data_mom['Volatility Rank'] = data_mom['Volatility'].rank(ascending = True)
data_mom['ID Rank'] = data_mom['Ret ID'].rank(ascending = True)




# MOMENTUM WITH VOLATILITY
#data_mom['Momentum Rank'] = (data_mom['Return 3m'].rank(ascending = False) + data_mom['Return 6m'].rank(ascending = False) + 
#                              data_mom['Return 1y'].rank(ascending = False) + data_mom['Volatility'].rank(ascending = True)).rank(ascending = True)

# PURE MOMENTUM
#data_mom['Momentum Rank'] = (data_mom['Return 3m'].rank(ascending = False) + data_mom['Return 6m'].rank(ascending = False) + 
#                              data_mom['Return 1y'].rank(ascending = False)).rank(ascending = True)

# MOMENTUM WITH WOLATILITY AND EA
data_mom['Momentum Rank'] = (data_mom['3m Rank'] + data_mom['6m Rank'] +  data_mom['1y Rank'] + data_mom['Volatility Rank'] + data_mom['EA Rank']).rank(ascending = True)

# %% [markdown]
# ## GESTALT

# %%
# MANAGE NaNs and NEGATIVE EARNINGS  

# set nan to median
columns = ['P/E', 'EV/EBIT', 'P/FCF', 'P/S', 'P/B', 'ROC', 'ROE',
           'F-Score', 'GPA', 'Assets Turn']
for i in columns: 
    data.loc[data[i].isna() ,i] = data[i].median()

# set nan to min
for i in ['Return 3m', 'Return 6m', 'Return 1y']:
    data.loc[data[i].isna() ,i] = data[i].min()
    
# set negative values to max
for i in ['P/E', 'EV/EBIT', 'P/FCF', 'P/S', 'P/B']:
    data.loc[data[i] < 0 ,i] = data[i].max()
    
# set nan yield & vol to 0
data.loc[data['Yield'].isna(),'Yield'] = 0

data.loc[data['Volatility'].isna(),'Volatility'] = data['Volatility'].median()

#set EA nan to median
data.loc[data['EA ret'].isna(),'EA ret'] = data['EA ret'].median()
data.loc[data['EA ret std'].isna(),'EA ret std'] = data['EA ret std'].median()

# %%
# Manage negativ equity

#data['Total Equity']
#data.loc[(data['Total Equity'] < 0), ['ROE', 'FCFROE']] = np.nan
#data.loc[(data['Total Equity'] < 0), ['ROE', 'FCFROE']]

# %% [markdown]
# ## Rankings and Sorting

# %%
# RANK ON DIFFERENT METRICS 


data['3m Rank'] = data['Return 3m'].rank(ascending = False)
data['6m Rank'] = data['Return 6m'].rank(ascending = False)
data['1y Rank'] = data['Return 1y'].rank(ascending = False)
data['EA Rank'] = data['EA ret'].rank(ascending = False)
data['EA Std Rank'] = data['EA ret std'].rank(ascending = False)


data['Momentum Rank'] = (data['3m Rank'] + data['6m Rank'] + data['1y Rank'] + data['EA Rank']).rank(ascending = True)


#data['Momentum'] = (data['Return 3m'] + data['Return 6m'] + data['Return 1y'])


# Ranking where lower value is better
for i in ['P/E', 'P/B', 'P/S', 'P/FCF', 'EV/EBIT']:
    data[i +' Rank'] = data[i].rank()
    
# Ranking where higher value is better
#for i in ['Yield', 'ROE', 'ROC', 'FCFROE', 'Momentum', 'GPA', 'Assets Turn']:
for i in ['Yield', 'ROE', 'ROC', 'FCFROE', 'GPA', 'Assets Turn']:
    data[i + ' Rank'] = (-data[i]).rank()
    
# Composite ranks
data['Quality Rank'] = (data['ROE Rank'] + data['ROC Rank'] + data['FCFROE Rank'] + 
                        data['GPA Rank'] + data['Assets Turn Rank']).rank()
data['Value Rank'] = (data['P/E Rank'] + data['P/B Rank'] + data['P/S Rank'] + data['P/FCF Rank'] + 
                      data['EV/EBIT Rank'] + data['Yield Rank']).rank()
 
data['Magic Formula'] = (data['ROC Rank'] + data['EV/EBIT Rank']).rank()
data['Siegfrieds'] = (data['ROC Rank'] + data['P/B Rank']).rank()
data['Triple Sort'] = ((data['Value Rank'] + data['Momentum Rank'] + data['Quality Rank'])).rank()
data['Double Sort'] = (data['Value Rank'] + data['Quality Rank']).rank()

# %%
# SORTING 

# number of stocks to choose before momentum screen
trend_screen = 40
double_sort_break_off = 40

value_tmp = data.sort_values(by=['Value Rank'])
quality_tmp = data.sort_values(by=['Quality Rank'])
#### MOMENTUM DATA FRAME
momentum_tmp = data_mom.sort_values(by=['Momentum Rank'])


trending_value_tmp = value_tmp[0:trend_screen]
trending_value_tmp = trending_value_tmp.sort_values(by='Momentum Rank')
trending_quality_tmp = quality_tmp[0:trend_screen]
trending_quality_tmp = trending_quality_tmp.sort_values(by='Momentum Rank')
magic_formula_tmp = data.sort_values(by=['Magic Formula'])
siegfrieds_tmp = data.sort_values(by=['Siegfrieds'])
triple_sort_tmp = data.sort_values(by=['Triple Sort'])
double_sort = data.sort_values(by=['Double Sort'])
double_sort_mom_tmp = double_sort[0:double_sort_break_off]
double_sort_mom = double_sort_mom_tmp.sort_values(by=['Momentum Rank'])

# %%
# FACTOR STRATEGIES 

compact = ['Company', 'List','Tick', 'Quality Rank', 'Value Rank', 'Momentum Rank', 'EA Rank', 'EA Std Rank', '1 Year Volatility']

compact_mom = ['Company', 'List','Tick', 'Momentum Rank','Volatility Rank', 'EA Rank', 'EA Std Rank', '1 Year Volatility']

# numbers of stocks to select for diff strategies

stocks = 20
magic_formula_stocks = 10
siegfried_stocks = 10
triple_sort_stocks = 20
double_sort_mom_stocks = 10

## VALUE ## 
value = value_tmp[0:stocks]
Value = value[compact]

## QUALITY ## 
quality = quality_tmp[0:stocks]
Quality = quality[compact]

## MOMENTUM ##
momentum = momentum_tmp[0:stocks]
Momentum = momentum[compact_mom]

## TRENDING VALUE ##
trending_value = trending_value_tmp[0:stocks]
Trending_Value = trending_value[compact]

## TRENDING QUALITY ##
trending_quality = trending_quality_tmp[0:stocks]
Trending_Quality = trending_quality[compact]

## MAGIC FORMULA ##
magic_formula = magic_formula_tmp[0:magic_formula_stocks]
Magic_Formula = magic_formula[compact]

## SIEGFRIEDS ##
siegfrieds = siegfrieds_tmp[0:siegfried_stocks]
Siegfrieds = siegfrieds[compact]

## TRIPLE SORT ##
triple_sort = triple_sort_tmp[0:triple_sort_stocks]
Triple_Sort = triple_sort[compact]

## DOUBLE SORT + Momentum ##
double_sort_mom = double_sort_mom[0:double_sort_mom_stocks]
Double_Sort_Mom = double_sort_mom[compact]

# %% [markdown]
# ## Print Stock Selection

# %%
#Triple_Sort 
Triple_Sort.index = range(len(Triple_Sort))
Triple_Sort.style.apply(lambda x: ['background: lightgreen' if x.name in range(10) 
                              else '' for i in x], axis=1)
# Out:
# <style  type="text/css" >
#     #T_676e85fe_210a_11ec_9538_8c859039bca2row0_col0 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row0_col1 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row0_col2 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row0_col3 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row0_col4 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row0_col5 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row0_col6 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row0_col7 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row0_col8 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row1_col0 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row1_col1 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row1_col2 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row1_col3 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row1_col4 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row1_col5 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row1_col6 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row1_col7 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row1_col8 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row2_col0 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row2_col1 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row2_col2 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row2_col3 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row2_col4 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row2_col5 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row2_col6 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row2_col7 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row2_col8 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row3_col0 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row3_col1 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row3_col2 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row3_col3 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row3_col4 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row3_col5 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row3_col6 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row3_col7 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row3_col8 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row4_col0 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row4_col1 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row4_col2 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row4_col3 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row4_col4 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row4_col5 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row4_col6 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row4_col7 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row4_col8 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row5_col0 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row5_col1 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row5_col2 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row5_col3 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row5_col4 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row5_col5 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row5_col6 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row5_col7 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row5_col8 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row6_col0 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row6_col1 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row6_col2 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row6_col3 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row6_col4 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row6_col5 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row6_col6 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row6_col7 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row6_col8 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row7_col0 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row7_col1 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row7_col2 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row7_col3 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row7_col4 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row7_col5 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row7_col6 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row7_col7 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row7_col8 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row8_col0 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row8_col1 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row8_col2 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row8_col3 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row8_col4 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row8_col5 {
#             background:  lightgreen;
#         }    #T_676e85fe_210a_11ec_9538_8c859039bca2row8_col6 {
#             background:  lightgreen;

# %%
Momentum.index = range(len(Momentum))
Momentum.style.apply(lambda x: ['background: lightgreen' if x.name in range(10) 
                              else '' for i in x], axis=1)
# Out:
# <style  type="text/css" >
#     #T_68236a78_210a_11ec_9538_8c859039bca2row0_col0 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row0_col1 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row0_col2 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row0_col3 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row0_col4 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row0_col5 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row0_col6 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row0_col7 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row1_col0 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row1_col1 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row1_col2 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row1_col3 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row1_col4 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row1_col5 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row1_col6 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row1_col7 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row2_col0 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row2_col1 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row2_col2 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row2_col3 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row2_col4 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row2_col5 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row2_col6 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row2_col7 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row3_col0 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row3_col1 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row3_col2 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row3_col3 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row3_col4 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row3_col5 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row3_col6 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row3_col7 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row4_col0 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row4_col1 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row4_col2 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row4_col3 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row4_col4 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row4_col5 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row4_col6 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row4_col7 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row5_col0 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row5_col1 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row5_col2 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row5_col3 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row5_col4 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row5_col5 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row5_col6 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row5_col7 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row6_col0 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row6_col1 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row6_col2 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row6_col3 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row6_col4 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row6_col5 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row6_col6 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row6_col7 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row7_col0 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row7_col1 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row7_col2 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row7_col3 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row7_col4 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row7_col5 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row7_col6 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row7_col7 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row8_col0 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row8_col1 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row8_col2 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row8_col3 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row8_col4 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row8_col5 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row8_col6 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row8_col7 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row9_col0 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row9_col1 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row9_col2 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row9_col3 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row9_col4 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row9_col5 {
#             background:  lightgreen;
#         }    #T_68236a78_210a_11ec_9538_8c859039bca2row9_col6 {
#             background:  lightgreen;

# %% [markdown]
# ## DATA EXPLORATION

# %%
plt.scatter(data_tmp['Volatility'], data_tmp['1 Year Volatility'])
plt.xlabel("100 Day Volatility")
plt.ylabel("1 Year Volatility")
# Out:
# Text(0, 0.5, '1 Year Volatility')

# %%
plt.scatter(data_mom['ID Rank'], data_mom['Volatility Rank'])
plt.xlabel("ID Rank")
plt.ylabel("Volatility Rank");

# %%
data_mom.sort_values(by='Beta')[['Company', 'Beta']]
# Out:
#                        Company  Beta
# 46             Studentbostäder -0.77
# 211                ISR Holding -0.28
# 1                       Zordix  0.03
# 307                       Doxa  0.11
# 228                ICA Gruppen  0.15
# 320              Creaspac SPAC  0.16
# 337                    Cavotec  0.17
# 262              Fastpartner D  0.19
# 360               Bokusgruppen  0.21
# 205               John Mattson  0.24
# 183                  LMK Group  0.24
# 384                AstraZeneca  0.24
# 387                     Axfood  0.24
# 397                Arion Banki  0.25
# 321                    Corem D  0.27
# 409              Alcadon Group  0.27
# 94                   Rottneros  0.27
# 249            Genova Property  0.28
# 302                   Eastnine  0.29
# 260             Fractal Gaming  0.29
# 283                   Essity B  0.31
# 308                       Doro  0.32
# 19            Wästbygg Gruppen  0.32
# 341                  Cantargia  0.33
# 269                   Flexqube  0.35
# 416                    Adapteo  0.37
# 202                       Kabe  0.38
# 272          Fingerprint Cards  0.39
# 3                  ZetaDisplay  0.39
# 59                 Sleep Cycle  0.40
# 267                FM Mattsson  0.41
# 265                  Fortinova  0.41
# 203                        K2A  0.42
# 180                Lundin Gold  0.43
# 54                 SpectraCure  0.44
# 290                 Enzymatica  0.44
# 328                    Cloetta  0.44
# 39               Swedish Match  0.44
# 35               Telia Company  0.44
# 118                     Pfizer  0.44
# 26              Train Alliance  0.45
# 66        Signatur Fastigheter  0.45
# 333                 Crunchfish  0.45
# 330               Cibus Nordic  0.45
# 176                       Lyko  0.45
# 75                      Semcon  0.45
# 171                     MedCap  0.46
# 353                  Bredband2  0.48
# 281                      eWork  0.48
# 355                 Björn Borg  0.48
# 198                Karo Pharma  0.49
# 261          Formpipe Software  0.49
# 126                OrganoClick  0.49
# 36                     Tele2 B  0.49
# 294                 Embellence  0.49
# 233                     Humana  0.50
# 199                     Karnov  0.50
# 245                       Heba  0.50
# 137               Nordic Paper  0.51
# 207                     Jetpak  0.51
# 210          ITAB Shop Concept  0.53
# 388                    Awardit  0.53
# 158                    Medivir  0.54
# 422          Absolent Air Care  0.54
# 274               Fasadgruppen  0.54
# 313                  Dignitana  0.54
# 150                       Nepa  0.54
# 53                     Serneke  0.55
# 412                   AegirBio  0.55
# 311                     DistIT  0.56
# 424                        AAK  0.56
# 82             Scandi Standard  0.56
# 108                      Probi  0.56
# 71                     Senzime  0.56
# 271                    Firefly  0.56
# 88                     Saniona  0.56
# 226                  Immunicum  0.57
# 252          Gaming Innovation  0.57
# 69         Stenhus Fastigheter  0.57
# 382                Balco Group  0.58
# 20                         VBG  0.58
# 99      RaySearch Laboratories  0.58
# 40                    Studsvik  0.58
# 367                  BioArctic  0.59
# 156                   Nanoform  0.60
# 161                  Midsona B  0.60
# 230              I.A.R Systems  0.62
# 420                      Acast  0.62
# 162          Micro Systemation  0.62
# 366                    BioGaia  0.62
# 322                Copperstone  0.63
# 404                    Amasten  0.63
# 174                   Magnolia  0.63
# 314                   Dedicare  0.64
# 394                 Arla Plast  0.64
# 113                  Polygiene  0.64
# 97                     Rejlers  0.65
# 389                    Attendo  0.66
# 83           Scandion Oncology  0.66
# 344                Byggpartner  0.66
# 395                       Arjo  0.66
# 284                 Ericsson B  0.66
# 14                Vimian Group  0.66
# 107                 Permascand  0.67
# 251                Smart Wires  0.67
# 141                      Nokia  0.67
# 164             Momentum Group  0.67
# 296                       Elos  0.67
# 390           Atrium Ljungberg  0.68
# 105                   QleanAir  0.68
# 133      Oasmia Pharmaceutical  0.69
# 315                CTT Systems  0.69
# 238              Hoist Finance  0.69
# 256             Generic Sweden  0.69
# 92              Revolutionrace  0.70
# 23                     Trianon  0.70
# 29                   TietoEVRY  0.70
# 5                Xspray Pharma  0.70
# 248          Green Landscaping  0.70
# 16               Vicore Pharma  0.71
# 28                    Millicom  0.71
# 225                 Implantica  0.71
# 87                         SAS  0.72
# 117               Pierce Group  0.72
# 173            MAG Interactive  0.73
# 138                        NP3  0.73
# 172                Maha Energy  0.73
# 223      InDex Pharmaceuticals  0.73
# 42                    Swedbank  0.73
# 279                    Exsitec  0.74
# 263              Fastpartner A  0.74
# 68             Handelsbanken A  0.74
# 154                      NCC B  0.74
# 295               Electrolux B  0.74
# 219                   Integrum  0.74
# 33                  Tethys Oil  0.74
# 364                    Biovica  0.74
# 104                      QLife  0.74
# 25                   Transtema  0.74
# 264              Fenix Outdoor  0.75
# 56                   Softronic  0.75
# 193                 Kungsleden  0.75
# 142                     Nobina  0.75
# 109                     Pricer  0.75
# 131                        OEM  0.75
# 383                 Bactiguard  0.75
# 277                  Fagerhult  0.76
# 103                    Q-Linea  0.76
# 125                      Orexo  0.76
# 329                 Cint Group  0.76
# 266                Ferronordic  0.76
# 406                     Alimak  0.76
# 351                    Brinova  0.77
# 166                    Minesto  0.77
# 101                   Raketech  0.77
# 275                   Ferroamp  0.77
# 402        Annehem Fastigheter  0.77
# 246                      Hanza  0.78
# 352               Bergs Timber  0.78
# 147                      Nexam  0.78
# 129           Oscar Properties  0.79
# 370            BillerudKorsnäs  0.79
# 254                    Getinge  0.79
# 76              Sedana Medical  0.79
# 357                Bonesupport  0.79
# 299        Egetis Therapeutics  0.79
# 276                   Fastator  0.80
# 373                  BHG Group  0.80
# 253         GHP Specialty Care  0.80
# 132                  Odd Molly  0.80
# 361                     Nimbus  0.80
# 310             Diamyd Medical  0.80
# 77                   Securitas  0.80
# 136                    Novotek  0.80
# 335              Cortus Energy  0.80
# 84                       SCA B  0.80
# 57    Swedish Orphan Biovitrum  0.80
# 21                  Wallenstam  0.81
# 213         IRLAB Therapeutics  0.81
# 338                     Catena  0.81
# 93                    RugVista  0.81
# 122                  Proact IT  0.81
# 237                   Holmen B  0.82
# 327                Clas Ohlson  0.82
# 403                      Ambea  0.82
# 70                  Stillfront  0.83
# 421                 AcadeMedia  0.83
# 86                     Nordnet  0.83
# 110                    Profoto  0.83
# 363                  Bio-Works  0.83
# 153                Nordea Bank  0.83
# 149                Net Insight  0.84
# 268                  FluoGuide  0.84
# 145              Nilörngruppen  0.84
# 334                CellaVision  0.84
# 49                  Stendörren  0.85
# 74                Sensys Gatso  0.86
# 418             Ascelia Pharma  0.86
# 64                  SinterCast  0.86
# 96                  Re:NewCell  0.86
# 34                     Teqnion  0.87
# 287                    Episurf  0.87
# 51                Starbreeze B  0.87
# 342                    Camurus  0.87
# 298                     Elekta  0.87
# 115                    Platzer  0.87
# 234             Hufvudstaden A  0.88
# 102                      Qliro  0.88
# 144                   Nederman  0.88
# 325                 Concentric  0.88
# 163                    Mentice  0.88
# 380                   BE Group  0.88
# 168                  Midsummer  0.88
# 425                     Traton  0.89
# 365                    Biotage  0.89
# 354                    Bravida  0.89
# 119                       Peab  0.89
# 368                  Bioinvent  0.89
# 208                    Invisio  0.89
# 326                    Climeon  0.89
# 340                  Castellum  0.89
# 393              Aspire Global  0.89
# 312                       Diös  0.90
# 31                       Thule  0.90
# 379                Beijer Alma  0.90
# 196             K-Fast Holding  0.90
# 212             Isofol Medical  0.90
# 130               Oncopeptides  0.91
# 349                  BTS Group  0.92
# 128      OptiCept Technologies  0.92
# 152                Nelly Group  0.92
# 292                       Enea  0.92
# 112                     Poolia  0.92
# 160                      MTG B  0.92
# 120        Paradox Interactive  0.92
# 278                     Fabege  0.92
# 6             Xbrane Biopharma  0.93
# 91                        Saab  0.93
# 206                         JM  0.93
# 204        Josemaria Resources  0.93
# 231                Husqvarna B  0.93
# 401                    Addnode  0.93
# 304                      Duroc  0.94
# 303               Dustin Group  0.94
# 374                    Betsson  0.94
# 400                 Africa Oil  0.94
# 192                     KnowIT  0.94
# 423                        ABB  0.94
# 12                   Vitrolife  0.94
# 135       Nordic Waterproofing  0.94
# 32                     TF Bank  0.94
# 30                  Thunderful  0.95
# 259           G5 Entertainment  0.95
# 381                Fast Balder  0.95
# 305                       Duni  0.95
# 60                     SkiStar  0.95
# 80                       SEB A  0.95
# 13              Vitec Software  0.96
# 58                    ShaMaran  0.96
# 291                    EnQuest  0.96
# 134                     Nyfosa  0.96
# 78                      Sectra  0.96
# 182                     Loomis  0.97
# 7                XANO Industri  0.97
# 170                  Medicover  0.98
# 375          Better Collective  0.98
# 50                Stora Enso R  0.99
# 177              Lundin Energy  0.99
# 37                   Systemair  0.99
# 239            Hansa Biopharma  0.99
# 241           Hennes & Mauritz  0.99
# 200                    Kancera  0.99
# 323               Coor Service  0.99
# 85     Samhällsbyggnadsbolag B  0.99
# 95              Resurs Holding  1.00
# 4              Xvivo Perfusion  1.00
# 179              Lundin Mining  1.00
# 371                      Bilia  1.00
# 362                    Byggmax  1.00
# 392                 Assa Abloy  1.00
# 293                   Embracer  1.00
# 405                    Autoliv  1.00
# 229           Infant Bacterial  1.01
# 257                       GARO  1.01
# 297                   Elanders  1.01
# 191                Lagercrantz  1.01
# 214                    Irisity  1.02
# 157                   Mycronic  1.02
# 124                      Ovzon  1.02
# 218                     Intrum  1.03
# 399                   AQ Group  1.03
# 319                      C-RAD  1.03
# 339                  Catella B  1.03
# 377         Beijer Electronics  1.04
# 15                   Wihlborgs  1.04
# 358                   Bonava B  1.04
# 408                 Alfa Laval  1.04
# 143                      Nobia  1.05
# 288                   Epiroc B  1.06
# 123                        OX2  1.06
# 181             Lucara Diamond  1.07
# 316               Catena Media  1.07
# 98                      Readly  1.08
# 324                  Collector  1.08
# 43                     Sweco B  1.08
# 111                     Prevas  1.08
# 73         Scandinavian Enviro  1.08
# 300              Enad Global 7  1.09
# 216                     Inwido  1.09
# 169                  Mekonomen  1.09
# 61                       SKF B  1.12
# 235                 Hexatronic  1.12
# 301                   Ecoclime  1.12
# 414                   Advenica  1.12
# 359                    Boliden  1.12
# 222                  Indutrade  1.13
# 209                  Intervacc  1.13
# 62                     Skanska  1.14
# 376           Bergman & Beving  1.14
# 413              Africa Energy  1.14
# 273                Filo Mining  1.15
# 2                      ZignSec  1.15
# 369                  BIMobject  1.16
# 243                    Hexagon  1.16
# 356                      Boozt  1.16
# 148                   New Wave  1.16
# 146                       NIBE  1.17
# 52                      SSAB A  1.17
# 236                     Hexpol  1.17
# 65                       Sinch  1.18
# 159                    Munters  1.18
# 90                     Sagax A  1.18
# 270             Flexion Mobile  1.19
# 8                      Volvo B  1.19
# 386                     Avanza  1.19
# 309                    Dometic  1.20
# 24                  Trelleborg  1.20
# 47            Swedish Stirling  1.20
# 240               HMS Networks  1.20
# 140                     Nolato  1.20
# 189                   LeoVegas  1.21
# 186          Lime Technologies  1.21
# 255                    Genovis  1.21
# 419                   Acconeer  1.22
# 391              Atlas Copco A  1.22
# 79                  Swedencare  1.23
# 227                  Immunovia  1.23
# 348                      Bufab  1.23
# 139                       NOTE  1.24
# 347                     Bulten  1.24
# 250                   GomSpace  1.25
# 385                     Azelio  1.25
# 114                     Pandox  1.25
# 188                     Lindab  1.26
# 41                   Svedbergs  1.26
# 165                       Mips  1.26
# 215    International Petroleum  1.26
# 345                   Bambuser  1.28
# 175            Media and Games  1.28
# 407                    AddLife  1.29
# 247                    Gränges  1.29
# 89                     Sandvik  1.29
# 232               Humble Group  1.31
# 242                     Haldex  1.31
# 220                   Instalco  1.31
# 151     Nordic Entertainment B  1.32
# 27                       Tobii  1.32
# 167               Mildef Group  1.33
# 116                 PiezoMotor  1.33
# 378                 Beijer Ref  1.34
# 48                    Storytel  1.34
# 317                 CoinShares  1.35
# 195                    Kindred  1.36
# 155                 NCAB Group  1.36
# 306                    Desenio  1.37
# 201                      Kambi  1.39
# 396            Arise Windpower  1.40
# 22                 Troax Group  1.41
# 343    Calliditas Therapeutics  1.42
# 350               Goobit Group  1.43
# 0                        Zwipe  1.44
# 286  Electrolux Professional B  1.45
# 44            Surgical Science  1.45
# 415                    Addtech  1.47
# 11                     Veoneer  1.47
# 67              Scandic Hotels  1.49
# 63       Sivers Semiconductors  1.51
# 332                checkin.com  1.52
# 106                 Physitrack  1.53
# 244                     Hemnet  1.55
# 282                  Evolution  1.58
# 289                 Eolus Vind  1.60
# 55              SolTech Energy  1.62
# 331                Cell Impact  1.62
# 72                   Smart Eye  1.64
# 258                   Gapwaves  1.65
# 280         ExpreS2ion Biotech  1.70
# 184                   Linkfire  1.88
# 398              Arcane Crypto  1.93
# 121                  PowerCell  2.03
# 224            Impact Coatings  2.16
# 336                       CDON  2.40
# 81                    Sdiptech   nan
# 372                 BICO Group   nan
# 411                       AFRY   nan
