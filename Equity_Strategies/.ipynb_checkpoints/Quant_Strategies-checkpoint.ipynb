# %% [markdown]
# # Quantitative Stock Selection

# %%
import yfinance as yf 

import pandas as pd
from matplotlib import pylab as plt
import numpy as np
from datetime import datetime
import math
from time import sleep
import quandl
import seaborn as sns
import sys
from scipy.stats import norm
from sklearn.linear_model import LinearRegression
import sys
from scipy.stats import norm
import ezodf
import scipy.optimize as sco
import scipy

# %% [markdown]
# ## Functions

# %%
# FUNCTIONS FOR VIEWING SINGLE COMPANY RANKINGS 

def company(company):
    for i in data['Company']:
        if company in i or company in i.lower():
            return data.loc[data['Company'] == i]
    print('No company found')
    
def Company(company):
    for i in data['Company']:
        if company in i or company in i.lower():
            stock = data.loc[data['Company'] == i]
            stock = stock[compact]
            return stock
    print('No company found')

# %%
def mod_Z_score(data):
    mean = np.mean(data.iloc[:-1])
    deviation_from_med = np.array(data.iloc[:-1]) - mean
    MAD = np.mean(np.abs(deviation_from_med))
    mod_Z = (data[-1:] - mean)/(MAD * 1.4826)
    return mod_Z

# %% [markdown]
# ## Data Import and Wrangling

# %%
# IMPORT LATEST DATA 

data_tmp = pd.read_excel("equity_data/Borsdata_2021-09-10.xlsx", sheet_name="Export")
data_tmp = data_tmp[1:]

data_tmp = data_tmp.rename({'Performance - Perform. 3m' : 'Return 3m','Performance - Perform. 6m' : 'Return 6m',
                            'Performance - Perform. 1y' : 'Return 1y',
                            'Div. Yield - Current': 'Yield', 
                            'Total Equity  - Millions':'Total Equity', 'FCF - Millions': 'FCF','ROE - Current':'ROE',
                            'Volatility - St.Dev. 100d':'Volatility','Market Cap - Current': 'Market Cap', 
                            'ROC - Current':'ROC', 'Tot. Assets - Millions':'Tot. Assets', 
                            'Gross profit - Millions':'Gross profit', 'Assets Turn - Current': 'Assets Turn',
                            'P/FCF - Current':'P/FCF', 'P/E - Current':'P/E', 'P/S - Current':'P/S',
                            'P/B - Current':'P/B','EV/EBIT - Current':'EV/EBIT',
                            'Info - Country' : 'Country','F-Score - Point':'F-Score',
                            'Info - List' : 'List', 'Info - Sector' : 'Sector', 'Info - Industry' : 'Industry',
                            'Info - Ticker' : 'Tick', 'Info - Yahoo':'Yahoo', 'Info - Last Report': 'Last Report',
                           'Volume - Average 50d Mill' : 'Volume'}, axis=1)

# FORMAT FOR VIEWING PLEASURE
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.options.display.float_format = "{:,.2f}".format

# %%
# MAKE NUMBERS FLOATS 

data_tmp['Market Cap'] = data_tmp['Market Cap'].replace(',', '') # remove , as 1000 separator

list = ['P/E', 'EV/EBIT', 'P/FCF', 'P/S', 'P/B', 'Assets Turn', 'Gross profit', 'Tot. Assets', 'ROC', 'Yield', 'Market Cap', 'Volatility',
        'F-Score', 'ROC', 'ROE', 'FCF', 'Total Equity', 
        'Return 3m', 'Return 6m', 'Return 1y']

for i in list: 
    data_tmp[i] = pd.to_numeric(data_tmp[i]) # make every number numeric


data_tmp['FCFROE'] = data_tmp['FCF']/data_tmp['Total Equity'] # calc FCFROE
data_tmp['GPA'] = data_tmp['Gross profit']/data_tmp['Tot. Assets']

# %%
# Manage negativ equity

data_tmp.loc[(data_tmp['Total Equity'] < 0), ['ROE', 'FCFROE', 'P/B']] = np.nan

# %%
### FILTER DATA FOR VOLUME, LIST AND MARKET CAP

#data_tmp = data_tmp.loc[data_tmp['Market Cap'] > 500] #Market cap filter


#data_tmp = data_tmp.loc[(data_tmp['List'] != 'First North') & (data_tmp['List'] != 'Spotlight') 
#                        & (data_tmp['List'] != 'NGM')]

data_tmp = data_tmp.loc[ (data_tmp['List'] != 'Spotlight') 
                        & (data_tmp['List'] != 'NGM')]

#Volume Filter
data_tmp = data_tmp.loc[data_tmp['Volume'] > 0.5] 

# Set to dattime
data_tmp['Last Report'] = pd.to_datetime(data_tmp['Last Report'])

#set new index
data_tmp.index = range(len(data_tmp.index))

# %%
len(data_tmp)
# Out:
# 542

# %% [markdown]
# ## Calculate Price Based Data from Yahoo Finance

# %%
## Get PEAD
data_tmp["EA ret"] = np.nan
data_tmp["EA ret std"] = np.nan
data_tmp['1 Year Volatility'] = np.nan
data_tmp['1 Year MAD'] = np.nan
data_tmp['Ret ID'] = np.nan
data_tmp['Beta'] = np.nan
index = yf.download('^OMXSPI',start='2020-01-01')
index = index['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
for i in range(len(data_tmp)):
    try:
        stock = yf.download(data_tmp.iloc[i]['Yahoo'],start='2020-01-01', progress = False)
        stock = stock['Close']
        import_data = pd.concat([stock, index], axis = 1)
        import_data.columns = ['stock', 'index']
            
        #price ID per Alpha Architect
        stock_id_pos = stock.tail(253).pct_change().dropna().gt(0).sum()/252
        stock_id_neg = stock.tail(253).pct_change().dropna().lt(0).sum()/252
        ret_sign = math.copysign(1, stock.pct_change(120).tail(1))
        data_tmp.loc[i, 'Ret ID'] = ret_sign * (stock_id_neg - stock_id_pos)
            
        #get beta of stock
        y_dat = import_data.pct_change().dropna().tail(252)['stock']
        x_dat = import_data.pct_change().dropna().tail(252)['index'].values.reshape((-1, 1))
        lin_model = LinearRegression().fit(x_dat, y_dat)
        data_tmp.loc[i, 'Beta'] = lin_model.coef_
            
        #Get MAD of stock
        data_tmp.loc[i,"1 Year MAD"]= np.log(stock/stock.shift()).tail(252).mad()*252**.5*1.25

        # get index of date of report
        idx = import_data.index.get_loc(data_tmp.iloc[i]['Last Report'])
        EA_data = import_data.iloc[idx - 2 : idx +2 ]
            
        data_tmp.loc[i,"1 Year Volatility"]= np.log(stock/stock.shift()).tail(252).std()*252**.5 
        data_tmp.loc[i, 'EA Volatility'] = (stock.iloc[idx-61:idx]/stock.iloc[idx-61:idx].shift()).tail(60).std()*252**0.5
    
        EA_ret = (EA_data.pct_change().dropna()+1).cumprod().tail(1)
        pead_ret = float(EA_ret['stock'] - EA_ret['index'])
        data_tmp.loc[i,"EA ret"]= pead_ret
            
        #std = ((np.sqrt(3))*data_tmp.iloc[i]["Volatility"])/(np.sqrt(252))
        #data_tmp.loc[i,"EA ret std"]= (pead_ret *100)/std
            
    except:
        data_tmp.loc[i,"EA ret"]= np.nan
        print("ERROR! INDEX: ", i, ', TICKER: ', data_tmp.iloc[i]['Yahoo'])
# Out:
# ERROR! INDEX:  11 , TICKER:  WYLD.ST
# ERROR! INDEX:  45 , TICKER:  TESSIN.ST
# ERROR! INDEX:  88 , TICKER:  SFAST.ST
#
# 1 Failed download:
# - SDIP.ST: No data found, symbol may be delisted
# ERROR! INDEX:  101 , TICKER:  SDIP.ST
# ERROR! INDEX:  150 , TICKER:  PFE.ST
# ERROR! INDEX:  164 , TICKER:  ONCOZ.ST
# ERROR! INDEX:  213 , TICKER:  ME.ST
# ERROR! INDEX:  240 , TICKER:  LCLEAN.ST
# ERROR! INDEX:  317 , TICKER:  GOGRID-SDB.ST
# ERROR! INDEX:  318 , TICKER:  GIGSEK.ST
# ERROR! INDEX:  355 , TICKER:  EURA.ST
# ERROR! INDEX:  405 , TICKER:  CPAC-SPAC.ST
# ERROR! INDEX:  464 , TICKER:  BIOSGN.ST

# %%
## Impute EA std and calculate EA STD after everything has been imputed
data_tmp.loc[data_tmp['EA Volatility'].isna(),'EA Volatility'] = data_tmp['EA Volatility'].median()
data_tmp["EA ret std"] = data_tmp["EA ret"]/((data_tmp["EA Volatility"]*np.sqrt(3))/np.sqrt(252))

#Impute median for NAN MAD
data_tmp.loc[data_tmp['1 Year MAD'].isna(),'1 Year MAD'] = data_tmp['1 Year MAD'].median()

# %%
####### FILTER DATA FOR SUB STRATEGIES
data_full = data_tmp.copy()
### MOMENTUM
data_mom = data_tmp.copy()
data_mom = data_mom.loc[(data_mom['Industry'] != 'Holding Companies')]
#data_mom = data_tmp.loc[(data_tmp['Sector'] != 'Financials')]

data = data_tmp.copy()
### GESTALT
data = data.loc[(data_tmp['Sector'] != 'Financials')]

# %% [markdown]
# ## MOMENTUM

# %%
# MANAGE NaNs and NEGATIVE EARNINGS  
# set nan to min
for i in ['Return 3m', 'Return 6m', 'Return 1y']:
    data_mom.loc[data_mom[i].isna() ,i] = data_mom[i].min()
    
data_mom.loc[data_mom['Volatility'].isna(),'Volatility'] = data_mom['Volatility'].median()
data_mom.loc[data_mom['EA ret'].isna(),'EA ret'] = data_mom['EA ret'].median()
data_mom.loc[data_mom['EA ret std'].isna(),'EA ret std'] = data_mom['EA ret std'].median()
data_mom.loc[data_mom['Ret ID'].isna(),'Ret ID'] = data_mom['Ret ID'].median()

#Impute 100 day volatility for NANs
data_mom.loc[data_mom['1 Year Volatility'].isna(),'1 Year Volatility'] = data_mom.loc[data_mom['1 Year Volatility'].isna(),'Volatility']

# %%
# RANK ON DIFFERENT METRICS 

data_mom['3m Rank'] = data_mom['Return 3m'].rank(ascending = False)
data_mom['6m Rank'] = data_mom['Return 6m'].rank(ascending = False)
data_mom['1y Rank'] = data_mom['Return 1y'].rank(ascending = False)
data_mom['EA Rank'] = data_mom['EA ret'].rank(ascending = False)
data_mom['EA Std Rank'] = data_mom['EA ret std'].rank(ascending = False)
data_mom['Volatility Rank'] = data_mom['Volatility'].rank(ascending = True)
data_mom['ID Rank'] = data_mom['Ret ID'].rank(ascending = True)


# MOMENTUM WITH VOLATILITY
#data_mom['Momentum Rank'] = (data_mom['Return 3m'].rank(ascending = False) + data_mom['Return 6m'].rank(ascending = False) + 
#                              data_mom['Return 1y'].rank(ascending = False) + data_mom['Volatility'].rank(ascending = True)).rank(ascending = True)

# PURE MOMENTUM
#data_mom['Momentum Rank'] = (data_mom['Return 3m'].rank(ascending = False) + data_mom['Return 6m'].rank(ascending = False) + 
#                              data_mom['Return 1y'].rank(ascending = False)).rank(ascending = True)

# MOMENTUM WITH WOLATILITY AND EA
data_mom['Momentum Rank'] = (data_mom['3m Rank'] + data_mom['6m Rank'] +  data_mom['1y Rank'] + data_mom['Volatility Rank'] + data_mom['EA Std Rank']).rank(ascending = True)

# %% [markdown]
# ## GESTALT

# %%
# MANAGE NaNs and NEGATIVE EARNINGS  

# set nan to median
columns = ['P/E', 'EV/EBIT', 'P/FCF', 'P/S', 'P/B', 'ROC', 'ROE',
           'F-Score', 'GPA', 'Assets Turn','Volatility', 'EA ret', 'EA ret std']
for i in columns: 
    data.loc[data[i].isna() ,i] = data[i].median()

# set nan to min
for i in ['Return 3m', 'Return 6m', 'Return 1y']:
    data.loc[data[i].isna() ,i] = data[i].min()
    
# set negative values to max
for i in ['P/E', 'EV/EBIT', 'P/FCF', 'P/S', 'P/B']:
    data.loc[data[i] < 0 ,i] = data[i].max()
    
# set nan yield & vol to 0
data.loc[data['Yield'].isna(),'Yield'] = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-aa15b0f9e9c8> in <module>
#       5            'F-Score', 'GPA', 'Assets Turn','Volatility', 'EA ret', 'EA ret std']
#       6 for i in columns:
# ----> 7     data.loc[data[i].isna() ,i] = data[i].median()
#       8
#       9 # set nan to min
#
# NameError: name 'data' is not defined

# %% [markdown]
# ## Rankings and Sorting

# %%
# RANK ON DIFFERENT METRICS 


data['3m Rank'] = data['Return 3m'].rank(ascending = False)
data['6m Rank'] = data['Return 6m'].rank(ascending = False)
data['1y Rank'] = data['Return 1y'].rank(ascending = False)
data['EA Rank'] = data['EA ret'].rank(ascending = False)
data['EA Std Rank'] = data['EA ret std'].rank(ascending = False)


data['Momentum Rank'] = (data['3m Rank'] + data['6m Rank'] + data['1y Rank'] + data['EA Std Rank']).rank(ascending = True)


#data['Momentum'] = (data['Return 3m'] + data['Return 6m'] + data['Return 1y'])


# Ranking where lower value is better
for i in ['P/E', 'P/B', 'P/S', 'P/FCF', 'EV/EBIT']:
    data[i +' Rank'] = data[i].rank()
    
# Ranking where higher value is better
#for i in ['Yield', 'ROE', 'ROC', 'FCFROE', 'Momentum', 'GPA', 'Assets Turn']:
for i in ['Yield', 'ROE', 'ROC', 'FCFROE', 'GPA', 'Assets Turn']:
    data[i + ' Rank'] = (-data[i]).rank()
    
# Composite ranks
data['Quality Rank'] = (data['ROE Rank'] + data['ROC Rank'] + data['FCFROE Rank'] + 
                        data['GPA Rank'] + data['Assets Turn Rank']).rank()
data['Value Rank'] = (data['P/E Rank'] + data['P/B Rank'] + data['P/S Rank'] + data['P/FCF Rank'] + 
                      data['EV/EBIT Rank'] + data['Yield Rank']).rank()
 
data['Magic Formula'] = (data['ROC Rank'] + data['EV/EBIT Rank']).rank()
data['Siegfrieds'] = (data['ROC Rank'] + data['P/B Rank']).rank()
data['Triple Sort'] = ((data['Value Rank'] + data['Momentum Rank'] + data['Quality Rank'])).rank()
data['Double Sort'] = (data['Value Rank'] + data['Quality Rank']).rank()

# %%
# SORTING 

# number of stocks to choose before momentum screen
trend_screen = 40
double_sort_break_off = 40

value_tmp = data.sort_values(by=['Value Rank'])
quality_tmp = data.sort_values(by=['Quality Rank'])
#### MOMENTUM DATA FRAME
momentum_tmp = data_mom.sort_values(by=['Momentum Rank'])


trending_value_tmp = value_tmp[0:trend_screen]
trending_value_tmp = trending_value_tmp.sort_values(by='Momentum Rank')
trending_quality_tmp = quality_tmp[0:trend_screen]
trending_quality_tmp = trending_quality_tmp.sort_values(by='Momentum Rank')
magic_formula_tmp = data.sort_values(by=['Magic Formula'])
siegfrieds_tmp = data.sort_values(by=['Siegfrieds'])
triple_sort_tmp = data.sort_values(by=['Triple Sort'])
double_sort = data.sort_values(by=['Double Sort'])
double_sort_mom_tmp = double_sort[0:double_sort_break_off]
double_sort_mom = double_sort_mom_tmp.sort_values(by=['Momentum Rank'])

# %%
# FACTOR STRATEGIES 

compact = ['Company', 'List','Tick', 'Quality Rank', 'Value Rank', 'Momentum Rank', 'EA Std Rank', '1 Year Volatility']

compact_mom = ['Company', 'List','Tick', 'Momentum Rank','Volatility Rank', 'EA Rank', 'EA Std Rank', '1 Year Volatility']

# numbers of stocks to select for diff strategies

stocks = 20
magic_formula_stocks = 10
siegfried_stocks = 10
triple_sort_stocks = 20
double_sort_mom_stocks = 10

## VALUE ## 
value = value_tmp[0:stocks]
Value = value[compact]

## QUALITY ## 
quality = quality_tmp[0:stocks]
Quality = quality[compact]

## MOMENTUM ##
momentum = momentum_tmp[0:stocks]
Momentum = momentum[compact_mom]

## TRENDING VALUE ##
trending_value = trending_value_tmp[0:stocks]
Trending_Value = trending_value[compact]

## TRENDING QUALITY ##
trending_quality = trending_quality_tmp[0:stocks]
Trending_Quality = trending_quality[compact]

## MAGIC FORMULA ##
magic_formula = magic_formula_tmp[0:magic_formula_stocks]
Magic_Formula = magic_formula[compact]

## SIEGFRIEDS ##
siegfrieds = siegfrieds_tmp[0:siegfried_stocks]
Siegfrieds = siegfrieds[compact]

## TRIPLE SORT ##
triple_sort = triple_sort_tmp[0:triple_sort_stocks]
Triple_Sort = triple_sort[compact]

## DOUBLE SORT + Momentum ##
double_sort_mom = double_sort_mom[0:double_sort_mom_stocks]
Double_Sort_Mom = double_sort_mom[compact]

# %%
company('SJR')
# Out:
#     Börsdata ID Company  Volume     Yahoo Last Report  EV/EBIT   Tick  \
# 80          343     SJR    0.76  SJR-B.ST  2021-08-20    13.71  SJR B
#
#        Industry         List Country  Return 1y  Return 6m  Return 3m  \
# 80  Outsourcing  First North  Sweden       0.68       0.39       0.26
#
#     Total Equity   FCF  ROE  F-Score  Volatility  Market Cap  ROC  \
# 80         59.10 19.50 0.36     6.00       38.34      422.65 1.57
#
#     Tot. Assets  Gross profit  Assets Turn  P/FCF Info - Ticker.1  Yield  \
# 80       123.50        144.30         3.01  21.67           SJR B   0.05
#
#      P/E  P/S  P/B       Sector  FCFROE  GPA  EA ret  EA ret std  \
# 80 19.84 1.14 7.15  Industrials    0.33 1.17    0.00        0.07
#
#     1 Year Volatility  1 Year MAD  Ret ID  Beta  EA Volatility  3m Rank  \
# 80               0.35        0.30   -0.13  0.68           0.43    91.00
#
#     6m Rank  1y Rank  EA Rank  EA Std Rank  Momentum Rank  P/E Rank  P/B Rank  \
# 80   105.00   130.00   203.00       202.00          94.50     95.00    328.00
#
#     P/S Rank  P/FCF Rank  EV/EBIT Rank  Yield Rank  ROE Rank  ROC Rank  \
# 80     84.00      112.00         67.00       12.00     16.00      5.00
#
#     FCFROE Rank  GPA Rank  Assets Turn Rank  Quality Rank  Value Rank  \
# 80        54.00      8.00              6.00          2.00       77.00
#
#     Magic Formula  Siegfrieds  Triple Sort  Double Sort
# 80          18.00      139.00        13.00        20.00

# %% [markdown]
# ## Print Stock Selection

# %%
#Triple_Sort 
th_props = [
  ('font-size', '14px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'Black'),
  ('background-color', '#f7f7f9')
  ]
# Set CSS properties for td elements in dataframe
td_props = [('font-size', '12px'), ('text-align', 'center')]
#set caption props
caption_props = [('color', 'black'),('font-size', '22px'),
        ("text-align", "center"),
        ('font-weight', 'bold')]
# Set table styles
styles = [
    dict(selector="th", props=th_props),
    dict(selector="td", props=td_props),
    dict(selector="caption", props=caption_props)
]
Triple_Sort.index = range(1, len(Triple_Sort)+1)
Triple_Sort_view = (Triple_Sort.style.apply(lambda x: ['background: lightgreen' if x.name in range(1, 10+1) 
                              else '' for i in x], axis=1).set_table_styles(styles)
                 .format({'1 Year Volatility': "{:.1%}"})
                 .set_caption("Gestalt"))
Triple_Sort_view
# Out:
# <style  type="text/css" >
#     #T_390e56f0_3986_11ec_8f78_8c859039bca2 th {
#           font-size: 14px;
#           text-align: center;
#           font-weight: bold;
#           color: Black;
#           background-color: #f7f7f9;
#     }    #T_390e56f0_3986_11ec_8f78_8c859039bca2 td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_390e56f0_3986_11ec_8f78_8c859039bca2 caption {
#           color: black;
#           font-size: 22px;
#           text-align: center;
#           font-weight: bold;
#     }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row0_col0 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row0_col1 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row0_col2 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row0_col3 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row0_col4 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row0_col5 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row0_col6 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row0_col7 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row0_col8 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row1_col0 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row1_col1 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row1_col2 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row1_col3 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row1_col4 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row1_col5 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row1_col6 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row1_col7 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row1_col8 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row2_col0 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row2_col1 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row2_col2 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row2_col3 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row2_col4 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row2_col5 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row2_col6 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row2_col7 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row2_col8 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row3_col0 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row3_col1 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row3_col2 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row3_col3 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row3_col4 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row3_col5 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row3_col6 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row3_col7 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row3_col8 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row4_col0 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row4_col1 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row4_col2 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row4_col3 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row4_col4 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row4_col5 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row4_col6 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row4_col7 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row4_col8 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row5_col0 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row5_col1 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row5_col2 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row5_col3 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row5_col4 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row5_col5 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row5_col6 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row5_col7 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row5_col8 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row6_col0 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row6_col1 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row6_col2 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row6_col3 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row6_col4 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row6_col5 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row6_col6 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row6_col7 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row6_col8 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row7_col0 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row7_col1 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row7_col2 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row7_col3 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row7_col4 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row7_col5 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row7_col6 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row7_col7 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row7_col8 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row8_col0 {
#             background:  lightgreen;
#         }    #T_390e56f0_3986_11ec_8f78_8c859039bca2row8_col1 {
#             background:  lightgreen;
#         }    #T_390e56f0_398

# %%
th_props = [
  ('font-size', '14px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'Black'),
  ('background-color', '#f7f7f9')
  ]
# Set CSS properties for td elements in dataframe
td_props = [('font-size', '12px'), ('text-align', 'center')]
#set caption props
caption_props = [('color', 'black'),('font-size', '22px'),
        ("text-align", "center"),
        ('font-weight', 'bold')]
# Set table styles
styles = [
    dict(selector="th", props=th_props),
    dict(selector="td", props=td_props),
    dict(selector="caption", props=caption_props)
]
Momentum.index = range(1,len(Momentum)+1)
Momentum_view = (Momentum.style.apply(lambda x: ['background: lightgreen' if x.name in range(1,10+1) 
                              else '' for i in x], axis=1).set_table_styles(styles).format({'1 Year Volatility': "{:.1%}"})
                 .set_caption("Focused Momentum"))
Momentum_view
# Out:
# <style  type="text/css" >
#     #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2 th {
#           font-size: 14px;
#           text-align: center;
#           font-weight: bold;
#           color: Black;
#           background-color: #f7f7f9;
#     }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2 td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2 caption {
#           color: black;
#           font-size: 22px;
#           text-align: center;
#           font-weight: bold;
#     }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row0_col0 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row0_col1 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row0_col2 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row0_col3 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row0_col4 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row0_col5 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row0_col6 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row0_col7 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row1_col0 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row1_col1 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row1_col2 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row1_col3 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row1_col4 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row1_col5 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row1_col6 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row1_col7 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row2_col0 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row2_col1 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row2_col2 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row2_col3 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row2_col4 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row2_col5 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row2_col6 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row2_col7 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row3_col0 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row3_col1 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row3_col2 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row3_col3 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row3_col4 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row3_col5 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row3_col6 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row3_col7 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row4_col0 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row4_col1 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row4_col2 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row4_col3 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row4_col4 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row4_col5 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row4_col6 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row4_col7 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row5_col0 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row5_col1 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row5_col2 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row5_col3 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row5_col4 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row5_col5 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row5_col6 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row5_col7 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row6_col0 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row6_col1 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row6_col2 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row6_col3 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row6_col4 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row6_col5 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row6_col6 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row6_col7 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row7_col0 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row7_col1 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row7_col2 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row7_col3 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row7_col4 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row7_col5 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row7_col6 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row7_col7 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row8_col0 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row8_col1 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row8_col2 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row8_col3 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row8_col4 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row8_col5 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row8_col6 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row8_col7 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row9_col0 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_3994_11ec_8f78_8c859039bca2row9_col1 {
#             background:  lightgreen;
#         }    #T_1bc5f5ea_399

# %%
company('Evolution')
# Out:
#      Börsdata ID    Company  Volume   Yahoo Last Report  EV/EBIT Tick  \
# 282          750  Evolution  954.01  EVO.ST  2021-07-21    64.62  EVO
#
#                Industry       List Country  Return 1y  Return 6m  Return 3m  \
# 282  Gambling & Casinos  Large Cap  Sweden       1.58       0.40      -0.06
#
#      Total Equity      FCF  ROE  F-Score  Volatility  Market Cap  ROC  \
# 282     31,151.86 3,230.02 0.14     4.00       53.86  312,460.41 0.16
#
#      Tot. Assets  Gross profit  Assets Turn  P/FCF Info - Ticker.1  Yield  \
# 282    36,150.66      6,610.48         0.23  96.74             EVO   0.00
#
#       P/E   P/S   P/B             Sector  FCFROE  GPA  EA ret  EA ret std  \
# 282 69.29 37.33 10.03  Consumer Durables    0.10 0.18    0.00        0.04
#
#      1 Year Volatility  1 Year MAD  Ret ID  Beta  EA Volatility  3m Rank  \
# 282               0.47        0.43   -0.06  1.65           0.62   237.00
#
#      6m Rank  1y Rank  EA Rank  EA Std Rank  Momentum Rank  P/E Rank  \
# 282    75.00    28.00   164.00       164.00         105.00    184.00
#
#      P/B Rank  P/S Rank  P/FCF Rank  EV/EBIT Rank  Yield Rank  ROE Rank  \
# 282    275.00    307.00      174.00        208.00      135.00    111.00
#
#      ROC Rank  FCFROE Rank  GPA Rank  Assets Turn Rank  Quality Rank  \
# 282    108.00       145.00    228.00            283.00        178.00
#
#      Value Rank  Magic Formula  Siegfrieds  Triple Sort  Double Sort
# 282      216.50         172.00      230.50       178.00       207.00

# %%
#data.sort_values(by=['Momentum Rank'])

# %% [markdown]
# ## Data Illustartion

# %%
plt.scatter(data['1 Year MAD'],data['1 Year Volatility']);
plt.xlabel('MAD');
plt.ylabel('Vol');

# %%
data[['1 Year MAD', '1 Year Volatility']].corr()
# Out:
#                    1 Year MAD  1 Year Volatility
# 1 Year MAD               1.00               0.94
# 1 Year Volatility        0.94               1.00

# %%
data.sort_values(by='1 Year MAD')[['Company','1 Year MAD', '1 Year Volatility' ]]
# Out:
#                          Company  1 Year MAD  1 Year Volatility
# 489                       Axfood        0.13               0.15
# 48                 Telia Company        0.14               0.16
# 289                  ICA Gruppen        0.16               0.18
# 421                      Cloetta        0.16               0.18
# 538                          AAK        0.17               0.17
# 49                       Tele2 B        0.17               0.20
# 357                     Essity B        0.18               0.19
# 537                          ABB        0.18               0.20
# 25              Wästbygg Gruppen        0.18               0.21
# 491                       Atvexa        0.18               0.24
# 52                 Swedish Match        0.19               0.21
# 450                    Bredband2        0.20               0.23
# 96                     Securitas        0.20               0.22
# 193                        NCC B        0.20               0.22
# 497                   Assa Abloy        0.20               0.23
# 469              BillerudKorsnäs        0.21               0.22
# 299                     Holmen B        0.21               0.22
# 40                     TietoEVRY        0.21               0.23
# 306                      Hexagon        0.21               0.22
# 79                       Skanska        0.21               0.24
# 39                      Millicom        0.22               0.25
# 496                Atlas Copco A        0.22               0.23
# 523                         AFRY        0.22               0.24
# 359                   Ericsson B        0.22               0.25
# 151                         Peab        0.22               0.24
# 485                  AstraZeneca        0.22               0.23
# 150                       Pfizer        0.22                nan
# 375                        Eltel        0.22               0.25
# 106                        SCA B        0.22               0.23
# 102              Scandi Standard        0.22               0.27
# 32                    Trelleborg        0.23               0.24
# 12                       Volvo B        0.23               0.25
# 412                    Concejo B        0.23               0.31
# 321                      Getinge        0.23               0.26
# 26                           VBG        0.23               0.24
# 492                      Attendo        0.23               0.27
# 519                   Alfa Laval        0.23               0.25
# 259                           JM        0.23               0.25
# 438                    CAG Group        0.23               0.26
# 297                       Hexpol        0.23               0.25
# 115                         Saab        0.24               0.28
# 128                     Railcare        0.24               0.30
# 451                      Bravida        0.24               0.25
# 363                     Epiroc B        0.24               0.25
# 63                  Stora Enso R        0.24               0.25
# 420                  Clas Ohlson        0.24               0.28
# 294                       Humana        0.25               0.27
# 379                       Elekta        0.25               0.27
# 112                      Sandvik        0.25               0.28
# 118                    Rottneros        0.25               0.28
# 181                        Nobia        0.25               0.29
# 223                         Lyko        0.25               0.28
# 56                       Sweco B        0.25               0.31
# 516                      Autoliv        0.25               0.27
# 251                  Karo Pharma        0.25               0.28
# 540                       Traton        0.25               0.26
# 292                  Husqvarna B        0.25               0.28
# 281                    Indutrade        0.25               0.27
# 78                         SKF B        0.25               0.27
# 408                 Coor Service        0.25               0.29
# 178                       Nolato        0.25               0.27
# 42                         Thule        0.26               0.30
# 349                    Fagerhult        0.26               0.28
# 374                 Electrolux B        0.26               0.28
# 180                       Nobina        0.26               0.29
# 303             Hennes & Mauritz        0.26               0.29
# 517                       Alimak        0.26               0.28
# 252                       Karnov        0.26               0.28
# 500                   Arla Plast        0.26               0.31
# 238                       Lindab        0.26               0.29
# 314                 Greater Than        0.27               0.31
# 319              Götenehus Group        0.27               0.28
# 255                         Kabe        0.27               0.31
# 82                    SinterCast        0.27               0.31
# 458                 Bokusgruppen        0.27               0.32
# 229                       Loomis        0.28               0.30
# 512                        Ambea        0.28               0.30
# 391                      Dometic        0.28               0.29
# 136                ProfilGruppen        0.28               0.33
# 74      Swedish Orphan Biovitrum        0.28               0.38
# 482                  Balco Group        0.28               0.31
# 509                      Addnode        0.28               0.32
# 479                  Beijer Alma        0.28               0.30
# 185                         NIBE        0.28               0.31
# 272                       Inwido        0.29               0.30
# 77                       SkiStar        0.29               0.32
# 390                         Doro        0.29               0.32
# 174                 Nordic Paper        0.29               0.29
# 198                     Mycronic        0.29               0.33
# 320           GHP Specialty Care        0.29               0.32
# 373                   Embellence        0.29               0.31
# 503                         Arjo        0.29               0.33
# 343                      Firefly        0.29               0.32
# 439                  Byggpartner        0.29               0.32
# 478                   Beijer Ref        0.30               0.31
# 80                           SJR        0.30               0.35
# 291                I.A.R Systems        0.30               0.35
# 387                         Duni        0.30               0.34
# 353                        eWork        0.30               0.34
# 430                      Cavotec        0.30               0.34
# 475                       Besqab        0.30               0.31
# 141           Precise Biometrics        0.30               0.34
# 202                    Midsona B        0.30               0.34
# 224                Lundin Energy        0.30               0.34
# 334                Fenix Outdoor        0.30               0.31
# 535                   AcadeMedia        0.30               0.35
# 457                      Boliden        0.30               0.31
# 465                      BioGaia        0.30               0.38
# 184                Nilörngruppen        0.30               0.40
# 411                   Concentric        0.31               0.37
# 346                 Fasadgruppen        0.31               0.33
# 463                      Biotage        0.31               0.33
# 90                       Senzime        0.31               0.39
# 179                        Nokia        0.31               0.43
# 336                  Ferronordic        0.31               0.35
# 398                     Dedicare        0.31               0.36
# 436                      Camurus        0.31               0.36
# 65                        SSAB A        0.32               0.35
# 385                 Dustin Group        0.32               0.38
# 138                       Pricer        0.32               0.37
# 4                    ZetaDisplay        0.32               0.43
# 117                     RugVista        0.32               0.36
# 536            Absolent Air Care        0.32               0.34
# 73                     Softronic        0.32               0.36
# 521                Alcadon Group        0.32               0.38
# 310                        Hanza        0.32               0.38
# 453                   Björn Borg        0.32               0.36
# 215                       MedCap        0.32               0.35
# 155                    Proact IT        0.32               0.37
# 212                    Mekonomen        0.32               0.36
# 470                        Bilia        0.32               0.45
# 190       Nordic Entertainment B        0.33               0.36
# 507                     AQ Group        0.33               0.36
# 244                       KnowIT        0.33               0.37
# 18                     Vitrolife        0.33               0.37
# 473                      Betsson        0.33               0.36
# 200                      Munters        0.33               0.37
# 172         Nordic Waterproofing        0.33               0.35
# 312                      Gränges        0.33               0.38
# 94                        Semcon        0.33               0.37
# 242                  Lagercrantz        0.33               0.35
# 386                        Duroc        0.33               0.38
# 66                       Serneke        0.33               0.44
# 97                        Sectra        0.33               0.38
# 427                  CellaVision        0.33               0.37
# 93                  Sensys Gatso        0.33               0.39
# 44                    Tethys Oil        0.34               0.36
# 125       RaySearch Laboratories        0.34               0.37
# 227                  Lundin Gold        0.34               0.35
# 19                Vitec Software        0.34               0.36
# 140                       Prevas        0.34               0.37
# 459                       Nimbus        0.34               0.38
# 361    Electrolux Professional B        0.34               0.38
# 173                      Novotek        0.34               0.39
# 347                     Ferroamp        0.34               0.39
# 527                      Addtech        0.34               0.37
# 331            Formpipe Software        0.34               0.41
# 264                       I-Tech        0.34               0.43
# 460                      Byggmax        0.34               0.37
# 442                       Bulten        0.35               0.37
# 298                      Hövding        0.35               0.41
# 239                     LeoVegas        0.35               0.40
# 508                   Africa Oil        0.35               0.36
# 214                    Medicover        0.35               0.38
# 476             Bergman & Beving        0.35               0.36
# 484                B3 Consulting        0.35               0.38
# 368                         Enea        0.35               0.38
# 201                        MTG B        0.35               0.40
# 525                Africa Energy        0.35               0.39
# 207               Momentum Group        0.35               0.38
# 30                   Troax Group        0.35               0.38
# 231                    LMK Group        0.35               0.43
# 302                 HMS Networks        0.35               0.39
# 452            Boule Diagnostics        0.36               0.38
# 33                     Transtema        0.36               0.40
# 483                   Bactiguard        0.36               0.38
# 400                  CTT Systems        0.36               0.39
# 156                          OX2        0.36               0.38
# 278                     Instalco        0.36               0.39
# 123                      Rejlers        0.36               0.37
# 232                      Lipidor        0.36               0.40
# 304                       Haldex        0.36               0.41
# 50                     Systemair        0.37               0.42
# 187                     New Wave        0.37               0.39
# 404                        C-RAD        0.37               0.42
# 142                       Poolia        0.37               0.44
# 490                      Awardit        0.37               0.42
# 444                    BTS Group        0.37               0.47
# 378                     Elanders        0.37               0.40
# 443                        Bufab        0.37               0.40
# 116               Revolutionrace        0.38               0.42
# 166                          OEM        0.38               0.42
# 139                      Profoto        0.38               0.46
# 467                    Bioinvent        0.38               0.42
# 262                      Invisio        0.38               0.41
# 195                     Nanoform        0.38               0.45
# 186                        Nexam        0.38               0.44
# 53                      Studsvik        0.38               0.44
# 54                     Svedbergs        0.38               0.41
# 288                      Iconovo        0.38               0.46
# 188                  Net Insight        0.38               0.44
# 8                        Xintela        0.38               0.44
# 311           Guard Therapeutics        0.39               0.46
# 158                     OssDsign        0.39               0.47
# 101                     Sdiptech        0.39                nan
# 61                      Storytel        0.39               0.45
# 477           Beijer Electronics        0.39               0.43
# 5                Xvivo Perfusion        0.39               0.41
# 498                Aspire Global        0.39               0.41
# 480                     BE Group        0.39               0.46
# 182                     Nederman        0.39               0.41
# 76                   Sleep Cycle        0.39               0.42
# 422                   Cint Group        0.39               0.45
# 418           Corline Biomedical        0.40               0.42
# 419                    Clavister        0.40               0.47
# 199                      Medivir        0.40               0.54
# 159                        Orexo        0.40               0.44
# 127                     Raketech        0.40               0.45
# 494         Alligator Bioscience        0.40               0.54
# 130                      Q-Linea        0.40               0.43
# 169        Oasmia Pharmaceutical        0.40               0.43
# 189                         Nepa        0.40               0.48
# 148                 Pierce Group        0.40               0.44
# 325                         GARO        0.41               0.45
# 171              NextCell Pharma        0.41               0.49
# 257          Josemaria Resources        0.41               0.46
# 17                       Veoneer        0.41               0.62
# 397                    Dignitana        0.41               0.45
# 371                  Empir Group        0.41               0.50
# 284                   Implantica        0.41               0.48
# 495                  Actic Group        0.41               0.46
# 434                     Capacent        0.41               0.68
# 454                        Boozt        0.42               0.47
# 417                     Clemondo        0.42               0.55
# 226                Lundin Mining        0.42               0.45
# 488                      aXichem        0.42               0.46
# 228               Lucara Diamond        0.42               0.47
# 203            Micro Systemation        0.42               0.52
# 248                      Kindred        0.42               0.45
# 176                         NOTE        0.42               0.45
# 237                        LIDDS        0.42               0.51
# 95                Sedana Medical        0.42               0.49
# 369                    Endomines        0.42               0.55
# 354                    Evolution        0.43               0.47
# 152          Paradox Interactive        0.43               0.53
# 472                    BHG Group        0.43               0.49
# 129                        Qliro        0.43               0.44
# 372                     Embracer        0.43               0.46
# 285                    Immunicum        0.43               0.51
# 518                      AddLife        0.43               0.47
# 137                        Probi        0.43               0.49
# 337                  FM Mattsson        0.43               0.47
# 279                       Infrea        0.43               0.48
# 383                     Ecoclime        0.43               0.49
# 290             Infant Bacterial        0.43               0.53
# 260                       Jetpak        0.43               0.46
# 133                     QleanAir        0.43               0.49
# 220              MAG Interactive        0.44               0.47
# 326                     Gapwaves        0.44               0.48
# 380          Egetis Therapeutics        0.44               0.52
# 263                    Intervacc        0.44               0.45
# 455                  Bonesupport        0.44               0.81
# 401                 Catena Media        0.44               0.52
# 466                    BioArctic        0.44               0.67
# 206                      Mentice        0.44               0.50
# 317                  Smart Wires        0.44                nan
# 64                  Starbreeze B        0.44               0.54
# 219                  Maha Energy        0.44               0.51
# 468                    BIMobject        0.44               0.54
# 135                   Permascand        0.44               0.48
# 20                  Vimian Group        0.44               0.47
# 210                 Mildef Group        0.44               0.51
# 270      International Petroleum        0.44               0.46
# 124                       Readly        0.45               0.49
# 296                   Hexatronic        0.45               0.51
# 531               Ascelia Pharma        0.45               0.53
# 449                 Bergs Timber        0.45               0.50
# 205                Moberg Pharma        0.45               0.55
# 143                    Polygiene        0.45               0.54
# 504              Arise Windpower        0.45               0.47
# 437      Calliditas Therapeutics        0.45               0.65
# 313            Green Landscaping        0.45               0.51
# 85                Scandic Hotels        0.45               0.55
# 364                   Eolus Vind        0.45               0.48
# 474            Better Collective        0.46               0.51
# 268           IRLAB Therapeutics        0.46               0.62
# 330               Fractal Gaming        0.46               0.69
# 27                     Waystream        0.46               0.54
# 499         Artificial Solutions        0.46               0.54
# 324                 Gaming Corps        0.46               0.57
# 38                         Tobii        0.46               0.52
# 160                  OrganoClick        0.46               0.56
# 37                    Toleranzia        0.46               0.57
# 104            Scandion Oncology        0.46               0.56
# 208                         Mips        0.46               0.51
# 75                      ShaMaran        0.47               0.47
# 3                         Ziccum        0.47               0.51
# 164                    OncoZenge        0.47                nan
# 301              Hansa Biopharma        0.47               0.53
# 305                      Hexicon        0.47               0.51
# 327             G5 Entertainment        0.47               0.53
# 282        InDex Pharmaceuticals        0.47               0.57
# 209                      Minesto        0.47               0.52
# 539              AAC Clyde Space        0.47               0.52
# 254                        Kambi        0.47               0.60
# 265            ITAB Shop Concept        0.47               0.61
# 407                  Copperstone        0.47               0.53
# 307                       Hemnet        0.47               0.58
# 67             Sprint Bioscience        0.47               0.72
# 235            Lime Technologies        0.47               0.53
# 191                  Nelly Group        0.47               0.53
# 10                 XANO Industri        0.47               0.49
# 108                      Saxlund        0.47               0.54
# 365                   Enzymatica        0.48               0.59
# 111                      Saniona        0.48               0.55
# 91                     Smart Eye        0.48               0.52
# 395                       DistIT        0.48               0.52
# 22                 Vicore Pharma        0.49               0.59
# 83                         Sinch        0.49               0.53
# 211                    Midsummer        0.49               0.64
# 157                        Ovzon        0.50               0.52
# 9               Xbrane Biopharma        0.50               0.55
# 541                       2cureX        0.50               0.54
# 351                      Exsitec        0.50               0.57
# 41                    Thunderful        0.50               0.76
# 261            JonDeTech Sensors        0.51               0.58
# 240                    Lifeclean        0.51                nan
# 29                        Urb-it        0.51               0.59
# 89                    Stillfront        0.51               0.57
# 514              AlzeCure Pharma        0.51               0.63
# 92           Scandinavian Enviro        0.52               0.58
# 167                    Odd Molly        0.52               0.58
# 533                        Acast        0.52               0.52
# 113             SaltX Technology        0.52               0.65
# 246                Klaria Pharma        0.52               0.57
# 530                     AcouSort        0.52               0.56
# 345                  Filo Mining        0.52               0.75
# 6                  Xspray Pharma        0.52               0.95
# 68                        Speqta        0.52               0.58
# 110                          SAS        0.52               0.74
# 196                       Nanexa        0.52               0.73
# 362                      Episurf        0.53               0.61
# 399                       Cyxone        0.53               0.60
# 35                  TradeDoubler        0.53               0.60
# 149                  Pharmacolog        0.54               0.63
# 471                   BICO Group        0.54               0.60
# 2                        ZignSec        0.54               0.60
# 344            Fingerprint Cards        0.54               0.73
# 98                    Swedencare        0.54               0.55
# 122                   Re:NewCell        0.54               0.60
# 57              Surgical Science        0.54               0.62
# 230                 Lohilo Foods        0.55               0.72
# 392               Diamyd Medical        0.55               0.63
# 376                         Elos        0.55               0.76
# 253                      Kancera        0.55               0.73
# 60              Swedish Stirling        0.55               0.65
# 194                   NCAB Group        0.55               0.59
# 81         Sivers Semiconductors        0.55               0.59
# 462                      Biovica        0.55               0.63
# 367                      EnQuest        0.55               0.58
# 388                      Desenio        0.56               0.97
# 329                    Freja eID        0.56               0.66
# 7                      XMReality        0.56               0.64
# 435                    Cantargia        0.56               0.67
# 358               Enorama Pharma        0.56               0.70
# 341               Flexion Mobile        0.56               0.62
# 0                          Zwipe        0.57               0.61
# 316                     GomSpace        0.57               0.66
# 147                   PiezoMotor        0.57               0.77
# 105                      Scibase        0.57               0.67
# 36                         Tourn        0.57               0.67
# 323               Generic Sweden        0.57               0.64
# 47                       Teqnion        0.57               0.59
# 286                    Immunovia        0.57               0.73
# 415                      Climeon        0.57               0.73
# 269                      Irisity        0.58               0.64
# 132                  Qiiwi Games        0.58               0.71
# 134                   Physitrack        0.58               0.62
# 72                SolTech Energy        0.58               0.60
# 103                 Scout Gaming        0.59               0.64
# 267               Isofol Medical        0.59               0.71
# 447             Brilliant Future        0.59               0.70
# 461                    Bio-Works        0.59               0.65
# 145                   ProstaLund        0.59               1.01
# 322                      Genovis        0.60               0.72
# 414        Clinical Laserthermia        0.61               0.77
# 197                 myFC Holding        0.62               0.72
# 409                    CombiGene        0.62               1.17
# 222              Media and Games        0.62               0.64
# 153                    PowerCell        0.62               0.64
# 131                        QLife        0.63               0.72
# 283              Impact Coatings        0.63               0.67
# 1                         Zordix        0.63               0.69
# 162        OptiCept Technologies        0.63               0.71
# 381                Enad Global 7        0.63               0.76
# 394           Divio Technologies        0.64               0.75
# 276                     Integrum        0.65               0.76
# 532                     Acconeer        0.65               0.68
# 216                     Mavshack        0.65               0.78
# 293                 Humble Group        0.65               0.69
# 70                   SpectraCure        0.65               0.98
# 393                  Dlaboratory        0.66               0.70
# 71                         Sozap        0.67               0.79
# 526                     Advenica        0.67               0.78
# 366                        Eniro        0.67               1.00
# 69                   SpectrumOne        0.67               0.79
# 308                       Hedera        0.67               1.04
# 338                    FluoGuide        0.68               0.80
# 520               Alelion Energy        0.68               0.75
# 183                  Nitro Games        0.68               0.95
# 428                Cortus Energy        0.69               0.82
# 274                       Invajo        0.70               0.80
# 502                      AroCell        0.70               0.98
# 534                       Acarix        0.70               0.84
# 486                       Azelio        0.71               0.78
# 340                     Flexqube        0.71               0.82
# 87                 Safello Group        0.71               0.78
# 271                       Inzile        0.71               0.86
# 511                    Amniotics        0.72               0.86
# 382               Eco Wave Power        0.72               1.30
# 440                     Bambuser        0.73               0.80
# 356                       Etrion        0.74               1.77
# 370                    Emplicure        0.74               0.78
# 46                      TerraNet        0.74               0.84
# 424                  Cell Impact        0.74               0.76
# 233                     Linkfire        0.74               0.90
# 377         Elicera Therapeutics        0.75               0.89
# 413                    ChemoTech        0.77               0.81
# 448                     Brighter        0.77               0.99
# 266                  ISR Holding        0.77               0.97
# 14                   Veg of Lund        0.79               0.89
# 165                 Oncopeptides        0.79               1.73
# 402                   CoinShares        0.81               0.86
# 154                      Papilly        0.82               1.07
# 243               LL Lucky Games        0.84               0.90
# 355  Euroafrica Digital Ventures        0.85                nan
# 352           ExpreS2ion Biotech        0.85               0.95
# 426                   Crunchfish        0.86               0.98
# 429                         CDON        0.86               0.97
# 445                 Goobit Group        0.86               0.94
# 328                         Fuud        0.86               1.10
# 15                       Vo2 Cap        0.88               1.08
# 339                     Fluicell        0.90               0.94
# 120                  Rizzo Group        0.91               1.20
# 515        Allarity Therapeutics        0.92               1.24
# 177              Nord Insuretech        0.93               1.40
# 425                  checkin.com        0.95               1.30
# 464                    Biosergen        0.95                nan
# 416                 Clean Motion        0.99               1.66
# 389                         Doxa        1.02               1.57
# 11                 Wyld Networks        1.07                nan
# 506                Arcane Crypto        1.09               1.29
# 217                       Mantex        1.13               2.13
# 277       Intellego Technologies        1.14               1.35
# 119        RNB Retail and Brands        1.19               1.65
# 524                     AegirBio        1.20               1.58
# 204                 Moment Group        1.25               2.54
# 168         Online Brands Nordic        1.38               2.41
# 318            Gaming Innovation        1.38               2.35
# 213               Modern Ekonomi        1.52                nan

# %%
plt.scatter(data['Momentum Rank'],data['EA Rank']);
plt.xlabel('Momentum Rank');
plt.ylabel('EA Rank');

# %% [markdown]
# #### Correlation heat map between selected Ranks

# %%
corr = data[['3m Rank', '6m Rank', '1y Rank' , 'Momentum Rank', 'EA Rank', 'EA Std Rank']].corr()

#corr = data[['Quality Rank', 'Value Rank', 'Momentum Rank', 'EA Std Rank']].corr()

# %%
corr
# Out:
#                3m Rank  6m Rank  1y Rank  Momentum Rank  EA Rank  EA Std Rank
# 3m Rank           1.00     0.75     0.55           0.86     0.39         0.40
# 6m Rank           0.75     1.00     0.70           0.89     0.30         0.31
# 1y Rank           0.55     0.70     1.00           0.78     0.18         0.19
# Momentum Rank     0.86     0.89     0.78           1.00     0.58         0.59
# EA Rank           0.39     0.30     0.18           0.58     1.00         0.98
# EA Std Rank       0.40     0.31     0.19           0.59     0.98         1.00

# %%
def Optimize_Portfolio(data ,risk_free = 0, objective = 'Kelly'):
    

    #cov_fit = LedoitWolf().fit(data)
    #cov = cov_fit.covariance_
    
    if objective == 'Kelly':  
        #ret = (data).prod()**(1/len(data)) - 1 #cagr
        ret = (data-1).mean()
        cov = data.cov().to_numpy()
        #need smaller step size
        num_assets = ret.shape[0]
        args = (ret, cov,risk_free)
        constraints = ({'type':'ineq', 'fun': lambda x: x},#all elements greater than one
                      {'type':'ineq', 'fun': lambda x: 1 - np.sum(x)}) # sum <= 1
                      #{'type': 'eq', 'fun': lambda x: np.sum(x) - 1})  
        
        
        result = sco.minimize(kelly_objective, num_assets*[1./num_assets,], args=args, 
                                  method='SLSQP', constraints=constraints) 
        
    elif objective == 'Sharpe':
        ret = (data-1).mean() 
        cov = data.cov().to_numpy()
        
        num_assets = ret.shape[0]
        args = (ret, cov,risk_free)
        constraints = ({'type':'ineq', 'fun': lambda x: x},#all elements greater than one
                  #{'type':'ineq', 'fun': lambda x: 1 - np.sum(x)} # sum <= 1
                  {'type': 'eq', 'fun': lambda x: np.sum(x) - 1})  
        result = sco.minimize(sharpe_objective, num_assets*[1./num_assets,], args=args, 
                              method='SLSQP', constraints=constraints)
    
    elif objective == 'Max Div':
        num_assets = len(data.columns)
        cov = data.cov().to_numpy()
        args = (cov)
        constraints = ({'type':'ineq', 'fun': lambda x: x},#all elements greater than one
                  #{'type':'ineq', 'fun': lambda x: 1 - np.sum(x)} # sum <= 1
                  {'type': 'eq', 'fun': lambda x: np.sum(x) - 1}) 
        
        result = sco.minimize(calc_diversification_ratio, num_assets*[1./num_assets,], args=args, 
                              method='SLSQP', constraints=constraints)
        
        
    
    return (result)

def kelly_objective(weights,ret, cov, risk_free = 0):
    
    #kelly_ret = port_ret(weights, ret)
    kelly_ret = port_ret(weights, ret) - port_var(weights, cov)/2
    
    obj = -(kelly_ret)
    
    return(obj)

def sharpe_objective(weights,ret, cov, risk_free = 0):
    ret = port_ret(weights, ret)
    std = port_var(weights, cov)**(1/2)
    
    obj = - (ret/std)
    return(obj)


def port_var(weights, cov):
    var = weights.dot(cov).dot(weights)
    return(var)

def port_ret(weights, ret, risk_free = 0):
    #needs to be array
    ret = ret - risk_free
    port_ret = weights.dot(ret)
    return(port_ret)

def risk_parity(data):
    vol = np.log((data)).std()

    sum_vol = 0
    for i in range(len(vol)):
        sum_vol =sum_vol + (1/vol[i])
    
    weight = []
    for i in range(len(vol)):
        w = (1/vol[i])/(sum_vol)
        weight.append(w)
   
    weight = [round(num, 2) for num in weight]
    return(weight)


def calc_diversification_ratio(weights, cov):
    # average weighted vol
    w_vol = np.dot(np.sqrt(np.diag(cov)), weights.T)
    # portfolio vol
    port_vol = np.sqrt(port_var(weights, cov))
    
    diversification_ratio = w_vol/port_vol
    # return negative for minimization problem (maximize = minimize -)
    return -diversification_ratio

# %%
## calculate optimal weights based on correlations between the factors

result = Optimize_Portfolio(data[['Quality Rank', 'Value Rank', 'Momentum Rank', 'EA Std Rank']], objective="Max Div")

# %%
result['x'].round(2)
# Out:
# array([0.07, 0.39, 0.25, 0.29])
