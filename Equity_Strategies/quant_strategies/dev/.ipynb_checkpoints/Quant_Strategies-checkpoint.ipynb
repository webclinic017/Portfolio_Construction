# %% [markdown]
# # Quantitative Stock Selection

# %%
import yfinance as yf 

import pandas as pd
from matplotlib import pylab as plt
import numpy as np
from datetime import datetime
import math
from time import sleep
import quandl
import seaborn as sns
import sys
from scipy.stats import norm
from sklearn.linear_model import LinearRegression
import sys
from scipy.stats import norm
import ezodf
import scipy.optimize as sco
import scipy
import re
import os.path

# %% [markdown]
# ## Functions

# %%
# FUNCTIONS FOR VIEWING SINGLE COMPANY RANKINGS 

def company(company):
    for i in data['Company']:
        if company in i or company in i.lower():
            return data.loc[data['Company'] == i]
    print('No company found')
    
def Company(company):
    for i in data['Company']:
        if company in i or company in i.lower():
            stock = data.loc[data['Company'] == i]
            stock = stock[compact]
            return stock
    print('No company found')

# %%
def mod_Z_score(data):
    mean = np.mean(data.iloc[:-1])
    deviation_from_med = np.array(data.iloc[:-1]) - mean
    MAD = np.mean(np.abs(deviation_from_med))
    mod_Z = (data[-1:] - mean)/(MAD * 1.4826)
    return mod_Z

# %% [markdown]
# ## Data Import and Wrangling

# %%
# IMPORT LATEST DATA 

path_import = "equity_data/Borsdata_2021-09-10.xlsx"
data_tmp = pd.read_excel(path, sheet_name="Export")
data_tmp = data_tmp[1:]

data_tmp = data_tmp.rename({'Performance - Perform. 3m' : 'Return 3m','Performance - Perform. 6m' : 'Return 6m',
                            'Performance - Perform. 1y' : 'Return 1y',
                            'Div. Yield - Current': 'Yield', 
                            'Total Equity  - Millions':'Total Equity', 'FCF - Millions': 'FCF','ROE - Current':'ROE',
                            'Volatility - St.Dev. 100d':'Volatility','Market Cap - Current': 'Market Cap', 
                            'ROC - Current':'ROC', 'Tot. Assets - Millions':'Tot. Assets', 
                            'Gross profit - Millions':'Gross profit', 'Assets Turn - Current': 'Assets Turn',
                            'P/FCF - Current':'P/FCF', 'P/E - Current':'P/E', 'P/S - Current':'P/S',
                            'P/B - Current':'P/B','EV/EBIT - Current':'EV/EBIT',
                            'Info - Country' : 'Country','F-Score - Point':'F-Score',
                            'Info - List' : 'List', 'Info - Sector' : 'Sector', 'Info - Industry' : 'Industry',
                            'Info - Ticker' : 'Tick', 'Info - Yahoo':'Yahoo', 'Info - Last Report': 'Last Report',
                           'Volume - Average 50d Mill' : 'Volume'}, axis=1)

# FORMAT FOR VIEWING PLEASURE
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.options.display.float_format = "{:,.2f}".format

# %%
# MAKE NUMBERS FLOATS 

data_tmp['Market Cap'] = data_tmp['Market Cap'].replace(',', '') # remove , as 1000 separator

param_list = ['P/E', 'EV/EBIT', 'P/FCF', 'P/S', 'P/B', 'Assets Turn', 'Gross profit', 'Tot. Assets', 'ROC', 'Yield', 'Market Cap', 'Volatility',
        'F-Score', 'ROC', 'ROE', 'FCF', 'Total Equity', 
        'Return 3m', 'Return 6m', 'Return 1y']

for i in param_list: 
    data_tmp[i] = pd.to_numeric(data_tmp[i]) # make every number numeric


data_tmp['FCFROE'] = data_tmp['FCF']/data_tmp['Total Equity'] # calc FCFROE
data_tmp['GPA'] = data_tmp['Gross profit']/data_tmp['Tot. Assets']

# %%
# Manage negativ equity

data_tmp.loc[(data_tmp['Total Equity'] < 0), ['ROE', 'FCFROE', 'P/B']] = np.nan

# %%
### FILTER DATA FOR VOLUME, LIST AND MARKET CAP

#data_tmp = data_tmp.loc[data_tmp['Market Cap'] > 400] #Market cap filter


data_tmp = data_tmp.loc[ (data_tmp['List'] != 'Spotlight') 
                        & (data_tmp['List'] != 'NGM')]

#Volume Filter
data_tmp = data_tmp.loc[data_tmp['Volume'] > 0.5] 

# Set to dattime
data_tmp['Last Report'] = pd.to_datetime(data_tmp['Last Report'])

#set new index
data_tmp.index = range(len(data_tmp.index))

# %%
print("Companies in data: ",len(data_tmp))
print("Missing Report Dates: ",sum(data_tmp['Last Report'].isna()))
# Out:
# Companies in data:  542
# Missing Report Dates:  11

# %% [markdown]
# ## Calculate Price Based Data from Yahoo Finance

# %%
## Get PEAD
data_tmp["EA ret"] = np.nan
data_tmp["EA ret std"] = np.nan
data_tmp['1 Year Volatility'] = np.nan
data_tmp['1 Year MAD'] = np.nan
index = yf.download('^OMXSPI',start='2020-01-01', threads = False, progress = False)
index = index['Close']

error_count = 0
error_list = []

# %%
for i in range(len(data_tmp)):
    try:
        stock = yf.download(data_tmp.iloc[i]['Yahoo'],start='2020-01-01', progress = False, threads = False)
        stock = stock['Close']
        import_data = pd.concat([stock, index], axis = 1)
        import_data.columns = ['stock', 'index']
        import_data = import_data.dropna()
        
        # get index of date of report
        idx = import_data.index.get_loc(data_tmp.iloc[i]['Last Report'], method='nearest')
        EA_data = import_data.iloc[idx - 2 : idx +2 ]
        
        stock_idx = stock.index.get_loc(data_tmp.iloc[i]['Last Report'], method='nearest')
        
        EA_ret = (EA_data.pct_change().dropna()+1).cumprod().tail(1)
        pead_ret = float(EA_ret['stock'] - EA_ret['index'])
        data_tmp.loc[i,"EA ret"]= pead_ret
        data_tmp.loc[i, 'EA Volatility'] = np.log(stock.iloc[:idx]/stock.iloc[:idx].shift()).tail(60).std()*252**.5 
        #Get MAD of stock
        data_tmp.loc[i,"1 Year MAD"]= np.log(stock/stock.shift()).tail(252).mad()*252**.5*1.25
        # Get volatility of stock
        data_tmp.loc[i,"1 Year Volatility"]= np.log(stock/stock.shift()).tail(252).std()*252**.5 
       
    except:
        #data_tmp.loc[i,"EA ret"]= np.nan
        #print("ERROR! INDEX: ", i, ', TICKER: ', data_tmp.iloc[i]['Yahoo'])
        error_count = error_count + 1
        error_list.append(i)
# Out:
# 1 Failed download:
# - SDIP.ST: No data found, symbol may be delisted

# %%
### NA ANALYTICS
print("Amount of Errors: ",error_count )
print("Missing EA rets: ",sum(data_tmp["EA ret"].isna()) )
print("Missing EA volatility: ",sum(data_tmp["EA Volatility"].isna()) )
print("Missing 1 Year volatility: ",sum(data_tmp["1 Year Volatility"].isna()) )
# Out:
# Amount of Errors:  14
# Missing EA rets:  0
# Missing EA volatility:  0
# Missing 1 Year volatility:  0

# %%
## Show errors
data_tmp[data_tmp['EA ret'].isna()][['Company', 'Yahoo', 'Last Report', 'EA ret']]
# Out:
#                          Company          Yahoo Last Report  EA ret
# 11                 Wyld Networks        WYLD.ST         NaT     nan
# 45                 Tessin Nordic      TESSIN.ST         NaT     nan
# 88           Stenhus Fastigheter       SFAST.ST         NaT     nan
# 101                     Sdiptech        SDIP.ST  2021-07-23     nan
# 150                       Pfizer         PFE.ST         NaT     nan
# 164                    OncoZenge       ONCOZ.ST         NaT     nan
# 213               Modern Ekonomi          ME.ST         NaT     nan
# 240                    Lifeclean      LCLEAN.ST         NaT     nan
# 317                  Smart Wires  GOGRID-SDB.ST         NaT     nan
# 318            Gaming Innovation      GIGSEK.ST  2021-08-18     nan
# 355  Euroafrica Digital Ventures        EURA.ST         NaT     nan
# 405                Creaspac SPAC   CPAC-SPAC.ST         NaT     nan
# 464                    Biosergen      BIOSGN.ST         NaT     nan

# %% [markdown]
# ### TESTING TICKERS ONCE AGAIN, RE ENTER FAILED TICKERS BY HAND

# %%
##### TESTING TICKERS ONCE AGAIN, RE ENTER FAILED TICKERS BY HAND #####
j = None
if j != None:
    stock = yf.download(data_tmp.iloc[j]['Yahoo'],start='2020-01-01', progress = False, threads = False)
    stock = stock['Close']
    import_data = pd.concat([stock, index], axis = 1)
    import_data.columns = ['stock', 'index']
    import_data = import_data.dropna()

    # get index of date of report
    idx = import_data.index.get_loc(data_tmp.iloc[j]['Last Report'], method='nearest')
    EA_data = import_data.iloc[idx - 2 : idx +2 ]

    stock_idx = stock.index.get_loc(data_tmp.iloc[j]['Last Report'])

    EA_ret = (EA_data.pct_change().dropna()+1).cumprod().tail(1)
    pead_ret = float(EA_ret['stock'] - EA_ret['index'])
    data_tmp.loc[j,"EA ret"]= pead_ret
    data_tmp.loc[j, 'EA Volatility'] = np.log(stock.iloc[:idx]/stock.iloc[:idx].shift()).tail(60).std()*252**.5 
    #Get MAD of stock
    data_tmp.loc[j,"1 Year MAD"]= np.log(stock/stock.shift()).tail(252).mad()*252**.5*1.25
    # Get volatility of stock
    data_tmp.loc[j,"1 Year Volatility"]= np.log(stock/stock.shift()).tail(252).std()*252**.5

# %% [markdown]
# ### Handel NANs

# %%
# MANAGE NaNs and NEGATIVE EARNINGS  
# set nan to min
for i in ['Return 3m', 'Return 6m', 'Return 1y']:
    data_tmp.loc[data_tmp[i].isna() ,i] = data_tmp[i].min()
    
data_tmp.loc[data_tmp['Volatility'].isna(),'Volatility'] = data_tmp['Volatility'].median()

data_tmp.loc[data_tmp['EA ret'].isna(),'EA ret'] = data_tmp['EA ret'].median()
data_tmp.loc[data_tmp['EA Volatility'].isna(),'EA Volatility'] = data_tmp['Volatility'].median()

#Impute 100 day volatility for NANs
data_tmp.loc[data_tmp['1 Year Volatility'].isna(),'1 Year Volatility'] = data_tmp.loc[data_tmp['1 Year Volatility'].isna(),'Volatility']/100

#Impute median for NAN MAD
data_tmp.loc[data_tmp['1 Year MAD'].isna(),'1 Year MAD'] = data_tmp['1 Year MAD'].median()

# %%
## Impute EA std and calculate EA STD after everything has been imputed
data_tmp["EA ret std"] = data_tmp["EA ret"]/((data_tmp["EA Volatility"]*np.sqrt(3))/np.sqrt(252))

#Impute median for NAN EA STD
data_tmp.loc[data_tmp['EA ret std'].isna(),'EA ret std'] = data_tmp['EA ret std'].median()

# %%
### SAVE cleaned file into a CSV
save = "NO"

if save == "YES":
    data_date  = re.search(r'\d{4}-\d{2}-\d{2}', path_import)
    folder = 'clean_equity_data'
    exp_file_name = "clean_equity_data_{}".format(data_date.group(0))+ ".csv"
    data_tmp.to_csv(os.path.join(folder, exp_file_name))

# %%
### POTENTIAL PLACE FOR NAN IMPUTATION ###

# %%
####### FILTER DATA FOR SUB STRATEGIES
data_full = data_tmp.copy()
### MOMENTUM
data_mom = data_tmp.copy()
data_mom = data_mom.loc[(data_mom['Industry'] != 'Holding Companies')]
#data_mom = data_tmp.loc[(data_tmp['Sector'] != 'Financials')]

data = data_tmp.copy()
### GESTALT
data = data.loc[(data_tmp['Sector'] != 'Financials')]

# %% [markdown]
# ## MOMENTUM

# %%
# RANK ON DIFFERENT METRICS 

data_mom['3m Rank'] = data_mom['Return 3m'].rank(ascending = False)
data_mom['6m Rank'] = data_mom['Return 6m'].rank(ascending = False)
data_mom['1y Rank'] = data_mom['Return 1y'].rank(ascending = False)
data_mom['EA Rank'] = data_mom['EA ret'].rank(ascending = False)
data_mom['EA Std Rank'] = data_mom['EA ret std'].rank(ascending = False)
data_mom['Volatility Rank'] = data_mom['1 Year Volatility'].rank(ascending = True)
data_mom['MAD Rank'] = data_mom['1 Year Volatility'].rank(ascending = True)

# MOMENTUM WITH VOLATILITY
#data_mom['Momentum Rank'] = (data_mom['Return 3m'].rank(ascending = False) + data_mom['Return 6m'].rank(ascending = False) + 
#                              data_mom['Return 1y'].rank(ascending = False) + data_mom['Volatility'].rank(ascending = True)).rank(ascending = True)

# PURE MOMENTUM
#data_mom['Momentum Rank'] = (data_mom['Return 3m'].rank(ascending = False) + data_mom['Return 6m'].rank(ascending = False) + 
#                              data_mom['Return 1y'].rank(ascending = False)).rank(ascending = True)

# MOMENTUM WITH WOLATILITY AND EA
data_mom['Momentum Rank'] = (data_mom['3m Rank'] + data_mom['6m Rank'] +  data_mom['1y Rank'] + data_mom['Volatility Rank'] + data_mom['EA Std Rank']).rank(ascending = True)

# %% [markdown]
# ## GESTALT

# %%
# MANAGE NaNs and NEGATIVE EARNINGS  

# set nan to median
columns = ['P/E', 'EV/EBIT', 'P/FCF', 'P/S', 'P/B', 'ROC', 'ROE',
           'F-Score', 'GPA', 'Assets Turn','Volatility', 'EA ret', 'EA ret std', 'FCFROE']
for i in columns: 
    data.loc[data[i].isna() ,i] = data[i].median()

# set nan to min
for i in ['Return 3m', 'Return 6m', 'Return 1y']:
    data.loc[data[i].isna() ,i] = data[i].min()
    
# set negative values to max
for i in ['P/E', 'EV/EBIT', 'P/FCF', 'P/S', 'P/B']:
    data.loc[data[i] < 0 ,i] = data[i].max()
    
# set nan yield & vol to 0
data.loc[data['Yield'].isna(),'Yield'] = 0

# %%
data.isna().sum()
# Out:
# Börsdata ID           0
# Company               0
# Volume                0
# Yahoo                 0
# Last Report           8
# EV/EBIT               0
# Tick                  0
# Industry              0
# List                  0
# Country               0
# Return 1y             0
# Return 6m             0
# Return 3m             0
# Total Equity          6
# FCF                  10
# ROE                   0
# F-Score               0
# Volatility            0
# Market Cap            0
# ROC                   0
# Tot. Assets           6
# Gross profit         17
# Assets Turn           0
# P/FCF                 0
# Info - Ticker.1       0
# Yield                 0
# P/E                   0
# P/S                   0
# P/B                   0
# Sector                0
# FCFROE                0
# GPA                   0
# EA ret                0
# EA ret std            0
# 1 Year Volatility     0
# 1 Year MAD            0
# EA Volatility         0
# dtype: int64

# %% [markdown]
# ## Rankings and Sorting

# %%
# RANK ON DIFFERENT METRICS 


data['3m Rank'] = data['Return 3m'].rank(ascending = False)
data['6m Rank'] = data['Return 6m'].rank(ascending = False)
data['1y Rank'] = data['Return 1y'].rank(ascending = False)
data['EA Rank'] = data['EA ret'].rank(ascending = False)
data['EA Std Rank'] = data['EA ret std'].rank(ascending = False)


data['Momentum Rank'] = (data['3m Rank'] + data['6m Rank'] + data['1y Rank'] + data['EA Std Rank']).rank(ascending = True)

#data['Momentum'] = (data['Return 3m'] + data['Return 6m'] + data['Return 1y'])

# Ranking where lower value is better
for i in ['P/E', 'P/B', 'P/S', 'P/FCF', 'EV/EBIT']:
    data[i +' Rank'] = data[i].rank()
    
# Ranking where higher value is better
#for i in ['Yield', 'ROE', 'ROC', 'FCFROE', 'Momentum', 'GPA', 'Assets Turn']:
for i in ['Yield', 'ROE', 'ROC', 'FCFROE', 'GPA', 'Assets Turn']:
    data[i + ' Rank'] = (-data[i]).rank()
    
# Composite ranks
data['Quality Rank'] = (data['ROE Rank'] + data['ROC Rank'] + data['FCFROE Rank'] + 
                        data['GPA Rank'] + data['Assets Turn Rank']).rank()
data['Value Rank'] = (data['P/E Rank'] + data['P/B Rank'] + data['P/S Rank'] + data['P/FCF Rank'] + 
                      data['EV/EBIT Rank'] + data['Yield Rank']).rank()
 
data['Magic Formula'] = (data['ROC Rank'] + data['EV/EBIT Rank']).rank()
data['Siegfrieds'] = (data['ROC Rank'] + data['P/B Rank']).rank()
data['Triple Sort'] = ((data['Value Rank'] + data['Momentum Rank'] + data['Quality Rank'])).rank()
data['Double Sort'] = (data['Value Rank'] + data['Quality Rank']).rank()

# %%
# SORTING 

# number of stocks to choose before momentum screen
trend_screen = 40
double_sort_break_off = 40

value_tmp = data.sort_values(by=['Value Rank'])
quality_tmp = data.sort_values(by=['Quality Rank'])
#### MOMENTUM DATA FRAME
momentum_tmp = data_mom.sort_values(by=['Momentum Rank'])


trending_value_tmp = value_tmp[0:trend_screen]
trending_value_tmp = trending_value_tmp.sort_values(by='Momentum Rank')
trending_quality_tmp = quality_tmp[0:trend_screen]
trending_quality_tmp = trending_quality_tmp.sort_values(by='Momentum Rank')
magic_formula_tmp = data.sort_values(by=['Magic Formula'])
siegfrieds_tmp = data.sort_values(by=['Siegfrieds'])
triple_sort_tmp = data.sort_values(by=['Triple Sort'])
double_sort = data.sort_values(by=['Double Sort'])
double_sort_mom_tmp = double_sort[0:double_sort_break_off]
double_sort_mom = double_sort_mom_tmp.sort_values(by=['Momentum Rank'])

# %%
# FACTOR STRATEGIES 

compact = ['Company', 'List','Tick', 'Quality Rank', 'Value Rank', 'Momentum Rank', 'EA Std Rank', '1 Year Volatility']
compact_mom = ['Company', 'List','Tick', 'Momentum Rank','Volatility Rank','EA Std Rank', '1 Year Volatility']

# numbers of stocks to select for diff strategies

stocks = 20
magic_formula_stocks = 10
siegfried_stocks = 10
triple_sort_stocks = 20
double_sort_mom_stocks = 10

## VALUE ## 
value = value_tmp[0:stocks]
Value = value[compact]

## QUALITY ## 
quality = quality_tmp[0:stocks]
Quality = quality[compact]

## MOMENTUM ##
momentum = momentum_tmp[0:stocks]
Momentum = momentum[compact_mom]

## TRENDING VALUE ##
trending_value = trending_value_tmp[0:stocks]
Trending_Value = trending_value[compact]

## TRENDING QUALITY ##
trending_quality = trending_quality_tmp[0:stocks]
Trending_Quality = trending_quality[compact]

## MAGIC FORMULA ##
magic_formula = magic_formula_tmp[0:magic_formula_stocks]
Magic_Formula = magic_formula[compact]

## SIEGFRIEDS ##
siegfrieds = siegfrieds_tmp[0:siegfried_stocks]
Siegfrieds = siegfrieds[compact]

## TRIPLE SORT ##
triple_sort = triple_sort_tmp[0:triple_sort_stocks]
Triple_Sort = triple_sort[compact]

## DOUBLE SORT + Momentum ##
double_sort_mom = double_sort_mom[0:double_sort_mom_stocks]
Double_Sort_Mom = double_sort_mom[compact]

# %%
company('Nil')
# Out:
#      Börsdata ID        Company  Volume     Yahoo Last Report  EV/EBIT   Tick  \
# 184          758  Nilörngruppen    1.85  NIL-B.ST  2021-07-16     8.52  NIL B
#
#       Industry       List Country  Return 1y  Return 6m  Return 3m  \
# 184  Packaging  Small Cap  Sweden       0.85       0.26      -0.07
#
#      Total Equity   FCF  ROE  F-Score  Volatility  Market Cap  ROC  \
# 184        224.73 86.58 0.29     7.00       35.14      778.76 0.45
#
#      Tot. Assets  Gross profit  Assets Turn  P/FCF Info - Ticker.1  Yield  \
# 184       457.03        310.05         1.47   8.99           NIL B   0.03
#
#       P/E  P/S  P/B     Sector  FCFROE  GPA  EA ret  EA ret std  \
# 184 11.93 1.16 3.46  Materials    0.39 0.68   -0.16       -5.09
#
#      1 Year Volatility  1 Year MAD  EA Volatility  3m Rank  6m Rank  1y Rank  \
# 184               0.40        0.30           0.28   300.00   141.00   105.00
#
#      EA Rank  EA Std Rank  Momentum Rank  P/E Rank  P/B Rank  P/S Rank  \
# 184   441.00       453.00         258.00     38.00    187.00     86.00
#
#      P/FCF Rank  EV/EBIT Rank  Yield Rank  ROE Rank  ROC Rank  FCFROE Rank  \
# 184       44.00         22.00       47.00     35.00     22.00        40.00
#
#      GPA Rank  Assets Turn Rank  Quality Rank  Value Rank  Magic Formula  \
# 184     39.00             42.00         12.00       23.00           9.50
#
#      Siegfrieds  Triple Sort  Double Sort
# 184       27.50        46.00         2.00

# %% [markdown]
# ## Print Stock Selection

# %%
#Triple_Sort 
th_props = [
  ('font-size', '14px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'Black'),
  ('background-color', '#f7f7f9')
  ]
# Set CSS properties for td elements in dataframe
td_props = [('font-size', '12px'), ('text-align', 'center')]
#set caption props
caption_props = [('color', 'black'),('font-size', '22px'),
        ("text-align", "center"),
        ('font-weight', 'bold')]
# Set table styles
styles = [
    dict(selector="th", props=th_props),
    dict(selector="td", props=td_props),
    dict(selector="caption", props=caption_props)
]
Triple_Sort.index = range(1, len(Triple_Sort)+1)
Triple_Sort_view = (Triple_Sort.style.apply(lambda x: ['background: lightgreen' if x.name in range(1, 10+1) 
                              else '' for i in x], axis=1).set_table_styles(styles)
                 .format({'1 Year Volatility': "{:.1%}"})
                 .set_caption("Gestalt"))
Triple_Sort_view
# Out:
# <style  type="text/css" >
#     #T_b335273a_42df_11ec_9d77_8c859039bca2 th {
#           font-size: 14px;
#           text-align: center;
#           font-weight: bold;
#           color: Black;
#           background-color: #f7f7f9;
#     }    #T_b335273a_42df_11ec_9d77_8c859039bca2 td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_b335273a_42df_11ec_9d77_8c859039bca2 caption {
#           color: black;
#           font-size: 22px;
#           text-align: center;
#           font-weight: bold;
#     }    #T_b335273a_42df_11ec_9d77_8c859039bca2row0_col0 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row0_col1 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row0_col2 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row0_col3 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row0_col4 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row0_col5 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row0_col6 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row0_col7 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row1_col0 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row1_col1 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row1_col2 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row1_col3 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row1_col4 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row1_col5 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row1_col6 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row1_col7 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row2_col0 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row2_col1 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row2_col2 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row2_col3 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row2_col4 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row2_col5 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row2_col6 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row2_col7 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row3_col0 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row3_col1 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row3_col2 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row3_col3 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row3_col4 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row3_col5 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row3_col6 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row3_col7 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row4_col0 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row4_col1 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row4_col2 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row4_col3 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row4_col4 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row4_col5 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row4_col6 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row4_col7 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row5_col0 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row5_col1 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row5_col2 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row5_col3 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row5_col4 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row5_col5 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row5_col6 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row5_col7 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row6_col0 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row6_col1 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row6_col2 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row6_col3 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row6_col4 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row6_col5 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row6_col6 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row6_col7 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row7_col0 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row7_col1 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row7_col2 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row7_col3 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row7_col4 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row7_col5 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row7_col6 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row7_col7 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row8_col0 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row8_col1 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row8_col2 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row8_col3 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row8_col4 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row8_col5 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row8_col6 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row8_col7 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row9_col0 {
#             background:  lightgreen;
#         }    #T_b335273a_42df_11ec_9d77_8c859039bca2row9_col1 {
#             background:  lightgreen;
#         }    #T_b335273a_42d

# %%
th_props = [
  ('font-size', '14px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'Black'),
  ('background-color', '#f7f7f9')
  ]
# Set CSS properties for td elements in dataframe
td_props = [('font-size', '12px'), ('text-align', 'center')]
#set caption props
caption_props = [('color', 'black'),('font-size', '22px'),
        ("text-align", "center"),
        ('font-weight', 'bold')]
# Set table styles
styles = [
    dict(selector="th", props=th_props),
    dict(selector="td", props=td_props),
    dict(selector="caption", props=caption_props)
]
Momentum.index = range(1,len(Momentum)+1)
Momentum_view = (Momentum.style.apply(lambda x: ['background: lightgreen' if x.name in range(1,10+1) 
                              else '' for i in x], axis=1).set_table_styles(styles).format({'1 Year Volatility': "{:.1%}"})
                 .set_caption("Focused Momentum"))
Momentum_view
# Out:
# <style  type="text/css" >
#     #T_b4166c2c_42df_11ec_9d77_8c859039bca2 th {
#           font-size: 14px;
#           text-align: center;
#           font-weight: bold;
#           color: Black;
#           background-color: #f7f7f9;
#     }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2 td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2 caption {
#           color: black;
#           font-size: 22px;
#           text-align: center;
#           font-weight: bold;
#     }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row0_col0 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row0_col1 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row0_col2 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row0_col3 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row0_col4 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row0_col5 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row0_col6 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row1_col0 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row1_col1 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row1_col2 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row1_col3 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row1_col4 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row1_col5 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row1_col6 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row2_col0 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row2_col1 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row2_col2 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row2_col3 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row2_col4 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row2_col5 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row2_col6 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row3_col0 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row3_col1 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row3_col2 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row3_col3 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row3_col4 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row3_col5 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row3_col6 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row4_col0 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row4_col1 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row4_col2 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row4_col3 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row4_col4 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row4_col5 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row4_col6 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row5_col0 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row5_col1 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row5_col2 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row5_col3 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row5_col4 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row5_col5 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row5_col6 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row6_col0 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row6_col1 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row6_col2 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row6_col3 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row6_col4 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row6_col5 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row6_col6 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row7_col0 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row7_col1 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row7_col2 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row7_col3 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row7_col4 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row7_col5 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row7_col6 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row8_col0 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row8_col1 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row8_col2 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row8_col3 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row8_col4 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row8_col5 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row8_col6 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row9_col0 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row9_col1 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row9_col2 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row9_col3 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row9_col4 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row9_col5 {
#             background:  lightgreen;
#         }    #T_b4166c2c_42df_11ec_9d77_8c859039bca2row9_col6 {
#             background:  lightgreen;
#         }</style><table id="T_b4166c2c_42df_11ec_9d77_8c859039bca2" ><caption>Focused Momentum</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Company</th>        <th class="col_heading level0 col1" >List</th>        <th class="col_heading level0 col2" >Tick</th>        <th class="col_heading level0 col3" >Momentum Rank</th>        <th class="col_heading level0 col4" >V

# %%
company('Evolution')
# Out:
#      Börsdata ID    Company  Volume   Yahoo Last Report  EV/EBIT Tick  \
# 354          750  Evolution  954.01  EVO.ST  2021-07-21    64.62  EVO
#
#                Industry       List Country  Return 1y  Return 6m  Return 3m  \
# 354  Gambling & Casinos  Large Cap  Sweden       1.58       0.40      -0.06
#
#      Total Equity      FCF  ROE  F-Score  Volatility  Market Cap  ROC  \
# 354     31,151.86 3,230.02 0.14     4.00       53.86  312,460.41 0.16
#
#      Tot. Assets  Gross profit  Assets Turn  P/FCF Info - Ticker.1  Yield  \
# 354    36,150.66      6,610.48         0.23  96.74             EVO   0.00
#
#       P/E   P/S   P/B             Sector  FCFROE  GPA  EA ret  EA ret std  \
# 354 69.29 37.33 10.03  Consumer Durables    0.10 0.18    0.00        0.04
#
#      1 Year Volatility  1 Year MAD  EA Volatility  3m Rank  6m Rank  1y Rank  \
# 354               0.47        0.42           0.62   296.00    99.00    38.00
#
#      EA Rank  EA Std Rank  Momentum Rank  P/E Rank  P/B Rank  P/S Rank  \
# 354   205.00       204.00         124.00    207.00    373.00    388.00
#
#      P/FCF Rank  EV/EBIT Rank  Yield Rank  ROE Rank  ROC Rank  FCFROE Rank  \
# 354      191.00        232.00      145.00    122.00    116.00       161.00
#
#      GPA Rank  Assets Turn Rank  Quality Rank  Value Rank  Magic Formula  \
# 354    273.00            350.00        203.50      241.00         194.50
#
#      Siegfrieds  Triple Sort  Double Sort
# 354      277.00       194.00       232.00

# %%
#data.sort_values(by=['Momentum Rank'])

# %% [markdown]
# ## Data Illustartion

# %%
plt.scatter(data['1 Year MAD'],data['1 Year Volatility']);
plt.xlabel('MAD');
plt.ylabel('Vol');

# %%
plt.scatter(data['Volatility']/100,data['1 Year Volatility']);
plt.xlabel('vol 60 dagars');
plt.ylabel('Vol 1år');

# %%
data[['1 Year MAD', '1 Year Volatility']].corr()
# Out:
#                    1 Year MAD  1 Year Volatility
# 1 Year MAD               1.00               0.66
# 1 Year Volatility        0.66               1.00

# %%
data_mom.sort_values(by='1 Year Volatility')[['Company','1 Year MAD', '1 Year Volatility' ]]
# Out:
#                          Company  1 Year MAD  1 Year Volatility
# 332                Fastpartner D        0.08               0.09
# 406                      Corem D        0.10               0.10
# 489                       Axfood        0.13               0.15
# 48                 Telia Company        0.14               0.16
# 421                      Cloetta        0.16               0.17
# 538                          AAK        0.17               0.17
# 357                     Essity B        0.17               0.19
# 384                     Eastnine        0.17               0.19
# 423                 Cibus Nordic        0.17               0.19
# 49                       Tele2 B        0.17               0.20
# 501       Aros Bostadsutveckling        0.19               0.20
# 86               Handelsbanken A        0.18               0.20
# 537                          ABB        0.18               0.20
# 99                         SEB A        0.19               0.20
# 289                  ICA Gruppen        0.17               0.21
# 55                      Swedbank        0.19               0.21
# 25              Wästbygg Gruppen        0.18               0.21
# 96                     Securitas        0.19               0.21
# 433                    Castellum        0.21               0.21
# 299                     Holmen B        0.21               0.21
# 497                   Assa Abloy        0.20               0.21
# 245                   Kungsleden        0.21               0.22
# 469              BillerudKorsnäs        0.20               0.22
# 193                        NCC B        0.20               0.22
# 79                       Skanska        0.20               0.22
# 52                 Swedish Match        0.20               0.22
# 192                  Nordea Bank        0.20               0.22
# 306                      Hexagon        0.21               0.22
# 28                    Wallenstam        0.22               0.22
# 295               Hufvudstaden A        0.22               0.22
# 485                  AstraZeneca        0.21               0.22
# 40                     TietoEVRY        0.21               0.23
# 39                      Millicom        0.20               0.23
# 496                Atlas Copco A        0.21               0.23
# 32                    Trelleborg        0.22               0.23
# 523                         AFRY        0.21               0.23
# 450                    Bredband2        0.20               0.23
# 493             Atrium Ljungberg        0.23               0.23
# 106                        SCA B        0.22               0.23
# 151                         Peab        0.21               0.23
# 491                       Atvexa        0.18               0.24
# 335                    Fortinova        0.22               0.24
# 259                           JM        0.23               0.24
# 451                      Bravida        0.23               0.24
# 12                       Volvo B        0.22               0.24
# 258                 John Mattson        0.22               0.24
# 297                       Hexpol        0.23               0.24
# 26                           VBG        0.23               0.24
# 519                   Alfa Laval        0.23               0.25
# 363                     Epiroc B        0.24               0.25
# 150                       Pfizer        0.39               0.25
# 63                  Stora Enso R        0.24               0.25
# 350                       Fabege        0.25               0.25
# 359                   Ericsson B        0.22               0.25
# 62                    Stendörren        0.24               0.25
# 431                       Catena        0.25               0.26
# 540                       Traton        0.25               0.26
# 396                         Diös        0.39               0.26
# 112                      Sandvik        0.24               0.26
# 375                        Eltel        0.23               0.26
# 170                       Nyfosa        0.25               0.26
# 321                      Getinge        0.23               0.26
# 21                     Wihlborgs        0.25               0.26
# 481                  Fast Balder        0.25               0.26
# 251                  Karo Pharma        0.24               0.26
# 516                      Autoliv        0.25               0.26
# 379                       Elekta        0.25               0.26
# 178                       Nolato        0.25               0.26
# 294                       Humana        0.24               0.26
# 281                    Indutrade        0.25               0.26
# 438                    CAG Group        0.23               0.26
# 492                      Attendo        0.23               0.27
# 333                Fastpartner A        0.26               0.27
# 408                 Coor Service        0.24               0.27
# 107      Samhällsbyggnadsbolag B        0.26               0.27
# 102              Scandi Standard        0.22               0.27
# 374                 Electrolux B        0.25               0.27
# 517                       Alimak        0.25               0.27
# 513                      Amasten        0.25               0.27
# 78                         SKF B        0.25               0.27
# 115                         Saab        0.23               0.27
# 303             Hennes & Mauritz        0.26               0.27
# 292                  Husqvarna B        0.25               0.28
# 275                       Intrum        0.25               0.28
# 118                    Rottneros        0.25               0.28
# 146                      Platzer        0.26               0.28
# 319              Götenehus Group        0.27               0.28
# 252                       Karnov        0.26               0.28
# 180                       Nobina        0.25               0.28
# 420                  Clas Ohlson        0.24               0.28
# 42                         Thule        0.25               0.28
# 229                       Loomis        0.26               0.28
# 121               Resurs Holding        0.24               0.29
# 309                         Heba        0.26               0.29
# 391                      Dometic        0.27               0.29
# 349                    Fagerhult        0.26               0.29
# 238                       Lindab        0.26               0.29
# 223                         Lyko        0.26               0.29
# 82                    SinterCast        0.26               0.29
# 181                        Nobia        0.26               0.29
# 174                 Nordic Paper        0.29               0.30
# 272                       Inwido        0.29               0.30
# 255                         Kabe        0.27               0.30
# 456                     Bonava B        0.28               0.30
# 479                  Beijer Alma        0.28               0.30
# 314                 Greater Than        0.26               0.30
# 56                       Sweco B        0.25               0.30
# 475                       Besqab        0.29               0.30
# 478                   Beijer Ref        0.29               0.30
# 185                         NIBE        0.28               0.30
# 500                   Arla Plast        0.27               0.31
# 412                    Concejo B        0.23               0.31
# 320           GHP Specialty Care        0.28               0.31
# 334                Fenix Outdoor        0.30               0.31
# 512                        Ambea        0.28               0.31
# 343                      Firefly        0.29               0.31
# 457                      Boliden        0.30               0.31
# 458                 Bokusgruppen        0.27               0.32
# 482                  Balco Group        0.28               0.32
# 224                Lundin Energy        0.29               0.32
# 503                         Arjo        0.28               0.32
# 77                       SkiStar        0.28               0.32
# 439                  Byggpartner        0.29               0.32
# 373                   Embellence        0.29               0.32
# 390                         Doro        0.28               0.32
# 128                     Railcare        0.24               0.32
# 88           Stenhus Fastigheter        0.39               0.32
# 242                  Lagercrantz        0.31               0.32
# 509                      Addnode        0.28               0.32
# 387                         Duni        0.28               0.32
# 136                ProfilGruppen        0.27               0.32
# 505                  Arion Banki        0.32               0.33
# 198                     Mycronic        0.28               0.33
# 346                 Fasadgruppen        0.30               0.33
# 144                       Pandox        0.31               0.33
# 361    Electrolux Professional B        0.32               0.33
# 463                      Biotage        0.31               0.33
# 536            Absolent Air Care        0.31               0.33
# 114                      Sagax A        0.31               0.34
# 34                Train Alliance        0.32               0.34
# 430                      Cavotec        0.29               0.34
# 80                           SJR        0.29               0.34
# 202                    Midsona B        0.30               0.34
# 291                I.A.R Systems        0.29               0.34
# 190       Nordic Entertainment B        0.31               0.34
# 65                        SSAB A        0.32               0.34
# 510          Annehem Fastigheter        0.33               0.34
# 535                   AcadeMedia        0.30               0.35
# 487                       Avanza        0.34               0.35
# 353                        eWork        0.30               0.35
# 315              Genova Property        0.31               0.35
# 141           Precise Biometrics        0.30               0.35
# 117                     RugVista        0.31               0.35
# 175                          NP3        0.34               0.35
# 453                   Björn Borg        0.31               0.35
# 227                  Lundin Gold        0.34               0.35
# 215                       MedCap        0.32               0.35
# 446                      Brinova        0.33               0.35
# 19                Vitec Software        0.33               0.35
# 336                  Ferronordic        0.31               0.35
# 348                     Fastator        0.31               0.35
# 465                      BioGaia        0.29               0.35
# 300                Hoist Finance        0.32               0.35
# 507                     AQ Group        0.32               0.35
# 44                    Tethys Oil        0.33               0.36
# 508                   Africa Oil        0.34               0.36
# 31                       Trianon        0.33               0.36
# 90                       Senzime        0.29               0.36
# 442                       Bulten        0.33               0.36
# 200                      Munters        0.32               0.36
# 221                     Magnolia        0.21               0.36
# 73                     Softronic        0.32               0.36
# 155                    Proact IT        0.32               0.36
# 109                      Nordnet        0.33               0.36
# 473                      Betsson        0.33               0.36
# 94                        Semcon        0.32               0.36
# 244                       KnowIT        0.32               0.36
# 527                      Addtech        0.34               0.36
# 427                  CellaVision        0.33               0.37
# 398                     Dedicare        0.32               0.37
# 125       RaySearch Laboratories        0.33               0.37
# 138                       Pricer        0.32               0.37
# 156                          OX2        0.36               0.37
# 476             Bergman & Beving        0.35               0.37
# 140                       Prevas        0.34               0.37
# 525                Africa Energy        0.34               0.37
# 18                     Vitrolife        0.33               0.37
# 123                      Rejlers        0.36               0.37
# 460                      Byggmax        0.34               0.37
# 312                      Gränges        0.32               0.37
# 74      Swedish Orphan Biovitrum        0.27               0.37
# 201                        MTG B        0.34               0.37
# 172         Nordic Waterproofing        0.33               0.37
# 179                        Nokia        0.29               0.37
# 483                   Bactiguard        0.36               0.37
# 459                       Nimbus        0.33               0.37
# 93                  Sensys Gatso        0.32               0.37
# 97                        Sectra        0.33               0.38
# 452            Boule Diagnostics        0.36               0.38
# 212                    Mekonomen        0.32               0.38
# 411                   Concentric        0.32               0.38
# 436                      Camurus        0.32               0.38
# 207               Momentum Group        0.35               0.38
# 385                 Dustin Group        0.32               0.38
# 30                   Troax Group        0.35               0.38
# 521                Alcadon Group        0.32               0.38
# 368                         Enea        0.35               0.38
# 400                  CTT Systems        0.35               0.38
# 101                     Sdiptech        0.39               0.38
# 214                    Medicover        0.35               0.38
# 302                 HMS Networks        0.36               0.39
# 84          Signatur Fastigheter        0.31               0.39
# 278                     Instalco        0.36               0.39
# 232                      Lipidor        0.36               0.39
# 187                     New Wave        0.37               0.39
# 173                      Novotek        0.34               0.39
# 256                          K2A        0.38               0.40
# 239                     LeoVegas        0.34               0.40
# 331            Formpipe Software        0.33               0.40
# 184                Nilörngruppen        0.30               0.40
# 43                       TF Bank        0.37               0.40
# 386                        Duroc        0.34               0.40
# 484                B3 Consulting        0.36               0.40
# 317                  Smart Wires        0.39               0.40
# 405                Creaspac SPAC        0.39               0.40
# 464                    Biosergen        0.39               0.40
# 11                 Wyld Networks        0.39               0.40
# 45                 Tessin Nordic        0.39               0.40
# 304                       Haldex        0.36               0.41
# 418           Corline Biomedical        0.38               0.41
# 5                Xvivo Perfusion        0.39               0.41
# 262                      Invisio        0.38               0.41
# 54                     Svedbergs        0.38               0.41
# 378                     Elanders        0.38               0.41
# 76                   Sleep Cycle        0.38               0.41
# 182                     Nederman        0.39               0.41
# 443                        Bufab        0.39               0.41
# 498                Aspire Global        0.39               0.41
# 166                          OEM        0.37               0.41
# 347                     Ferroamp        0.36               0.41
# 432                    Catella B        0.32               0.42
# 404                        C-RAD        0.36               0.42
# 490                      Awardit        0.37               0.42
# 298                      Hövding        0.35               0.42
# 130                      Q-Linea        0.39               0.42
# 50                     Systemair        0.36               0.42
# 454                        Boozt        0.39               0.42
# 169        Oasmia Pharmaceutical        0.40               0.42
# 159                        Orexo        0.40               0.42
# 4                    ZetaDisplay        0.32               0.43
# 264                       I-Tech        0.34               0.43
# 33                     Transtema        0.38               0.43
# 467                    Bioinvent        0.39               0.43
# 495                  Actic Group        0.39               0.43
# 66                       Serneke        0.32               0.43
# 477           Beijer Electronics        0.39               0.43
# 310                        Hanza        0.34               0.43
# 8                        Xintela        0.38               0.44
# 472                    BHG Group        0.40               0.44
# 129                        Qliro        0.43               0.44
# 470                        Bilia        0.31               0.44
# 176                         NOTE        0.42               0.44
# 53                      Studsvik        0.38               0.44
# 142                       Poolia        0.37               0.44
# 186                        Nexam        0.39               0.45
# 263                    Intervacc        0.43               0.45
# 260                       Jetpak        0.42               0.45
# 116               Revolutionrace        0.39               0.45
# 422                   Cint Group        0.39               0.45
# 270      International Petroleum        0.43               0.45
# 248                      Kindred        0.42               0.45
# 85                Scandic Hotels        0.42               0.45
# 127                     Raketech        0.39               0.45
# 372                     Embracer        0.42               0.45
# 139                      Profoto        0.38               0.45
# 226                Lundin Mining        0.42               0.45
# 195                     Nanoform        0.39               0.45
# 158                     OssDsign        0.38               0.46
# 488                      aXichem        0.42               0.46
# 311           Guard Therapeutics        0.38               0.46
# 257          Josemaria Resources        0.41               0.46
# 325                         GARO        0.41               0.46
# 444                    BTS Group        0.36               0.46
# 20                  Vimian Group        0.44               0.46
# 326                     Gapwaves        0.43               0.46
# 480                     BE Group        0.39               0.46
# 354                    Evolution        0.42               0.47
# 228               Lucara Diamond        0.41               0.47
# 220              MAG Interactive        0.43               0.47
# 75                      ShaMaran        0.46               0.47
# 337                  FM Mattsson        0.43               0.47
# 364                   Eolus Vind        0.45               0.47
# 419                    Clavister        0.40               0.47
# 518                      AddLife        0.43               0.47
# 135                   Permascand        0.44               0.47
# 38                         Tobii        0.44               0.48
# 148                 Pierce Group        0.43               0.48
# 288                      Iconovo        0.39               0.48
# 189                         Nepa        0.40               0.48
# 231                    LMK Group        0.38               0.48
# 137                        Probi        0.42               0.48
# 504              Arise Windpower        0.46               0.48
# 133                     QleanAir        0.43               0.48
# 219                  Maha Energy        0.42               0.48
# 383                     Ecoclime        0.42               0.48
# 279                       Infrea        0.44               0.48
# 410                    Collector        0.45               0.48
# 61                      Storytel        0.40               0.48
# 95                Sedana Medical        0.42               0.49
# 10                 XANO Industri        0.47               0.49
# 284                   Implantica        0.42               0.49
# 171              NextCell Pharma        0.41               0.49
# 449                 Bergs Timber        0.45               0.50
# 371                  Empir Group        0.41               0.50
# 124                       Readly        0.45               0.50
# 208                         Mips        0.45               0.50
# 210                 Mildef Group        0.43               0.50
# 474            Better Collective        0.45               0.50
# 237                        LIDDS        0.42               0.50
# 206                      Mentice        0.44               0.50
# 305                      Hexicon        0.47               0.50
# 397                    Dignitana        0.44               0.51
# 313            Green Landscaping        0.46               0.51
# 3                         Ziccum        0.47               0.51
# 249               K-Fast Holding        0.45               0.51
# 209                      Minesto        0.46               0.51
# 143                    Polygiene        0.45               0.51
# 203            Micro Systemation        0.42               0.51
# 152          Paradox Interactive        0.42               0.52
# 157                        Ovzon        0.49               0.52
# 290             Infant Bacterial        0.42               0.52
# 528                      Adapteo        0.29               0.52
# 533                        Acast        0.52               0.52
# 91                     Smart Eye        0.48               0.52
# 380          Egetis Therapeutics        0.44               0.52
# 539              AAC Clyde Space        0.47               0.52
# 235            Lime Technologies        0.46               0.52
# 531               Ascelia Pharma        0.44               0.52
# 401                 Catena Media        0.43               0.52
# 301              Hansa Biopharma        0.46               0.52
# 191                  Nelly Group        0.47               0.52
# 407                  Copperstone        0.47               0.52
# 296                   Hexatronic        0.46               0.52
# 395                       DistIT        0.48               0.52
# 285                    Immunicum        0.44               0.53
# 27                     Waystream        0.45               0.54
# 514              AlzeCure Pharma        0.47               0.54
# 327             G5 Entertainment        0.46               0.54
# 499         Artificial Solutions        0.45               0.54
# 188                  Net Insight        0.44               0.54
# 468                    BIMobject        0.44               0.54
# 64                  Starbreeze B        0.44               0.54
# 98                    Swedencare        0.53               0.54
# 205                Moberg Pharma        0.45               0.54
# 110                          SAS        0.45               0.54
# 541                       2cureX        0.50               0.54
# 369                    Endomines        0.43               0.54
# 466                    BioArctic        0.40               0.54
# 111                      Saniona        0.48               0.55
# 199                      Medivir        0.41               0.55
# 164                    OncoZenge        0.39               0.55
# 9               Xbrane Biopharma        0.50               0.55
# 83                         Sinch        0.49               0.55
# 318            Gaming Innovation        0.39               0.55
# 417                     Clemondo        0.41               0.55
# 246                Klaria Pharma        0.51               0.55
# 530                     AcouSort        0.51               0.55
# 494         Alligator Bioscience        0.41               0.56
# 268           IRLAB Therapeutics        0.43               0.56
# 37                    Toleranzia        0.45               0.56
# 160                  OrganoClick        0.46               0.56
# 92           Scandinavian Enviro        0.50               0.57
# 108                      Saxlund        0.49               0.57
# 81         Sivers Semiconductors        0.54               0.57
# 307                       Hemnet        0.46               0.57
# 324                 Gaming Corps        0.45               0.57
# 282        InDex Pharmaceuticals        0.47               0.57
# 367                      EnQuest        0.55               0.57
# 89                    Stillfront        0.52               0.58
# 261            JonDeTech Sensors        0.51               0.58
# 194                   NCAB Group        0.54               0.58
# 351                      Exsitec        0.51               0.58
# 167                    Odd Molly        0.52               0.59
# 365                   Enzymatica        0.47               0.59
# 22                 Vicore Pharma        0.48               0.59
# 29                        Urb-it        0.51               0.59
# 2                        ZignSec        0.52               0.59
# 0                          Zwipe        0.55               0.59
# 399                       Cyxone        0.52               0.59
# 68                        Speqta        0.53               0.59
# 35                  TradeDoubler        0.53               0.60
# 254                        Kambi        0.47               0.60
# 47                       Teqnion        0.58               0.60
# 122                   Re:NewCell        0.54               0.60
# 240                    Lifeclean        0.39               0.60
# 104            Scandion Oncology        0.49               0.60
# 72                SolTech Energy        0.59               0.61
# 437      Calliditas Therapeutics        0.45               0.61
# 362                      Episurf        0.53               0.61
# 17                       Veoneer        0.39               0.61
# 341               Flexion Mobile        0.56               0.61
# 113             SaltX Technology        0.49               0.61
# 265            ITAB Shop Concept        0.48               0.61
# 57              Surgical Science        0.55               0.62
# 392               Diamyd Medical        0.53               0.62
# 323               Generic Sweden        0.56               0.62
# 222              Media and Games        0.61               0.62
# 462                      Biovica        0.55               0.62
# 60              Swedish Stirling        0.53               0.64
# 7                      XMReality        0.55               0.64
# 153                    PowerCell        0.62               0.64
# 149                  Pharmacolog        0.54               0.64
# 269                      Irisity        0.58               0.64
# 211                    Midsummer        0.50               0.64
# 134                   Physitrack        0.60               0.64
# 103                 Scout Gaming        0.59               0.64
# 471                   BICO Group        0.56               0.64
# 461                    Bio-Works        0.59               0.65
# 316                     GomSpace        0.55               0.65
# 105                      Scibase        0.56               0.66
# 329                    Freja eID        0.57               0.66
# 435                    Cantargia        0.56               0.66
# 283              Impact Coatings        0.62               0.67
# 434                     Capacent        0.40               0.67
# 36                         Tourn        0.58               0.67
# 330               Fractal Gaming        0.45               0.68
# 447             Brilliant Future        0.57               0.68
# 1                         Zordix        0.62               0.68
# 532                     Acconeer        0.66               0.69
# 293                 Humble Group        0.66               0.69
# 358               Enorama Pharma        0.56               0.70
# 393                  Dlaboratory        0.66               0.70
# 322                      Genovis        0.58               0.70
# 267               Isofol Medical        0.58               0.71
# 253                      Kancera        0.53               0.71
# 196                       Nanexa        0.51               0.71
# 132                  Qiiwi Games        0.58               0.71
# 230                 Lohilo Foods        0.54               0.71
# 197                 myFC Holding        0.61               0.72
# 286                    Immunovia        0.56               0.72
# 162        OptiCept Technologies        0.65               0.72
# 131                        QLife        0.61               0.72
# 67             Sprint Bioscience        0.47               0.72
# 415                      Climeon        0.57               0.73
# 344            Fingerprint Cards        0.54               0.73
# 69                   SpectrumOne        0.65               0.73
# 381                Enad Global 7        0.61               0.74
# 218                      Mangold        0.67               0.74
# 520               Alelion Energy        0.67               0.75
# 41                    Thunderful        0.49               0.75
# 216                     Mavshack        0.64               0.75
# 345                  Filo Mining        0.53               0.76
# 87                 Safello Group        0.69               0.76
# 394           Divio Technologies        0.66               0.76
# 370                    Emplicure        0.71               0.76
# 424                  Cell Impact        0.74               0.76
# 414        Clinical Laserthermia        0.59               0.76
# 276                     Integrum        0.66               0.76
# 274                       Invajo        0.66               0.77
# 147                   PiezoMotor        0.58               0.77
# 71                         Sozap        0.65               0.77
# 486                       Azelio        0.71               0.78
# 526                     Advenica        0.67               0.78
# 376                         Elos        0.57               0.78
# 338                    FluoGuide        0.67               0.79
# 413                    ChemoTech        0.74               0.79
# 440                     Bambuser        0.72               0.79
# 428                Cortus Energy        0.68               0.81
# 455                  Bonesupport        0.44               0.81
# 340                     Flexqube        0.70               0.82
# 511                    Amniotics        0.69               0.82
# 46                      TerraNet        0.74               0.84
# 271                       Inzile        0.70               0.85
# 402                   CoinShares        0.82               0.87
# 243               LL Lucky Games        0.83               0.89
# 14                   Veg of Lund        0.79               0.89
# 377         Elicera Therapeutics        0.76               0.89
# 534                       Acarix        0.70               0.90
# 445                 Goobit Group        0.84               0.92
# 339                     Fluicell        0.89               0.94
# 352           ExpreS2ion Biotech        0.84               0.94
# 388                      Desenio        0.55               0.95
# 6                  Xspray Pharma        0.52               0.95
# 426                   Crunchfish        0.84               0.96
# 183                  Nitro Games        0.70               0.96
# 266                  ISR Holding        0.78               0.97
# 233                     Linkfire        0.80               0.97
# 502                      AroCell        0.69               0.98
# 70                   SpectraCure        0.66               0.98
# 429                         CDON        0.88               0.98
# 448                     Brighter        0.76               0.98
# 163             Oscar Properties        0.75               0.99
# 366                        Eniro        0.67               1.00
# 145                   ProstaLund        0.59               1.01
# 308                       Hedera        0.68               1.04
# 154                      Papilly        0.82               1.07
# 15                       Vo2 Cap        0.87               1.08
# 328                         Fuud        0.87               1.10
# 120                  Rizzo Group        0.85               1.15
# 409                    CombiGene        0.61               1.16
# 515        Allarity Therapeutics        0.94               1.25
# 425                  checkin.com        0.93               1.27
# 355  Euroafrica Digital Ventures        0.39               1.27
# 506                Arcane Crypto        1.08               1.29
# 382               Eco Wave Power        0.73               1.30
# 277       Intellego Technologies        1.10               1.31
# 177              Nord Insuretech        0.93               1.41
# 59               Studentbostäder        0.62               1.46
# 389                         Doxa        1.01               1.57
# 524                     AegirBio        1.19               1.58
# 416                 Clean Motion        0.99               1.66
# 356                       Etrion        0.76               1.78
# 165                 Oncopeptides        0.84               1.80
# 217                       Mantex        1.14               2.14
# 168         Online Brands Nordic        1.38               2.41
# 204                 Moment Group        1.22               2.53
# 119        RNB Retail and Brands        1.62               4.31
# 213               Modern Ekonomi        0.39               6.67

# %%
plt.scatter(data['Momentum Rank'],data['EA Rank']);
plt.xlabel('Momentum Rank');
plt.ylabel('EA Rank');

# %% [markdown]
# #### Correlation heat map between selected Ranks

# %%
corr = data_mom[['3m Rank', '6m Rank', '1y Rank' , 'Momentum Rank', 'EA Std Rank', 'Volatility Rank']].corr()

#corr = data[['Quality Rank', 'Value Rank', 'Momentum Rank', 'EA Std Rank']].corr()

# %%
corr
# Out:
#                  3m Rank  6m Rank  1y Rank  Momentum Rank  EA Std Rank  \
# 3m Rank             1.00     0.75     0.56           0.82         0.38
# 6m Rank             0.75     1.00     0.70           0.86         0.31
# 1y Rank             0.56     0.70     1.00           0.73         0.19
# Momentum Rank       0.82     0.86     0.73           1.00         0.58
# EA Std Rank         0.38     0.31     0.19           0.58         1.00
# Volatility Rank     0.07     0.12     0.03           0.38         0.09
#
#                  Volatility Rank
# 3m Rank                     0.07
# 6m Rank                     0.12
# 1y Rank                     0.03
# Momentum Rank               0.38
# EA Std Rank                 0.09
# Volatility Rank             1.00
