# %%
import pandas as pd
from matplotlib import pylab as plt
import numpy as np
from datetime import datetime
import math
import seaborn as sns
import sys
import sys
import re
import os.path

# %% [markdown]
# ## data import

# %%
file_name =  "clean_data_2021-11-29.csv"
folder = "../clean_equity_data/"
data_tmp = pd.read_csv(folder + file_name)

# %%
### MOMENTUM
data_mom = data_tmp.copy()
data_mom = data_mom.loc[(data_mom['Industry'] != 'Holding Companies')]


### GESTALT
data_gestalt = data_tmp.copy()
data_gestalt = data_gestalt.loc[(data_tmp['Sector'] != 'Financials')]

# %% [markdown]
# ### Momentum Rank

# %%
# RANK ON DIFFERENT METRICS 

data_mom['3m Rank'] = data_mom['Return 3m'].rank(ascending = False)
data_mom['6m Rank'] = data_mom['Return 6m'].rank(ascending = False)
data_mom['1y Rank'] = data_mom['Return 1y'].rank(ascending = False)
data_mom['EA Rank'] = data_mom['EA ret'].rank(ascending = False)
data_mom['EA Std Rank'] = data_mom['EA ret std'].rank(ascending = False)
data_mom['Volatility Rank'] = data_mom['1 Year Volatility'].rank(ascending = True)
data_mom['MAD Rank'] = data_mom['1 Year Volatility'].rank(ascending = True)

# MOMENTUM WITH WOLATILITY AND EA
data_mom['Momentum Rank'] = (data_mom['3m Rank'] + data_mom['6m Rank'] +  data_mom['1y Rank'] + data_mom['Volatility Rank'] + data_mom['EA Std Rank']).rank(ascending = True)

# %% [markdown]
# ### Gestalt Imputation and Rank

# %%
# MANAGE NaNs and NEGATIVE EARNINGS  

# set nan to median, only fundamental data
columns = ['P/E', 'EV/EBIT', 'P/FCF', 'P/S', 'P/B', 'ROC', 'ROE',
            'GPA', 'Assets Turn', 'FCFROE']
for i in columns: 
    data_gestalt.loc[data_gestalt[i].isna() ,i] = data_gestalt[i].median()


    
# set negative values to max
for i in ['P/E', 'EV/EBIT', 'P/FCF', 'P/S', 'P/B']:
    data_gestalt.loc[data_gestalt[i] < 0 ,i] = data_gestalt[i].max()
    
# set nan yield & vol to 0
data_gestalt.loc[data_gestalt['Yield'].isna(),'Yield'] = 0

# %%
data_gestalt['3m Rank'] = data_gestalt['Return 3m'].rank(ascending = False)
data_gestalt['6m Rank'] = data_gestalt['Return 6m'].rank(ascending = False)
data_gestalt['1y Rank'] = data_gestalt['Return 1y'].rank(ascending = False)
data_gestalt['EA Rank'] = data_gestalt['EA ret'].rank(ascending = False)
data_gestalt['EA Std Rank'] = data_gestalt['EA ret std'].rank(ascending = False)


data_gestalt['Momentum Rank'] = (data_gestalt['3m Rank'] + data_gestalt['6m Rank'] + 
                                 data_gestalt['1y Rank'] + data_gestalt['EA Std Rank']).rank(ascending = True)



# Ranking where lower value is better
for i in ['P/E', 'P/B', 'P/S', 'P/FCF', 'EV/EBIT']:
    data_gestalt[i +' Rank'] = data_gestalt[i].rank()
    

for i in ['Yield', 'ROE', 'ROC', 'FCFROE', 'GPA', 'Assets Turn']:
    data_gestalt[i + ' Rank'] = (-data_gestalt[i]).rank()
    
# Composite ranks
data_gestalt['Quality Rank'] = (data_gestalt['ROE Rank'] + data_gestalt['ROC Rank'] + data_gestalt['FCFROE Rank'] + 
                        data_gestalt['GPA Rank'] + data_gestalt['Assets Turn Rank']).rank()

data_gestalt['Value Rank'] = (data_gestalt['P/E Rank'] + data_gestalt['P/B Rank'] + data_gestalt['P/S Rank'] + data_gestalt['P/FCF Rank'] + 
                      data_gestalt['EV/EBIT Rank'] + data_gestalt['Yield Rank']).rank()
 

data_gestalt['Gestalt Rank'] = ((data_gestalt['Value Rank'] + data_gestalt['Momentum Rank'] + data_gestalt['Quality Rank'])).rank()

# %% [markdown]
# ### Data Error Check

# %%
#data_mom.isna().sum()
data_gestalt.isna().sum()
# Out:
# Unnamed: 0                      0
# Börsdata ID                     0
# Company                         0
# Industry                        0
# Volume                          0
# P/FCF                           0
# Assets Turn                     0
# Gross profit                   11
# Tot. Assets                     2
# ROC                             0
# Market Cap                      0
# Volatility                      0
# ROE                             0
# FCF                             2
# Total Equity                    2
# Return 3m                       0
# Return 6m                       0
# Return 1y                       0
# Country                         0
# List                            0
# Tick                            0
# EV/EBIT                         0
# Last Report                     2
# Yahoo                           0
# Performance - Perform. 1y.1    26
# Yield                           0
# P/E                             0
# P/S                             0
# P/B                             0
# Info - Time                     0
# Info - Stock price              0
# Info - Report                   0
# Sector                          0
# FCFROE                          0
# GPA                             0
# EA ret                          0
# EA ret std                      0
# 1 Year Volatility               0
# 1 Year MAD                      0
# EA Volatility                   0
# 3m Rank                         0
# 6m Rank                         0
# 1y Rank                         0
# EA Rank                         0
# EA Std Rank                     0
# Momentum Rank                   0
# P/E Rank                        0
# P/B Rank                        0
# P/S Rank                        0
# P/FCF Rank                      0
# EV/EBIT Rank                    0
# Yield Rank                      0
# ROE Rank                        0
# ROC Rank                        0
# FCFROE Rank                     0
# GPA Rank                        0
# Assets Turn Rank                0
# Quality Rank                    0
# Value Rank                      0
# Gestalt Rank                    0
# dtype: int64

# %% [markdown]
# ### Sorting

# %%
#### MOMENTUM DATA FRAME
momentum_tmp = data_mom.sort_values(by=['Momentum Rank'])
#### Gestalt Data Frame
gestalt_tmp = data_gestalt.sort_values(by=['Gestalt Rank'])

# %%
compact = ['Company', 'List','Tick', 'Gestalt Rank', 'Quality Rank', 'Value Rank', 'Momentum Rank', 'EA ret std', '1 Year Volatility']
compact_mom = ['Company', 'List','Tick','Momentum Rank','EA ret std', '1 Year Volatility']
# numbers of stocks to select for diff strategies

stocks = 20
## MOMENTUM ##
momentum = momentum_tmp[0:stocks]
Momentum = momentum[compact_mom]


## TRIPLE SORT ##
gestalt = gestalt_tmp[0:stocks]
gestalt = gestalt[compact]

# %% [markdown]
# ### Print Stock Selection

# %%
#gestalt 
th_props = [
  ('font-size', '14px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'Black'),
  ('background-color', '#f7f7f9')
  ]
# Set CSS properties for td elements in dataframe
td_props = [('font-size', '12px'), ('text-align', 'center')]
#set caption props
caption_props = [('color', 'black'),('font-size', '22px'),
        ("text-align", "center"),
        ('font-weight', 'bold')]
# Set table styles
styles = [
    dict(selector="th", props=th_props),
    dict(selector="td", props=td_props),
    dict(selector="caption", props=caption_props)
]
gestalt.index = range(1, len(gestalt)+1)
gestalt_view = (gestalt.style.apply(lambda x: ['background: lightgreen' if x.name in range(1, 10+1) 
                              else '' for i in x], axis=1).set_table_styles(styles)
                 .format({'EA ret std': "{:.1f}",'1 Year Volatility': "{:.1%}"})
                 .set_caption("Gestalt"))
gestalt_view
# Out:
# <style  type="text/css" >
#     #T_31fe70c2_63c8_11ec_a201_8c859039bca2 th {
#           font-size: 14px;
#           text-align: center;
#           font-weight: bold;
#           color: Black;
#           background-color: #f7f7f9;
#     }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2 td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2 caption {
#           color: black;
#           font-size: 22px;
#           text-align: center;
#           font-weight: bold;
#     }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row0_col0 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row0_col1 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row0_col2 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row0_col3 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row0_col4 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row0_col5 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row0_col6 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row0_col7 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row0_col8 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row1_col0 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row1_col1 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row1_col2 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row1_col3 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row1_col4 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row1_col5 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row1_col6 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row1_col7 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row1_col8 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row2_col0 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row2_col1 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row2_col2 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row2_col3 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row2_col4 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row2_col5 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row2_col6 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row2_col7 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row2_col8 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row3_col0 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row3_col1 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row3_col2 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row3_col3 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row3_col4 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row3_col5 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row3_col6 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row3_col7 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row3_col8 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row4_col0 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row4_col1 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row4_col2 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row4_col3 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row4_col4 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row4_col5 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row4_col6 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row4_col7 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row4_col8 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row5_col0 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row5_col1 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row5_col2 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row5_col3 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row5_col4 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row5_col5 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row5_col6 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row5_col7 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row5_col8 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row6_col0 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row6_col1 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row6_col2 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row6_col3 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row6_col4 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row6_col5 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row6_col6 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row6_col7 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row6_col8 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row7_col0 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row7_col1 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row7_col2 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row7_col3 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row7_col4 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row7_col5 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row7_col6 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row7_col7 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row7_col8 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row8_col0 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c8_11ec_a201_8c859039bca2row8_col1 {
#             background:  lightgreen;
#         }    #T_31fe70c2_63c

# %%
th_props = [
  ('font-size', '14px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'Black'),
  ('background-color', '#f7f7f9')
  ]
# Set CSS properties for td elements in dataframe
td_props = [('font-size', '12px'), ('text-align', 'center')]
#set caption props
caption_props = [('color', 'black'),('font-size', '22px'),
        ("text-align", "center"),
        ('font-weight', 'bold')]
# Set table styles
styles = [
    dict(selector="th", props=th_props),
    dict(selector="td", props=td_props),
    dict(selector="caption", props=caption_props)
]
Momentum.index = range(1,len(Momentum)+1)
Momentum_view = (Momentum.style.apply(lambda x: ['background: lightgreen' if x.name in range(1,10+1) 
                              else '' for i in x], axis=1).set_table_styles(styles).format({'EA ret std': "{:.1f}",'1 Year Volatility': "{:.1%}"})
                 .set_caption("Focused Momentum"))
Momentum_view
# Out:
# <style  type="text/css" >
#     #T_32a41cc0_63c8_11ec_a201_8c859039bca2 th {
#           font-size: 14px;
#           text-align: center;
#           font-weight: bold;
#           color: Black;
#           background-color: #f7f7f9;
#     }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2 td {
#           font-size: 12px;
#           text-align: center;
#     }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2 caption {
#           color: black;
#           font-size: 22px;
#           text-align: center;
#           font-weight: bold;
#     }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row0_col0 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row0_col1 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row0_col2 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row0_col3 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row0_col4 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row0_col5 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row1_col0 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row1_col1 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row1_col2 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row1_col3 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row1_col4 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row1_col5 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row2_col0 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row2_col1 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row2_col2 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row2_col3 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row2_col4 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row2_col5 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row3_col0 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row3_col1 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row3_col2 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row3_col3 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row3_col4 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row3_col5 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row4_col0 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row4_col1 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row4_col2 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row4_col3 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row4_col4 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row4_col5 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row5_col0 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row5_col1 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row5_col2 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row5_col3 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row5_col4 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row5_col5 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row6_col0 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row6_col1 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row6_col2 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row6_col3 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row6_col4 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row6_col5 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row7_col0 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row7_col1 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row7_col2 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row7_col3 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row7_col4 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row7_col5 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row8_col0 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row8_col1 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row8_col2 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row8_col3 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row8_col4 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row8_col5 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row9_col0 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row9_col1 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row9_col2 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row9_col3 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row9_col4 {
#             background:  lightgreen;
#         }    #T_32a41cc0_63c8_11ec_a201_8c859039bca2row9_col5 {
#             background:  lightgreen;
#         }</style><table id="T_32a41cc0_63c8_11ec_a201_8c859039bca2" ><caption>Focused Momentum</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Company</th>        <th class="col_heading level0 col1" >List</th>        <th class="col_heading level0 col2" >Tick</th>        <th class="col_heading level0 col3" >Momentum Rank</th>        <th class="col_heading level0 col4" >EA ret std</th>        <th class="col_heading level0 col5" >1 Year Volatility</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_32a41cc0_63c8_11ec_a201_8c859039bca2level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_32a41cc0_63c8_11ec_a201_8c859039bca2row0_col0" class="data row0 col0" >Samhällsbyggnadsbolag B</td>
#                         <td id="T_32a41cc0_63c8_11ec_a201_8c859039bca2row0_col1" class="data row0 col1" >Large Cap</td>
#                         <td id="T_32a41cc0_63c8_11ec_a201_8c859039bca2row0_col2" class="data row0 col2" >SBB B</td>
#                         <td id="T_32a41cc0_63c8_11ec_a201_8c859039bca2row0_col3" class="data row0 col3" >1</td>
#                         <td id="T_32a41cc0_63c8_11ec_a201_8c859039bca2row0_col4" class="data row0 col4" >1.1</td>
#                         <td id="T_32a41cc0_63c8_11ec_a201_8c859039bca2row0_col5" class="data row0 col5" >27.2%</td>
#             </tr>
#             <tr>

# %%
data_gestalt.sort_values(by=['Momentum Rank']).head(20)
# Out:
#      Unnamed: 0  Börsdata ID           Company               Industry  \
# 306         306          162              NOTE         Semiconductors
# 419         419          775         Transtema       Telecom Services
# 192         192          403             Hanza   Business Consultants
# 291         291          154       Net Insight         Communications
# 197         197          405        Hexatronic  Electrical Components
# 43           43         1557           Awardit            Advertising
# 286         286         1695        NCAB Group         Semiconductors
# 410         410         1789           Teqnion  Industrial Components
# 430         430         1843         Vertiseit            IT Services
# 7             7         1572          Acconeer   Measuring & Analysis
# 18           18         1358     Alcadon Group  Electrical Components
# 367         367          200            Sectra      Medical Equipment
# 292         292          155          New Wave    Clothing & Footwear
# 397         397         1489  Surgical Science      Medical Equipment
# 71           71           38        Björn Borg    Clothing & Footwear
# 220         220         1455          Integrum      Medical Equipment
# 279         279         1421              Mips     Recreation & Sport
# 330         330          177            Poolia            Outsourcing
# 256         256          127            Lindab           Installation
# 12           12          257   ADDvise Group A       Medical Supplies
#
#       Volume     P/FCF  Assets Turn  Gross profit  Tot. Assets      ROC  ...  \
# 306   19.962  2056.280        1.219       301.000     1882.000  0.25473  ...
# 419    7.054     6.818        2.200      1069.857      746.278  0.59647  ...
# 192    4.891    68.117        1.302       950.700     1761.200  0.10853  ...
# 291   19.958    25.634        0.471       228.704      807.374  0.05211  ...
# 197  116.121  2056.280        0.877      1350.458     3363.400  0.16004  ...
# 43     2.438  2056.280        0.572       127.136      688.935  0.07446  ...
# 286   13.390  2056.280        1.401       850.300     1981.800  0.31141  ...
# 410    2.599   395.115        1.188       356.416      694.594  0.20524  ...
# 430    0.684  2056.280        0.433        68.833      239.726  0.01963  ...
# 7     11.323  2056.280        0.255        21.222      102.092 -1.16277  ...
# 18     3.743    56.639        0.914        71.500      701.000  0.13003  ...
# 367   40.044   198.495        1.096      1587.444     1634.497  0.70383  ...
# 292   26.138     8.749        0.848      2991.500     7415.900  0.16002  ...
# 397   20.336  2056.280        0.055       164.127     3800.002  0.00756  ...
# 71     2.004    11.561        1.142       435.267      676.127  0.21819  ...
# 220    3.799  2056.280        0.408        51.675      151.037  0.16058  ...
# 279   67.875   136.444        0.861       402.000      639.000  0.72087  ...
# 330    0.950    11.768        3.088       139.100      574.700  0.55777  ...
# 256   62.220   108.727        0.910      2963.000    10761.000  0.17024  ...
# 12     2.196  2056.280        0.560       188.010      739.110  0.09231  ...
#
#      EV/EBIT Rank  Yield Rank  ROE Rank  ROC Rank  FCFROE Rank  GPA Rank  \
# 306         163.0       268.5      64.0      57.0        218.0     266.0
# 419         104.0       268.5      25.0      20.0          7.0       3.0
# 192         101.0       142.0     159.0     160.0        170.0      62.0
# 291         236.0       268.5     238.0     230.0        122.0     150.0
# 197         222.0       165.0      60.0     112.0        315.0     101.0
# 43          226.0       124.0     210.0     208.0        236.0     243.0
# 286         208.0        91.0      37.0      43.0        264.0      91.0
# 410         164.0       268.5      76.0      77.0        183.0      71.0
# 430         246.0       268.5     233.0     249.0        362.0     147.0
# 7           311.5       268.5     348.0     335.0        333.0     221.0
# 18          157.0       268.5     131.0     143.0        141.0     298.0
# 367         240.0       152.0      20.0      15.0         68.0      14.0
# 292          64.0       268.5     111.0     113.0         46.0     100.0
# 397         249.0       268.5     242.0     254.0        352.0     323.0
# 71           49.0        31.0      58.0      72.0         42.0      37.0
# 220         248.0       268.5     235.0     111.0        225.0     115.0
# 279         241.0       158.0       9.0      14.0         15.0      41.0
# 330          32.0        29.0      32.0      22.0         29.0     176.0
# 256         116.0       115.0     102.0     105.0        171.0     158.0
# 12          192.0       162.0     234.0     186.0        328.0     169.0
#
#      Assets Turn Rank  Quality Rank Value Rank Gestalt Rank
# 306              64.0         117.5      213.0         73.0
# 419              12.0           4.0      135.0          7.0
# 192              54.5          96.0       86.0         14.0
# 291             247.0         207.0      194.5        119.5
# 197             139.0         138.0      262.0        117.5
# 43              232.0         244.0      232.0        161.0
# 286              41.0          61.0      239.0         59.0
# 410              71.0          62.0      194.5         42.0
# 430             254.5         267.0      284.0        200.0
# 7               300.0         328.5      370.0        263.0
# 18              126.0         169.0      172.0         84.0
# 367              90.0          17.0      261.0         52.0
# 292             145.0          76.0       91.5         12.0
# 397             346.5         324.0      299.0        229.0
# 71               80.5          25.0       42.0          2.0
# 220             260.0         201.0      320.0        185.0
# 279             141.0          18.0      269.0         57.0
# 330               3.0          21.0       29.0          1.0
# 256             127.0         113.5      128.0         39.5
# 12              235.0         246.5      223.0        167.0
#
# [20 rows x 60 columns]
